# %%
import re
from konlpy.tag import Mecab
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# %%
# 1. 데이터 불러오기
with open('korean-english-park.train.ko', 'r', encoding='utf-8') as f:
    kor_sentences = f.readlines()

with open('korean-english-park.train.en', 'r', encoding='utf-8') as f:
    eng_sentences = f.readlines()

# %%
kor_sentences
# Out:
# ['개인용 컴퓨터 사용의 상당 부분은 "이것보다 뛰어날 수 있느냐?"\n',
#  '모든 광마우스와 마찬가지 로 이 광마우스도 책상 위에 놓는 마우스 패드를 필요로 하지 않는다.\n',
#  '그러나 이것은 또한 책상도 필요로 하지 않는다.\n',
#  '79.95달러하는 이 최첨단 무선 광마우스는 허공에서 팔목, 팔, 그외에 어떤 부분이든 그 움직임에따라 커서의 움직임을 조절하는 회전 운동 센서를 사용하고 있다.\n',
#  '정보 관리들은 동남 아시아에서의 선박들에 대한 많은 (테러) 계획들이 실패로 돌아갔음을 밝혔으며, 세계 해상 교역량의 거의 3분의 1을 운송하는 좁은 해로인 말라카 해협이 테러 공격을 당하기 쉽다고 경고하고 있다.\n',
#  '이 지역에 있는 미국 선박과 상업용 선박들에 대한 알카에다의 (테러) 시도 중 여러 건이 실패했다는 것을 알게 된 후에, 전문가들은 테러 조직이 여전히 세계 경제에 타격을 입히려 한다고 경고하고 있으며, 동남 아시아에 있는 세계 경제의 주요 통로가 위험에 처해 있다고 그들은 생각하고 있다.\n',
#  '국립 과학 학회가 발표한 새 보고서에따르면, 복잡한 임무를 수행해야 하는 군인들이나 보다 오랜 시간 동안 경계를 늦추지 않고 있기 위해 도움이 필요한 군인들에게 카페인이 반응 시간을 증가시키고 임무 수행 능력을 향상시키는데 도움이 된다고 한다.\n',
#  '이 보고서에따르면, "특히, 군사 작전에서 생사가 걸린 상황이 될 수도 있는 반응 속도와 시각 및 청각의 경계 상태를 유지시키기 위해 카페인이 사용될 수도 있다." 고 한다.\n',
#  '"결정적인 순간에 그들의 능력을 증가시켜 줄 그 무엇이 매우 중요합니다."\n',
#  '연구가들이 이미 커피 대체품으로서 음식 대용 과자나 껌에 카페인을 첨가하는 방법을 연구하고 있다고 Archibald는 말했다.\n',
#  '약 200600밀리그램의, 비슷한 분량의 카페인은 또한 육체적 지구력을 강화시키는 데 효과적인 것 같으며, 특히 고도가 높은 곳에서 약해진 육체적 지구력을 일부 회복시켜주는 데 유용하다는 것이 이번 연구에서 밝혀졌다.\n',
#  '의약 연구소는 정부에 과학 문제에 관해 자문하기 위해 의회가 설립 인가를 내어 준 민간 단체인 국립 과학 학회의 부속 단체이다.\n',
#  '아시아에서의 왕성한 수요 덕분에 일본의 수출이 9월에 연속 6개월간 증가하여, 무역 흑자가 1조550억엔(84억7,000만달러)으로 늘어났다고 재무성이 발표했다.\n',
#  '그러나 침체되고 있는 미국 경제와 국내 수요의 약세 전망이 향후 수개월 동안의 낙관론을 어둡게 했다.\n',
#  '특수 부대가 극장 건물로 공격해 들어가면서, 러시아인이 아닌 75명의 외국인과 25명의 어린이 전부를 포함해 750명 이상의 인질들이 구출되었다.\n',
#  '러시아 특수 부대는 극장으로 공격해 들어가기 전에 신경 독가스를 사용했다.\n',
#  '많은 인질들이 화학 가스의 영향으로 고통을 겪으며 병원으로 옮겨졌다.\n',
#  '과거 노조 지도자였던 루이스 이나시오 룰라 다 실바가 브라질의 대통령 선거 결선 투표에서 압승을 거두면서, 라틴 아메리카 최대 국가로서는 좌파로의 역사적인 전환을 맞이하게 되었다.\n',
#  '실바의 노동자당이 자신들의 후보가 선거의 승리자라고 선언한 후 몇 시간이 지나, 집권당 후보인 조제 세하는 패배를 시인했다.\n',
#  '수천명의 실바 지지자들이 상 파울로와 리오 데 자네이로의 거리에 모여 들어, 실바가 이끄는 당의 붉은 깃발을 흔들며 축하했다.\n',
#  '북한의 핵무기 계획을 포기하도록 하려는 압력이 거세지고 있는 가운데, 일본과 북한의 외교관들이 외교 관계를 정상화하려는 회담을 재개했다.\n',
#  '말레이시아의 수도 쿠알라 룸푸르에서 열리는 이틀간의 회담에서는 1970년대와 80년대에 있었던 일본 민간인들의 납치에 대한 보다 충분한 설명을 요청하는 것 뿐만아니라 북한의 (핵)폭탄 제조 노력에 대한 일본의 우려가 주로 논의될 것으로 예상되고 있다.\n',
#  '100여명의 사망자가 예상되는 베트남 빌딩 화재\n',
#  '상점, 디스코텍, 그리고 여러 외국 회사들이 들어 있는 베트남 호지민市의 6층 건물을 휩쓸어버린 화재가 발생하여, 적어도 54명이 사망한 것으로 확인되었는데\n',
#  '최초 보도에 의하면 그 화재는 건물 2층의 Blue Disco에서 누전에 의해 발화되었을 것이라고 했다.\n',
#  '소방관들이 그 지옥 같은 화재를 진압하는데는 5 시간 이상이 걸렸는데, 강한 열과 수그러들지 않는 불길 때문에 소방관들은 약 4시간 동안 건물에 진입할 수 없었다.\n',
#  '이동할 수 있는 폭탄 제거 로보트가 이미 폭발물이나 위험 물질이 있는 것으로 의심되는 자동차, 건물, 또는 우편물을 검사할 수 있다고, 유엔의 유럽 경제 위원회 소속 전문가인 Jan Karlsson이 전하고 있다.\n',
#  '어휘 :\n',
#  '"테러범들과 싸우기 위해서 자동화 기술에 투자하는 것이 분명히 훨씬 많은 이익이 있습니다," 라고 Karlsson이 말했다.\n',
#  '"자동화 기술은 우체국에서, 그리고 업무가 끝난 후 사무실 경비에, 그리고 의심스러운 차량을 수색하는 데 사용될 수 있습니다."\n',
#  '어휘 :\n',
#  '그와 동시 에 노동 비용은 더욱 상승하고 있습니다." 라고 말했다.\n',
#  '"산업용 로보트 분야에서 2000년은 최상의 해였습니다." 라고 이 스웨덴인은 덧붙혀 말했다.\n',
#  '"일본, 유럽 및 북아메리카 뿐만아니라 일부 개발도상국들, 예를들어 브라질, 중국 및 남아프리카에서도 산업용 로보트는 사용량이 폭증하기 시작했습니다.\n',
#  '로보트 장치의 연간 판매액은 50억60억달러로 추산되고 있다.\n',
#  '그러나 필수 소프트웨어 및 통합 시스템 설치 비용을 합할 경우, 전체 로보트 공학 시장의 가치는 250억달러에 달할 수 있다.\n',
#  '2000년까지 이스라엘과 영국을 비롯한 여러 국가들에서 화재 진압 및 폭탄 처리 로보트 시스템이 약 50대가 판매되었다.\n',
#  '미국에서 끔찍한 공격이 발생하기 전에 작성된 이 연구 보고서는 2004년까지 120대의 시스템이 판매될 것으로 예측하고 있다.\n',
#  '약 2,300대의 로보트가 핵, 화학 물질, 폐기물, 또는 기타 위험한 합성물을 파괴하거나, 처리하거나, 해체하는 작업을 하고 있다고 보고서는 전했다.\n',
#  '또 다른 60대의 로보트가 경비 일을 하고 있다.\n',
#  '"경호 로보트가 침입자나 화재를 탐지하기 위해서 개인적으로, 그리고 전문적으로 사용되고 있습니다."\n',
#  '라고 Karlsson이 말했다. "국방성은 그러한 로보트를 여러 대 갖고 있으며, 그 로보트들은 미국과 유럽의 핵 발전소에서 사용되고 있지만, 시장은 아직도 한계를 벗어나지 못하고 있습니다."\n',
#  '미국 의회 의원 5명은 북한이 핵무기 계획을 계속 진행하는 데 대해 북한을 응징하고, 이 고립된 사회주의 국가에서의 정권 교체를 추진하라고 촉구하는 서한을 부시 대통령에게 보냈다.\n',
#  '행정부에 보낸 서한에서, 공화당 상원의원 제시 헬름스, 봅 스미스, 존 킬, 그리고 공화당 하원의원 크리스 콕스와 민주당 하원의원 에드 마키는 대통령에게 미국이 북한에게 연료용 기름을 제공하기로 한 1994 협약을 폐지하라고 요청했다.\n',
#  '양측이 아시아에서 가장 오래 지속되어온 분쟁을 종식시키기 위해 노력함에따라, 스리랑카 정부와 타밀 반군 사이 의 4일간의 평화 회담이 큰 성과를 거두고 끝났다.\n',
#  '65,000명에 가까운 사상자를 냈으며, 150만명 이상을 피난시켰던 19년간의 전쟁에서의 핵심적인 쟁점들을 검토하기 위해 3개 위원회를 구성하기로 합의한 후에, 양측은 태국에서의 회담이 성공적이었다고 선언했다.\n',
#  '새 기구들은 민족 문제와 권력 분할 문제를 중점적으로 다룰 것이며, 난민 재정착과 수십년간의 내전으로 파괴된 지역의 복구 문제를 감독할 것이라고 스리랑카 정부는 말하고 있다.\n',
#  '로스앤젤레스 남부의 한 고속도로에서 194대의 차량이 연쇄 추돌하여 40명 이상이 부상당하고, 5명이 중상을 입었다고 경찰이 발표했다.\n',
#  '이 사고는 오전 7시 직전에 발생했으며, 사고가 나자 캘리포니아 고속도로 순찰대는 즉시 Interstate 710 도로의 2마일 구간을 양방향 모두 그날 오후까지 폐쇄시켰다.\n',
#  '짙은 안개가 사고의 요인이었을 것이라고 캘리포니아 고속도로 순찰대 관리들이 말했다.\n',
#  '신랑 들러리가 포도주 잔을 들어 올린다 그리고는 술주정을 늘어놓는다.\n',
#  '하지만 점점 더 많은 연인들이 웹사이트에 완벽한 축배의 말을 대신 써주도록 의뢰함으로써 그러한 실패로부터 자신들을 보호하고 있다.\n',
#  '적당한 가격의 돈을 받고, 수십개의 사이트들이 정치 집회, 세례식, 성인식, 장례식, 심지어 기업 광고 등 과 같은 어떠한 행사를 위해서도 거기에 적합한 말을 찾아주겠다고 약속하고 있다.\n',
#  '그러나 행복한 신랑, 신부를 위한 축배의 말이 가장 빈번하게 의뢰되고 있다.\n',
#  '美 공화당과 부시 대통령에게는 놀랍고도 역사적 밤 에, 공화당이 상원을 장악했으며, 하원에서도 과반수를 유지하였다.\n',
#  '하원 쪽에서는 공화당이 선거에 들어갈 때 차지하고 있던 223석에서 늘어나 최소한 226석을 얻었다.\n',
#  '중국이 604억달러의 비용이 소요되는 아마도 세계 에서 가장 값비싼 계획 중의 하나이며, 중국 역사상 가장 규모가 큰 수로 변경 계획을 밝혔다.\n',
#  '이 사업은 중국에서 가장 긴 강인 양쯔강의 물을 강 유역이 말라 들어가고 있는 북부의 황허, 화이허, 그리고 하이허, 세 개의 강으로 돌리게 될 것이다.\n',
#  '이 야심찬 남북 수로 변경 사업은 더 습하고 홍수가 잦은 남부의 강 유역을 매우 건조한 북부 지방과 연결시키는 세 개의 수로를 따라 물을 이동시키게 될 것이다.\n',
#  '최근의 사업 중에는 3개의 협곡 수력 발전 댐, 4,000킬로미터의 천연 가스 파이프라인 계획, 그리고 큉하이에서 티벳까지의 세계 최고도의 철로 건설이 포함되어 있다.\n',
#  '수자원부 당국은 논란이 되고 있고, 막대한 비용이 드는 이 사업에 대해 내년에 건설을 시작할 계획이다.\n',
#  '장쟈오 수자원부 차관은 사업 승인을 받기 위해 금년말까지 이 사업 계획이 의회에 제출될 것이라고 말했다.\n',
#  '환경 전문가들은 이 새 사업이 광범위한 부패와 사람들의 고난, 그리고 환경 파괴를 야기시킬 수 있고, 30년내에 양쯔강을 고갈시킬 수도 있다고 말한다.\n',
#  '그들은 중국이 물 가격 인상, 무분별한 우물 파기의 억제, 누수 방지, 그리고 용수 처리 방법의 개선과 같은 보다 간단한 조치들을 취할 것을 촉구하고 있다.\n',
#  '유럽의 관리들은 공화당의 중간 선거 득표의 결과로 이제는 미국 대통령이 특히 이라크에 대해 더욱 대담해질 것이라는 우려를 나타냈다.\n',
#  '유럽과 부시는 이라크에 대한 새 유엔 결의안 초안에 군사 행동을 통한 위협을 포함시킬지 여부를 놓고 서로 다투어왔으며, 유럽 지도자들은 또한 이라크에서의 "정권 교체"를 바라는 미국의 주장에 대해 우려를 표명했다.\n',
#  '양측은 또한 지구 온난화와 새 국제 형사 재판소를 포함한 광범위한 문제에 대해 견해 차이를 보여왔다.\n',
#  '영국의 영화 비평가와 작가들을 대상으로 한 조사에 의하면, 프란시스 포드 코폴라의 反베트남전 명작, "지옥의 묵시록(Apocalypse Now)"이 지난 25년 간 가장 위대한 영화라고 한다.\n',
#  '마틴 스콜세지의 영화 두 편이 영국 영화 연구소의 Sight & Sound誌가 발표한 여론 조사에서 상위 10위 안에 들었다.\n',
#  '50명의 응답자들은 스콜세지의 "성난 황소(Raging Bull)"를 지난 25년 간 두번째로 가장 훌륭한 영화로 선정했으며, 잉그마르 베르그만의 "패니와 알렉산더(Fanny and Alexander)"가 3위로 그 뒤를 이었다.\n',
#  '34명을 태운 필리핀 국내 여객기가 추락한 후에 필리핀 해안 경비대와 해군 잠수부들이 마닐나 만(灣)에서 생존자를 수색하고 있다. 추락한지 이틀이 지난 지금 까지 그들은 승객 16명을 구조했으며, 이미 사망한 다른 14명을 발견했다고 해군 관리들이 말했다.\n',
#  '다른 4명은 아직도 실종된 상태이다.\n',
#  '생존자들은 필리핀 수도 마닐라의 해안 지역인 마닐라 만(灣) 부근에 있는 병원들로 이송되었다.\n',
#  '잇따른 토네이도에 의해 36명의 사망자 발생\n',
#  '70개 이상의 토네이도가 덮친 이후에 알라바마州에서 펜실바니아州에 이르는 지역에서 가옥, 학교, 교회, 상점들이 무너져 내려 앉았다.\n',
#  '유엔 무기 사찰관들의 복귀를 거부하라는 권고안을 이라크 의회가 만장일치로 채택한 후에, 코피 아난 유엔 사무총장은 이라크의 최종 결정을 받기를 "기대하고 있다"고 말했다.\n',
#  '하루가 지난 후 뉴욕에서, 이라크의 무하마드 알 두리 유엔 대사는 코피 아난에게 (사찰) 수용서를 전달했으며, 그 서한에는 "이라크는 어떠한 대랑 살상 무기도 보유하지 않을 것이다.\n',
#  '따라서 우리는 (무기) 사찰단이 이라크로 다시 돌아온다 해도 그들에 대해 불안해 하지 않는다. 이라크는 결백하다.\n',
#  '적당한 육체 활동이 심장 질환을 예방하는 데 좋지만 활동의 정도를 높이는 것이 더욱 좋을 수 있으며, 특히 근력 운동을 함께 하면 더 좋다는 것이 4만명 이상의 남성을 대상으로 한 하버드의 한 연구 조사에서 나타났다.\n',
#  '강도가 높은 운동에는 달리기나 시간당 6마일의 속도로 조깅하는 것이 포함되는 반면에, 강도가 낮은 운동에는 시간당 약 2마일의 속도로 걷는 것이 포함된다.\n',
#  '또한 근력 운동은 활발하게 걷는 것이나 최소한 20분 동안 뛰는 것과 같은 유산소 활동에서 얻는 운동 효과를 심장과 폐에 주지 않기 때문에, 연구학자들은 근력 운동이 심장에 큰 영향을 미치는지 여부에 대해 논쟁을 해왔다.\n',
#  '그러나 이번 하버드 공중 위생 학교의 연구에서는, 일주일에 30분이나 그 이상 근력 운동을 한 남성들이 아령으로 운동하지 않는 남성들보다 심장병에 걸릴 위험이 23% 낮았다.\n',
#  '이러한 긍정적인 효과는 부분적으로는 근력 운동을 통해 얻어진 혈압과 신체 지방의 감소에 의한 것일 수 있다고 연구학자들은 말했다.\n',
#  '근력 운동에 의한 독립적인 결과를 고려하면, 근력 운동을 강도 높은 운동 프로그램에 추가하는 것이 훨씬 더 큰 효과를 얻을 수 있을 것이라는 것을 연구학자들은 이론화하였다.\n',
#  '이번 연구 조사는 1986년에서 1998년 사이 의 의학 보고서와 44,452명의 건강 전문가들에게 정기적으로 보낸 설문서에 근거한 것이다.\n',
#  '연구가 시작될 때에 참가자들의 나이는 40세에서 75세 사이였다.\n',
#  '결과적으로 1,700명의 참가자들에게서 심장 질환이 진단되었다.\n',
#  '일주일에 한 시간 또는 그 이상 동안 시속 6마일 이상의 속도로 달린 사람들은 달리기를 하지 않은 사람들보다 심장 질환에 걸린 가능성이 42%나 낮았다.\n',
#  '매일 최소한 30분 동안 적어도 시간당 3마일의 적당한 속도로 활발하게 걸었던 사람들은 그렇게 하지 않은 사람들보다 심장 질환에 걸릴 가능성이 18% 낮았다.\n',
#  '강도가 약하게 걷는 것으로부터 발견된 현저한 심장 (질환 억제) 효과는 없었다.\n',
#  '라고 미국 심장 협회 대변인인 제럴드 플레처 박사가 말했다.\n',
#  '그는 이 연구 결과가 美 심장 협회의 지침과도 부합된다고 말했는데, 美 심장 협회의 지침은 일주일에 적어도 6일은 유산소 운동을 하고, 매주 23번은 근력 운동을 하라고 권장하고 있다.\n',
#  '그러나 "(운동을) 조금이라도 하는 것이 텔레비전 앞에 앉아 있는 것보다는 좋습니다." 라고 플레처 박사는 말했다.\n',
#  '"해리포터와 비밀의 방"의 개봉을 며칠 앞두고, 이 영화의 제작사는 해적판이 인터넷에 출현하고 있어 걱정이 된다고 말했다.\n',
#  '워너 브러더스는 이 영화의 불법 복제판이 인터넷 상에 나타났다고 밝혔는데, 인터넷에는 영화가 극장에서 상영되기도 전에 불법 복제판이 나타나는 경우가 종종 있다.\n',
#  '핵무기 개발 완료를 공식 발표한 북한\n',
#  '북한이 핵무기를 개발했다고 처음으로 밝혔다.\n',
#  '북한 방송을 감시 청취하는 연합 통신에따르면, 북한은 "미국 제국주의자들에 의한 증가한 핵 위협에 대처하기 위해 핵무기와 다른 강력한 군사 무기들을 보유하게 되었다."\n',
#  '그러나 그 보도가 언급한 것이 플루토늄에 의한 무기인지 우라늄에 의한 무기인지는 명확하지 않았다.\n',
#  '마이크로소프트社의 공동 창업자인 빌 게이츠는 알람 시계와 펜과 같은 일상 생활용품에 지능형 컴퓨터 기술을 결합시키는 전략을 발표하면서, 첨단 기술 산업의 침체에도 불구하고 혁신은 계속 되고 있다고 말했다.\n',
#  '제 23차 연례 컴덱스 박람회의 개회사를 한 케이츠는 2년여전 기술 산업의 거품이 붕괴된 이후에 첨단 기술에 대해 부정적인 인식이 있다고 말했다.\n',
#  '1,960만갤론 이상의 중유를 운반하던 손상된 유조선이 스페인 북서부 연안 130마일 해역에서 침몰하여, 스페인 당국이 어업이 주요 산업인 이 지역에서 해안선 보호를 위해 황급히 서두르고 있다.\n',
#  '싣고 있는 기름이 모두 유출된다면, 알라스카州 프린스 윌리암 사운드에서 1989년에 발생했던 엑손 발데즈 기름 유출 사건의 규모보다 두 배 이상이 되는 사상 최대 규모의 기름 유출 사건 중의 하나가 될 것이라고 세계 야생 생물 기금이 경고하고 있다.\n',
#  '대도시를 완전히 파괴할 만큼 커다란 우주의 암석 덩어리들이 지구에 충돌하는 것은 이전에 생각했던 것보다 빈도가 훨씬 적은, 대략 1천년에 한 번 정도이다.\n',
#  '핵폭발의 근거지를 찾아내는 美 국방성의 인공위성으로부터 얻은 수년간의 자료에 대한 전례 없는 조사에서 이러한 수정된 계산 결과가 나오게 되었다.\n',
#  '최인원은 배드민턴 게임을 완벽하게 하고 싶어한다.\n',
#  '김소현은 그저 잠을 많이 자려 한다.\n',
#  '한국이 주 6일 근무에서 미국, 일본 및 서구 유럽에서 일반화되어 있는 주 5일 근무로 변경하는 것을 고려하고 있음에따라, 이 세 명의 임금 노동자와 수백만의 동포들은 머리 속으로 앞으로 생길 여가를 어떻게 지낼 것인지 상상하기에 바쁘다.\n',
#  '한국은 또한 전통적인 경제 논리에 명백히 거슬리는 이런 변화를 이룩해내길 바라고 있다.\n',
#  '노조의 강력한 지지를 받고 있는 정부의 안(案)은 근로자들에게 똑 같은 임금을 받으며 일년에 300500시간 더 적게 일하도록 요구하고 있다.\n',
#  '정부는 전에도 한 번 그런 적이 있었기 때문에 이 책략이 성공할 수 있다고 생각하고 있다.\n',
#  '1989년에 한국은 임금의 삭감 없이 연간 근로 시간을 2,700시간에서 2,500시간으로 줄일 것을 기업들에게 지시했다.\n',
#  '지금은 그때와 크게 다른 것이 한국은 1980년대 말에 처했었던 편협하고 억압적인 경제 체제가 아니고, 근로자들도 착취당하고 임금을 충분히 받지 못하는 희생자들이 아니라는 점을 고용주들은 언급하고 있다.\n',
#  '지금의 경제는 훨씬 활력적이며, 근로자들은 잘 조직되어 있고, 정치적으로 적극적이며, 일상적으로 생산성을 능가하는 임금 인상의 수혜자들이다.\n',
#  '노조 측은 완벽한 시기란 없으며, 높은 임금이 한국을 보다 고급 산업으로 이동시킬 것이고, 근로자와 한국 사회는 보다 행복해지고, 보다 건강해지고, 보다 여유로와질 것이라고 말한다.\n',
#  '양측은 한 가지 즉, 한국인들은 오래 일하긴 하지만 반드시 효율적으로 일하는 것은 아니라는 데에는 동의한다.\n',
#  '국제 노동 기구에따르면, 미국인들의 1,979시간, 그리고 일본인들의 1,859시간과 비교해, 한국인들은 연간 2,474시간을 일한다고 한다.\n',
#  '그러나 한국인들은 생산성이 그들보다 각기 62%, 45%나 더 낮다.\n',
#  '아침 8시에서 밤 10시까지 지속되는 주중 근무일에 잠자고, 먹고, 한가롭게 빈둥거리고, 인터넷 쇼핑하고, 주식 거래하고, 카드 놀이하는 것이 일상화되어 있다.\n',
#  '분석가들은 일과 놀이가 광범위하게 혼합되어 있는 것이 부분적으로는 한국이 농경에서 공장으로, 그리고 불빛이 환하게 밝혀진 사무실로 급속하게 변화한 탓으로 돌리고 있다.\n',
#  '"미국은 상업 활동의 역사가 수백년이지만, 한국은 얼마 되지 않습니다."\n',
#  '과거 공산주의 국가였던 7개국을 NATO에 가입하도록 요청한 이번 결정은 그 국가들에게는 베를린 장벽의 붕괴 만큼이나 의미심장한 것이었다.\n',
#  '새 회원국들인 에스토니아, 라트비아, 리투아니아, 슬로베이아, 슬로바키아, 불가리아, 그리고 루마니아는 현재의 19개 회원국들에 의해 정식으로 승인을 받은 후 2004년에 북대서양 조약 기구 가입 자격을 받게 될 예정이다.\n',
#  '사우디아라비아 정부가 9월 11일 항공기 납치범들 중 두 명의 동료들에게 자금을 보내주었는지 여부를 FBI가 수사하고 있다.\n',
#  '국토안보부 신설 법안에 서명한 부시 부시 대통령이 내각 수준의 국토안보부를 신설하는 법안에 서명했는데, 이는 50여년만에 가장 규모가 큰 연방 정부 조직 개편 작업을 착수하려는 조치이다.\n',
#  '부시는 이 거대한 신설 부서를 이끌 지명자로서 백악관 국토안보실장으로 있는 톰 리지를 임명했다.\n',
#  '이 부서(가 생긴 것)은 2001년 9월 11일 테러 공격의 직접적인 결과인데, 그 테러 공격은 안보 공백과 정보 수집 실패를 노출시켰으며, 국방, 정보, 그리고 법 집행 부서에 대한 대대적인 변화를 요구하게 되었다.\n',
#  '3개월만에 이혼하는 니콜라스 케이지 그것은 리사 마리 프레슬리와 니콜라스 케이지를 위한 "Heartbreak Hotel(상심의 호텔)"인 것 같다.\n',
#  '이들의 결별에 관한 자세한 내용은 발표되지 않았지만, 양측의 진술을 보면 화해할 수 없는 불화가 있다는 것을 보여주는 것 같다.\n',
#  '5개월 이전에 미군 차량에 치였던 한국인 소녀 두 명의 죽음에 대해 부시 대통령이 사과했다.\n',
#  '6월 13일 도로에서 숨진 13살난 심미선과 신효순의 사망 사건에서 美 군사 법원에 의해 제 2 보병 사단의 페르난도 니노 하사와 마크 워커 하사가 과실 치사 혐의가 없다는 판결이 내려진지 수 일이 지난 후에 이러한 사과가 발표되었다.\n',
#  '전국 민주 노동조합 총연맹의 박강우 정책기획실장에게 있어 그 해결책은 분명하다.\n',
#  '즉, 근무시간을 합리적인 수준으로 줄이면, 사고가 적어지고, 생산성이 향상되는 것을 알게 될 것이다.\n',
#  '선례가 하나 있다.\n',
#  '1998년 가정용품 제조회사인 주식회사 유한 킴벌리가 급여 삭감 없이 주 5일 근무제로 전환했다.\n',
#  '사고와 결함률이 감소했고, 생산성은 감소된 근무 시간을 벌충할 정도로 충분히 향상되었다고 이 회사 대변인이 말했다.\n',
#  '그러나 국제적으로 경영되는 한 회사의 경험이 경제 전체에 걸쳐 발생할 수도 있는 일을 반영하지는 못한다고 경제학자들은 말하고 있다. 그리고 고용주들은 실행되지 않을지도 모를 혜택의 대가로 시간당 15%의 임금 인상에 해당하는 금액을 미리 지급하라는 요청을 받고 있다.\n',
#  '왜 이렇게 어려운 일을 서둘러 성취하려 하는가?\n',
#  '현재 한국의 일인당 소득 9,700달러에 비해, 일본은 일인당 소득이 약 19,000달러였던 1987년에 시작하여 한국과 유사한 변화를 이룩하는 데 10년이 걸렸다.\n',
#  '그리스와 폴투갈은 1997년에 이와같은 전환을 시작했으며, 마찬가지로 10년의 기한을 잡고 있다.\n',
#  '그리고 홍콩과 싱가폴은 보다 자율적인 과정에따라 그러한 방향으로 완화시켜 나가고 있다.\n',
#  '정부는 이 조치가 한국이 선진국임을 내보이는 방법이라고 말한다.\n',
#  '이러한 변화는 또한 위축된 소비를 부양시키고, 국내 여행을 촉진시키며, 도시 거주민들이 자연의 아름다움을 즐기기 위해 시골로 가게 되면서 지역 경제에도 도움이 될 것이다.\n',
#  '즉, 한국 경영자 연맹의 김 씨는 "이것은 정치적인 동기에서 비롯된 것입니다."\n',
#  '라고 말했다. "이 문제는 아주 인기가 있는 것이며, 특히 내년에 지방 선거와 총선거가 다가오면서 정부는 이 문제로 잘했다는 소리를 듣고 싶어 합니다."\n',
#  '많은 어려운 문제 중에는 휴일 문제가 있다.\n',
#  '한국인들은 연간 국경일 17일, 연차 휴가 2주, 근무연수 당 추가 휴가 1일, 보너스 휴가 12일의 휴일을 즐긴다.\n',
#  '흔히 대기업들은 개인별로 34일의 추가 휴일을 제공하고, 여자들은 12일의 생리 휴가를 추가로 얻는다.\n',
#  '토요일 휴무로 얻게 되는 52일에 이 휴일들을 더하면, 한국은 세계 에서 휴일이 가장 많은 국가가 되며, 카페에서 즐기기를 좋아하는 프랑스보다도 휴일이 많아지게 된다.\n',
#  '일부 계산에따르면, 프랑스의 145일, 미국의 142일에 비해, 총 휴일 수가 165일로 크게 증가할 수 있다.\n',
#  '또 다른 우려는 지나치게 긴장이 풀려 한국의 원동력인 일의 성과와 근로 의식이 훼손될지도 모른다는 것이다.\n',
#  '토목 기사인 최인웅은, "우리는 나태해지거나 긴장을 풀 여유가 없습니다.\n',
#  '만일 우리가 그렇게 하면, 우리 다음 세대는 더욱 게을러질 것입니다." 라고 말했다.\n',
#  '소규모 광고 회사의 부장인 원종도는 이러한 여가 시간들이 전통적으로 동질성을 자랑해 온 나라에서 사회적 긴장을 증가시킬 것이라고 흥분한다.\n',
#  '"어떤 사람은 스키를 타러 가고, 다른 사람은 지저분한 아파트에 앉아 있게 된다면, 사람들은 매우 시기하고 증오심을 갖게 될 것입니다.\n',
#  '그것은 큰 문제입니다."\n',
#  '2월이면 폐기될 미르 우주정거장\n',
#  '14년된 미르 우주정거장이 태평양의 외딴 수역에 추락하도록 하강을 유도하여 2월이면 바다에 불시착할 것이라고 관리들이 오늘 밝혔다.\n',
#  '러시아가 더이상 유지관리할 여력이 없는 이 미르 호를 어떻게 할것이냐에 대해 관리들은 여러달 동안 논쟁을 벌여왔다.\n',
#  '베트남의 호치민시를 방문한 클린턴\n',
#  '미국의 빌 클린턴 대통령은 1967년 하노이 외곽에서 격추된 美 F-105D機의 추락 장소를 방문한 후에 베트남의 호치민 시에 도착했다.\n',
#  '인터넷 감독위원회가 닷컴 이름의 위기상황을 완화하기 위하여 인터넷 상에 일단의 새로운 도메인 이름을 부여하기로 하고, .biz, .name, .info, .pro, .museum, .aero, 그리고 .coop를 선정했다.\n',
#  'ICANN의 이번 결정으로 전세계적으로 등록수가 약 2천만이 되는 닷컴으로 끝나는 과도하게 많은 주소群을 어떻게 경감시킬 것인가에 대한 5년간의 논의가 마무리되었다.\n',
#  '이 새로운 도메인 접미사들은 내년 중반에나 사용될 수 있을 것이다.\n',
#  '갱단 두목에게 노벨평화상?? 스탠리 "투키" 윌리암즈는 이 나라에서 가장 악명높은 갱단 중의 하나를 공동조직한 자이며, 1981년에 4사람을 살해한 죄로 유죄판결을 받고 사형집행을 기다리는 죄수이다.\n',
#  '그는 또한 2001년 노벨평화상 후보로 추천된 150명중의 한 사람이기도 하다.\n',
#  '윌리암즈는 샌 틴 교도소의 작은 독방에서 아이들이 자신과 똑같은 실수를 저지르지 않도록 하는 운동을 주도하고 있다.\n',
#  '그는 거리 갱단인 Crips의 조직자이자, 두목으로서의 자신의 경험에 대한 대담한 책을 집필하고 있다.\n',
#  '플로리다州 대법원은 민주당 우세의 세군데 카운티에서 수작업으로 재검표되고 있는 투표용지가 미국 43대 대통령 선거에서의 플로리다州 최종투표수에 포함되어야 한다고 판결함으로서 앨 고어측 선거운동에 주요한 법적 승리를 부여했다.\n',
#  '7명의 판사로 구성된 심사위원단인 州 최고법원은 팜비치, 브로워드, 그리고 마이애미-데이드의 3개 카운티는 재검표를 완결하고 그 결과를 11월 26일 일요일 오후 5시까지, 또는 州 국무장관이 일요일에 이를 접수할 수 없는 경우에는 11월 27일 오전 9시까지 제출해야 한다고 밝혔다.\n',
#  '이스라엘의 하데라 마을을 뒤흔든 폭발로 적어도 2명이 죽고, 36명 이상이 부상을 당했다고 현지 이스라엘 관리가 말했다.\n',
#  '이스라엘 TV방송은 차량 폭탄이 하데라의 하나씨 간선도로 상의 버스 옆에서 폭발했다고 보도했다.\n',
#  '폭탄이 실렸던 차량은 뒤틀리고, 연기가 나는 금속덩어리가 되어 버렸다.\n',
#  '폭발이 매우 강력하여, 버스를 근처 상점으로 날려버렸다.\n',
#  '여러 상점에도 불이 붙었다.\n',
#  '호전적인 회교단체인 하마스의 분견대인 "이즈 엘딘 알카쌈"이 오늘 성명에서 모든 이스라엘의 가정에 죽음을 가져다 주겠다고 밝히긴 했지만 이 폭발사건을 자신들이 주도했다는 주장이 곧바로 나오지는 않았다.\n',
#  '몇 달간 추측만 나돌던 끝에 "IT" 또는 "Ginger"이라고 언급되었던 정확히 무엇이라고 말할 수 없었던 것의 정체가 대중 앞에 드러났다.\n',
#  '월요일에 ABC 텔레비전의 프로그램인 "굿 모닝 아메리카"는 시속 약 12마일로 달릴 수 있고 바퀴가 두 개 달린 자체 동력 스쿠터인 이 발명품을 소개했다.\n',
#  '"이것은 스스로 균형을 잡으며 사람을 실어 나르는 세계 최초의 운송 수단입니다."\n',
#  '이것은 사람의 내이(內耳)와 같은 작용을 하는 자이로스코프와 센서를 갖고 있으며, 사람의 두뇌가 하는 일을 해내는 컴퓨터를 갖고 있습니다.\n',
#  '이것은 사람의 발이 하는 일을 하는 타이어를 갖고 있습니다."\n',
#  'Kamen은 Segway HT라고 불리는 이 발명품이 앞으로 수 개월 동안은 제한된 수량만 출시될 것이며, 내년 말이 되면 널리 사용될 것이라고 말했다.\n',
#  '가격은 약 3,000불이 될 것으로 예상되고 있다.\n',
#  '뉴스 웹 사이트인 Inside.com에서 1월에 처음 보도한 바에따르면, Kamen의 발명품은 Ginger를 보고 배후 자금을 대주었다고 전해지는 California 州의 실리콘밸리에 있는 몇몇 거물들을 끌어 들였다고 한다.\n',
#  '거물 투자자인 John Doerr는 Kamen을 Thomas Edison과 Henry Ford의 합성 인물이라고 불렀다.\n',
#  '애플 컴퓨터의 Steve Jobs는 사람들이 도시 전체를 "IT" 중심으로 건설해 나갈 것이라고 말한 것으로 인용되었다.\n',
#  'Amazon.com 창립자이자 CEO인 Jeff Bezos는 이 발명품을 특히 좋아했으며, Amazon의 웹 사이트에 이것을 소개했다.\n',
#  'Ginger에 관한 뉴스는 하버드 경영대 출판부가 한 작가의 도움을 받아 Ginger 제작 과정을 책에 담아 역사에 남기게 하려고 Kamen에게 250,000불을 제공했다는 사실이 밝혀졌을 때 처음으로 드러났다.\n',
#  'Kamen의 작업은 New Hampshire 州 Manchester의 DEKA 연구 및 개발이라는 실험실에서 이루어진 것이다.\n',
#  '2002년에 사상 최대의 침체를 겪은 세계 정보 기술 산업이 내년에는 5% 이상 성장할 것으로 예상되고 있다.\n',
#  '"우리는 정보 기술 및 통신 (분야)에 대한 소비가 재개되어, 이 산업의 전세계 성장률이 5.8%에 이르게 될 것으로 예상하고 있습니다."\n',
#  '그러나 여전히 내년도 성장은 무기력할 것으로 예상되고 있다.\n',
#  '이 조사 회사도 이라크에서의 전쟁이 오래 간다거나 주식 시장이 붕괴되면 소비를 위축시킬 수도 있다고 경고했다.\n',
#  '"설명되지 않는 불빛들"이라는 제목이 붙여진 이 보고서에서, 한 미국 공군 중령은 "붉은 태양 같은 빛"을 발하는 물체가 렌들쉠 숲의 나무들 사이로 움직이고 있는 것을 어떻게 목격하였는지를 밝혀 놓았다.\n',
#  '그는 호텔 발코니에서 자신의 어린 아들을 대롱대롱 매달리게 했으며, 그리고 흉측하게 변형된 그의 얼굴은 더욱 괴상해져 가고 있다.\n',
#  '계약 분쟁으로 이 44세의 연예인에 대해 제소된 소송의 재판이 재개되면서, 그의 별난 행동이 다시한번 자신의 음악적 재능을 실추시켰다.\n',
#  '십여명의 경찰과 30명의 시(市) 관리들이 이 원숭이를 찾고 있다고 도쿄에서 북서쪽으로 약 160킬로미터 떨어져 있는 수와시(市)의 시게루 아라이 경찰부서장이 말했다.\n',
#  '이 원숭이의 공격은 월요일에 시작되었는데, 월요일에 이 원숭이는 쓰레기를 집밖으로 내어놓는다든가 출근하기 위해 집을 나서는 여성 14명을 물었다.\n',
#  '화요일에 9명의 여성이 더 공격을 받았다.\n',
#  '피해자들의 대부분은 나이가 50세에서 80세 사이였다.\n',
#  '국제 원자력 기구는 북한이 핵 무기 개발 계획을 중지하고, 즉각적으로 "모든 관련 시설들"을 공개하여 사찰을 받으라고 요구했다.\n',
#  '그러나 북한 관리들은 그 요구를 거부했다.\n',
#  '그리고 미국은 사찰관들이 북한의 핵 시설을 조사하는 것을 허용하지 않겠다는 북한의 거부는 "실망스러운" 것이라고 평가했지만, 북한 측이 핵 무기 개발 계획을 포기하도록 설득하기 위해 동맹국들과 계속 협력해 나갈 것이라고 했다.\n',
#  '카페인은 원래 커피에 들어있는 물질이다.\n',
#  '카페인이 제거된 커피는 카페인이 없는 커피 또는 "디카프"라고 불리워진다.\n',
#  '류마티스성 관절염은 뼈가 연결되는 부위인 관절을 둘러싸고 있는 조직을 신체의 면역 체계가 공격하는 질병이다.\n',
#  '이 질병은 남성보다는 여성에게 더 잘 걸린다.\n',
#  'Birmingham 시의 Alabama 대학교의 연구원들은 California 州 San Francisco에 있는 미국 류마티스 전문 대학의 연례 회의에서 자신들의 연구 내용을 보고했다.\n',
#  '그들은 55세에서 69세 사이 의 여성 31,000명 이상을 연구했다.\n',
#  '이 여성들은 1986년에서 1997년까지 진행된 Iowa 여성 건강 연구에서 조사 대상이 되었었다.\n',
#  '연구원들은 이 기간 동안 류마티스성 관절염에 걸린 여성 158명을 조사했다.\n',
#  '그들은 또한 류마티스성 관절염에 걸리지 않은 여성들도 연구했다.\n',
#  '하루에 카페인이 없는 커피를 4컵 이상 마신 여성들은 카페인이 없는 커피를 전혀 마시지 않은 여성들보다 류마티스성 관절염에 걸릴 가능성이 두 배 더 많았다.\n',
#  '하루에 차를 3컵 이상 마신 여성들은 차를 전혀 마시지 않은 여성들보다 류마티스성 관절염에 걸릴 가능성이 60% 더 적었다.\n',
#  'Massachusetts 州 Boston 대학교의 연구원들은 또 다른 연구에 관해 보고했다.\n',
#  '이 연구는 흑인 여성 64,000명을 대상으로 한 류마티스성 관절염에 관한 것이었다.\n',
#  '이 여성들은 1995년에 시작된 흑인 여성의 건강 연구에 대상이 되었다.\n',
#  '연구원들은 하루에 카페인이 없는 커피를 한 컵 이상 마시면 류마티스성 관절염에 걸릴 가능성이 4배나 증가하는 것 같다는 점을 발견했다.\n',
#  '그러나 이 연구에서는, 차를 마시는 것이 류마티스성 관절염에 걸릴 가능성을 증가시켜주는 것 같았다.\n',
#  '연구원들은 이 연구들이 카페인이 없는 커피와 류마티스성 관절염의 연관성을 보여주는 최초의 연구들이라고 말했다.\n',
#  '그러나 그들은 보다 많은 연구가 행해질 때까지는 카페인이 없는 커피나 차를 끊을 것까지는 없다고 말했다.\n',
#  'DNA에 관한 것이라면, 쥐와 인간 사이 에서 그렇게 큰 차이가 없는 것으로 판명되었다.\n',
#  '쥐와 인간은 각각 약 3만개의 유전자를 갖고 있으나, 각각의 생명체에 독특한 유전자는 300개에 불과하다.\n',
#  '꼬리에 대한 유전자가 인간에게서는 "발현되지" 않았지만, 둘 다 모두 꼬리에 대한 유전자를 갖고 있다.\n',
#  '쥐는 인간 다음으로 유일한 포유 동물인데, 인간의 염색체 배열 구조는 밝혀져 있다.\n',
#  '어려움에 처한 미국 경제를 회생시키는 임무를 맡았던 부시 행정부 팀에 대한 갑작스러운 개편으로 폴 오닐 재무 장관과 래리 린시 백악관 경제 수석 고문이 사임했다.\n',
#  '후임자는 발표되지 않았다.\n',
#  '아리 플레이셔 대통령 대변인은 두 사람이 해임당한 것이냐는 질문에 각자가 사임했다고만 말하며 직접적인 논평을 하지 않으려 했다.\n',
#  '먹지 않은 음식물이 식사 찌꺼기로서가 아니라 플라스틱 포장지로서 여러분의 식탁으로 되돌아갈 수도 있다.\n',
#  '인도양의 예멘 남동쪽 해안 수백마일 지점에서 미국의 군사 무기 전문가들이 북한을 출발하여 운항 중 정선시킨 선박에 실려 있던 최소한 십여基의 스커드 미사일을 발견했다고 미국 국방성 관리들이 말했다.\n',
#  '그러나 그 선박이 이라크로 향하고 있었다는 증거는 없다고 미국 관리들이 말했다.\n',
#  '스커드 미사일은 페르시아만 전쟁 때 사담 후세인 이라크 지도자가 사우디 아라비아와 이스라엘을 공격하기 위해 사용한 탄도 미사일 유형이다.\n',
#  '혼다 자동차 회사가 어린이 크기의 걸어다니는 로봇 아시모로 가장 세심하고, 아마도 가장 정직한 자동차 거래상을 내어 놓았는지도 모른다.\n',
#  '아시모는 걷고, 계단을 오르고, 음성을 식별하는 법을 이미 알고 있다.\n',
#  '이 로봇은 전시관에서 자동차에 관한 정보를 상세히 설명하고, 광고와 혼다 자동차의 행사에 모습을 나타나면서, 홍보용 도구로 이용되고 있다.\n',
#  '법정 변호사들은 ‘당신이 답을 모르는 질문은 절대 하지 말라.’\n',
#  '외교관들도 대체로 그와 같은 원칙에 입각해서 행동한다.\n',
#  '그래서 부시 행정부가 북한 지도자들에게 그들의 국가가 핵무기를 개발하고 있다는 증거를 제시했을 때에도 부시 행정부는 북한 정권이 그에 대해 거짓말을 할 것으로 예상했었다.\n',
#  '하루가 지난 후 소름끼치는 일이 발생했다.\n',
#  '라고 "경애하는 지도자" 김정일의 수석 보좌관은 놀란 제임스 켈리 미국 특사에게 말했다.\n',
#  '그리고 그는 덧붙여, "우리는 더욱 강력한 무기도 갖고 있소.\n',
#  '"라고 말했는데, 이는 아마도 생화학 무기를 의미하는 것 같다.\n',
#  '그는 전혀 사과하는 기색이 없고, 오히려 "그 문제에 대해 단호하고 공격적이었다."\n',
#  '북한과 같이 통제가 심한 국가들은 전형적으로 그러한 민감한 질문은 의식적으로 피한다.\n',
#  '그래서 그러한 시인은 부시의 "악의 축"의 일원으로 포함되어 있는 북한이 1994년의 (핵개발) 금지 협약에도 불구하고 대량 살상 무기를 얻으려고 노력해왔다고 미국 측이 오래 동안 품어 왔던 의심을 단순히 확인시켜주는 것 이상의 의미를 갖고 있다.\n',
#  '모든 사람들은 궁금해 했다. 왜 김정일이 지금 자백했는가?\n',
#  '그리고 부시는 왜 이미 두 곳에서 대규모의 세계적 대치 상황에 몰두해 있는 때에 그 문제를 압박해들어갔는가?\n',
#  '부시 행정부가 그 위기를 축소시킬 수 있는 방법을 찾아내느라 애썼던 12일 동안에 부시 행정부가 뉴스거리가 되었다는 것은 놀랄 일이 아니다.\n',
#  '부시 행정부가 지난 주 그 뉴스를 공개했을 때, 부시 행정부는 또한 이 교착 상태가 적어도 현재로서는 군사적인 힘이 아니라 외교적으로 처리되도록 힘쓸 것이라는 점을 시민들과 동맹국들에게 재확인시켜주느라 애쓰고 있었다.\n',
#  '그러면 누가 북한을 지원했는가?\n',
#  '파키스탄은 핵폭탄을 갖고 있었지만 그것을 장착할 미사일이 없었고, 북한은 세계 에서 가장 적극적인 미사일 수출국으로서, 특히 다른 곳에서 구매할 수 없는 고객들에게는 그러했다.\n',
#  '1998년에 파키스탄은 자국산 중거리 탄도 미사일 Ghauri를 시험했는데, 미국은 이것이 북한에서 온 것으로 믿고 있다.\n',
#  '북한과의 전쟁은 생각할 수 없는 것이라고 부시는 보좌관들에게 말했다.\n',
#  '부시는 한반도에서의 깨지기 쉬운 힘의 균형을 김정일이 변화시키도록 하지는 않을 것이다. 한반도에는 전격적인 대공세로 남한의 수도인 서울을 파괴할 수 있을 정도로 가까운 거리에 있는 호전적인 군대와 DMZ를 사이에 두고 미군 3만7,000명이 주둔해 있다.\n',
#  '부시의 선제 공격 주의에 의한다면, 미국은 대량 살상 무기와 무책임한 독재자가 있는 어떤 국가애 대해서도 공격을 해야만 한다.\n',
#  '그러나 북한에 대한 공격의 결과는 받아들일 수 없는 것이다.\n',
#  '부시가 분명 예측하지 못했던 것은 (북한이 핵무기 개발 계획을 갖고 있다는) 그 증거가 옳았다는 뻔뻔스러운 (북한의) 시인이었다.\n',
#  '미국과 영국의 과학자들이 악수를 했다.\n',
#  '전혀 대단한 일이 아니라고 생각할지 모르지만, 당사자들은 3,000마일이나 떨어져 있었고, 인터넷에 의해서만 연결되어 있었다.\n',
#  '한 명은 런던에 있고, 다른 한 명은 보스톤에 있는\n',
#  '두 명의 과학자들이 그들 사이에 있는 컴퓨터가 생성한 큐브를 집어 들고 그 큐브를 움직여 각자는 상대가 그 큐브에 가한 힘에 반응하는 것이었다.\n',
#  '"우리는 우리의 손으로 밀려오는 대상체를 실제로 느낄 수 있습니다.\n',
#  '이 기술의 이면에 숨은 비밀은 연속적인 충격들이 전송되는 속도라고 런던 대학 측이 말했다.\n',
#  '과학자들은 대서양 건너에 있는 동료들이 가하는 힘을 느낄 수 있을 뿐 아니라, 그들이 느끼고 있는 대상체의 질감도 느낄 수 있다.\n',
#  '이번 일을 "인터넷을 통한 세계 최초의 대서양 횡단 악수"라고 묘사한 런던 대학 측은 이 실험의 의미가 대단히 클 수도 있다고 말했다.\n',
#  '예를들어, 수련의들이 인터넷을 통해 수술 실습을 하기 위해 이것을 이용할 수 있을 것이다.\n',
#  '이것은 또한 사람들이 인터넷을 통해 서로를 만지고 느낄 수 있도록 해주는 오락적인 용도도 갖게 될 것이다.\n',
#  '동안은 이것이 일반인들에게 이용가능해지게 될 것이라고 생각하지 않습니다."\n',
#  '라고 조던이 말했다.\n',
#  '그것은 일본이 미국으로부터 수입한 490억달러와 유럽 연합으로부터 수입한 366억달러보다 더 많은 것이다.\n',
#  '신용 카드 빚을 현금으로 갚아야 합니까?\n',
#  '음악 교습비가 꼭 있어야합니까?\n',
#  '단지 일하는 데 지쳤거나, 깡통을 들고 거리에서 구걸하기가 너무 난처합니까?\n',
#  '카린 보스낙의 웹사이트에 의하면, 인터넷 상에서 모르는 사람들이 그녀의 사정을 듣고 1만 3,000달러 이상을 기부해준 후에, 카린 보스낙은 뉴욕 생활로 인해 쌓였던 신용 카드 빚 2만달러를 지난 달 에 모두 갚았다고 한다. 야후는 1996년에 4개의 사이트로 "구걸" 부문을 개설했다.\n',
#  '그러나 이런 사이트들의 활동량과 다양성이 최근에 급증하면서 야후는 이 부문의 명칭을 e-구걸로 바꾸게 되었다.\n',
#  '미국은 북한을 공격할 의도가 없다고 말하고 있지만, 북한이 먼저 핵 무기 개발 계획을 중지하는 구체적인 조치를 취해야 한다고 말하면서 북한 측의 불가침 조약에 관한 협상 요청을 거절했다.\n',
#  '"불가침 조약의 문제는 우리가 그들의 잘못된 행동에 대한 대가로 무엇인가를 지금 당장 주어야 한다는 것을 암시합니다. "라고 콜린 파월 국무장관이 말했다.\n',
#  '"북한의 행동에 대해 북한에 보상을 해주는 일은 우리가 할 수도 없고, 하지도 않을 것입니다."\n',
#  '인도 북동부의 아셈州에서, 시골에서 빚은 술을 먹고 광포해진 야생 코끼리 떼가 난동을 부리던 중에 6명을 짓밟아 죽였는데, 사망자 중 4명이 어린이였다.\n',
#  '이 동물들은 숲에서 나와, 곡물 창고를 덮치고, 틴수키아의 마을 주민들이 저장해둔 시골에서 빚은 술을 마셨다.\n',
#  '엄청난 양의 시골에서 빚은 술을 마셔버린 코끼리들은 광포해져 현장에서 6명을 죽이고 말았다.\n',
#  '부시 대통령은 탄도 미사일 공격으로부터 미국을 보호하기 위해 고안된 제한적인 (미사일 방어) 시스템의 1단계를 2년 이내에 배치한다는 계획을 발표했다.\n',
#  '어휘 :\n',
#  'Army 미국 육군\xa0 / shoot down 을 쏘아 떨어뜨리다\xa0 / artillery 대포\xa0 / shell 포탄\xa0 / in mid-flight 비행 중인\xa0 / defense industry 국방 산업\xa0 / breakthrough (발명에 의한) 비약적 전진, 그 발명\xa0 / manufacturer 제조업체 번역 :\n',
#  '뉴 멕시코州의 화이트 샌즈 발사 시험장 상공에서 빠르게 날아가는 포탄을 레이저가 추적하여, 포착한 후 집적된 빛에너지 광자를 집중 발사했다고 육군과 이 무기를 개발한 TRW社가 공동으로 발표했다.\n',
#  '이 이동용 전술 고에너지 레이저(MTHEL)는 美 육군과 이스라엘 국방부를 위해 TRW社에 의해 개발되고 있는 중이다.\n',
#  '이 발사 시험장에서 실시된 이전의 시험에서는, 인접한 레바논의 과격 게릴라 단체들에 의해 이스라엘에 발사되었던 로켓들과 유사한 보다 속도가 느린 카츄사 로켓를 쏘아 떨어뜨리기 위해 레이저가 사용되어 왔었다.\n',
#  '"이번 격추는 방어력의 패러다임을 변화시키는 것입니다.\n',
#  '초음속으로 공중을 날아가는 포탄 발사체라도 레이저에는 못 당한다는 것을 우리가 보여주었습니다."\n',
#  '라고 미사일 방어 사령부 사령관인 조셉 코스마노 육군 중장이 말했다.\n',
#  '"전술 고에너지 레이저는 전투 상황을 변화시킬 수 있습니다." 라고 그가 덧붙여 말했다.\n',
#  '조심스럽게 통제된 시험에서 이 레이저는 고정된 시험대에서 발사되었지만, TRW 직원들은 이 프로그램이 진전되면서 진정한 이동형 레이저 발사기종을 생산할 것으로 기대한다고 말했다.\n',
#  '2000년과 2001년에 실시된 이전 시험에서는 시험대가 로켓 포탄의 위협에 초점을 맞추었고, 단발로 또는 일시에 발사되는 25기의 카츄사 로켓들을 쏘아 떨어뜨렸다.\n',
#  '미군은 발사체 무기들을 사용하여 대기권 내에서와 대기권 밖에서 실시한 시험에서 모형 대륙간 미사일 탄두를 쏘아 떨어뜨렸으며, 또한 비행 중인 그러한 탄두를 폭파시키기 위해 장거리 레이저 사용이 가능한지를 시험하고 있다.\n',
#  '다우 존스 산업 평균지수가 거의 1% 하락했다. 나스닥 종합 지수와 S&P 500 지수는 다소 완만한 하락을 기록했다. 한스 블릭스 유엔 선임 무기 사찰관이 이라크의 무기 프로그램에 대한 총괄 보고서에 만족하지 않는다고 말한 이후에 우량주에 대한 하락이 더욱 커졌다.\n',
#  '하다 \xa0 dossier (어떤 문제에 관한) 일체의 서류 북한의 핵시설 재가동에 대한 국제사회의 우려\n',
#  '북한은 국제 사찰관들이 가동을 중지시킨 원자로에 설치한 봉인들을 대부분 절단했으며, 원자로의 감시 장비를 폐쇄했다고 북한측이 확인했다.\n',
#  '유엔은 영변 원자로가 (핵)무기 제조에 쓰이는 플루토늄을 생산할 수 있다고 믿고 있다.\n',
#  '미국의 인권 단체가 자치 지역을 방문한 후 불과 몇 일만에 심양의 고위 중국 관리가 분리주의자들과 테러리스트들을 엄중 처벌할 것임을 분명히 했다.\n',
#  'J. 프레드릭 모쯔 미국 지방 법원 판사는 선 마이크로시스템즈의 요청에따라 마이크로 소프트에게 자바를 탑재하도록 하는 가처분 명령을 내렸다.\n',
#  '일본에서 124명의 사망자를 낸 폐암 치료제\n',
#  '암 치료제인 제피티니브의 부작용으로 일본에서 124명이 사망했다.\n',
#  '사망자들은 그 약으로 인한 간질성 폐렴을 포함해 신체를 쇠약하게 하는 폐 질환에 걸린 494명의 환자들 중에서 발생했다.\n',
#  '이 사망자 수는 이 약의 제조 회사인 영국계 스웨덴 제약 대기업 아스트라제네카가 10월에 인정한 사망자 39명보다 증가한 것이다.\n',
#  '제피티니브는 7월에 일본에서 사용이 허가된 이후로 최소한 1만명의 암 환자들에 의해 복용되어 왔다.\n',
#  '미국의 빌 클린턴 대통령은 미국의 골치 아픈 대도시 빈민가를 재건하기 위한 "권한 부여 지대"라고 하는 35억 달러 규모의 5개년 계획을 발표했다.\n',
#  '여러해 전에 폭동으로 황폐화한 LA 중남부와 같은 도시 빈곤 지역이 정부 지원과 기업의 투자 대상이 될 것이다.\n',
#  '다른 95개 도시 및 농촌 지역에는 보다 적은 금액이 주어질 것이다.\n',
#  '이 계획은 1960년대의 소위 위대한 사회의 빈곤 퇴치 계획에 필적하는 것이기는 하지만, 다른 계획들이 실패한 곳에서 이 계획이 성공을 거둘 수 있을 것인가?\n',
#  '백악관에서 있은 식전에서의 논평에서 도시를 구하기 위한 또 다른 값비싼 연방 계획의 실현 가능성에 대해 널리 퍼져있는 회의론에 대해 대통령은 언급을 회피했다.\n',
#  '1949년에, 당시 대통령인 해리 트루만은 도시 부흥 계획을 주도했다.\n',
#  '그 뒤를 이은 정부들도 "지역사회법", "표본 도시", "지역사회 개발구획 보조금", 그리고 "도시개발법 보조금"과 같은 이름의 계획들에 수십억 달러를 소비했다.\n',
#  '하지만, 오늘날 대부분의 도시 빈곤지역은 본질적으로, 그리고 놀라울 정도로 변화되지 않은 상태로 남아 있으며, 어떤 경우에는 더욱 악화되어 있다.\n',
#  '워싱턴 DC에 있는 도시문제 연구소의 도시정책 분석가인 죠지 피터슨은 범죄, 가난, 그리고 나태함으로 둘러 싸인 전형적인 도시 빈곤지역의 풍경을 묘사하고 있다.\n',
#  '"그 지역의 2/3가 비어 있습니다.\n',
#  '인구의 대부분은 집에서 살고 있지 않은 거리의 주민들입니다.\n',
#  '그리고 사람들은 사람에 대한 아주 심한 두려움을 갖고 있는데, 이것은 자신들이 단순히 외부인이기 때문이 아니라, 그곳에 사는 사람들이 그들의 생활 속에서 느끼는 두려움을 갖고 있다는 것 때문입니다."\n',
#  '그것은, 이러한 물리적 황량함에 의해 더욱 심해진, 지역사회의 한 부분이 될 수 없다는 좌절감입니다. 그것은, 일단 사람들이 이런 지역에 들어오게 되면, 결코 잊지 못하는 그런 것입니다."\n',
#  '어휘 : examine 면밀히 조사하다\xa0\xa0 plight 상태, 양상\xa0\xa0 revive 회복시키다\n',
#  '최근 워싱턴에서 한 겨울 에 열렸던 미국 시장 회의를 겨냥하여, 미 상원의원인 폴 사빈즈는 최근 뉴욕 타임즈 잡지의 "빈민가 재건은 성공하지 못한다.\n',
#  '"그들의 정책 처방은 간단합니다.\n',
#  '성공할 수 있는 일들이 있습니다."\n',
#  '하지만 전체적으로는 증거가 다르게 나타나고 있다.\n',
#  '"우리가 알고 있는 바와 같은 그런 문명이 우리 주위에서 붕괴하기 시작했으며, 점증하는 폭력이 주요한 원인입니다.\n',
#  '그리고 30년이 넘는 나의 수사 경험과 지난 2년간의 샌프란시스코 시장으로서의 경험으로 보건데, 이에 대해서는 의심의 여지가 없습니다."\n',
#  '매트 로드리게가 경찰 서장으로 있는 시카고와 같은 미국의 도시들에 있어서 폭력 범죄는 제 1의 문제이다.\n',
#  '"지난해 시카고에서는 자살이 9% 감소했으나, 11살에서 20살 나이의 젊은이들의 살인은 기록적인 수준으로 높아졌습니다.\n',
#  '현재 시카고에서는 10명의 살인 중 3명이 이 나이 또래의 희생자들입니다.\n',
#  '그리고 92%, 그들 중 92%가 소형 무기에 의해 살해되고 있습니다.\n',
#  '전국적으로 18세 미만의 아이들이 오늘날 총기에 의해 사망할 가능성은 1996년보다 244%가 높습니다."\n',
#  '보스톤 시립병원의 존 리치 박사는 응급실에서 많은 범죄 희생자들을 보고 있다.\n',
#  '"하루 저녁에 3, 4명의 사람들이 들어오게 되는데, 그들은 다른 많은 건강상의 문제를 갖고 있는 사람들과 총에 맞거나, 칼에 찔린 사람들입니다.\n',
#  '내 말은, 많은 경우에 있어서, 특히 사람들이 외과 치료실로 실려 오거나, 수술실로 황급히 옮겨지는 많은 경우에, 그들의 부상이 치료되고, 심한 중상을 입은 많은 경우에는 입원이 되고, 때로는 상당 기간 동안 생명유지 장치를 필요로 하게 된다는 뜻입니다."\n',
#  '루이빌 시장인 제리 에이브람슨은 집없는 노숙자의 수가 전국적으로 60만에서 7백만에 이를 것이라고 추정하고 있다.\n',
#  '미국 시장 회의의 기아와 노숙자에 대한 특별 위원회 위원장인 세인트 루이스 시장 프리만 바슬리 2세는 많은 노숙자들의 놀라운 면모를 밝히고 있다.\n',
#  '"노숙자들 중 50%가 넘는 사람들이 고용 상태에 있습니다.\n',
#  '그들은 일을 하고 있는 겁니다. 그들이 받는 임금이나 급여는 아주, 아주 적은 것이어서 기본적인 임대료나 집을 구할 여유가 없는 것입니다.\n',
#  '집없이 떠도는 누군가를 생각할 때면, 많은 경우에 사람들은 공원 벤치에서 잠을 자는 남자나, 가방을 들고 거리를 배회하는 여자를 생각하게 됩니다.\n',
#  '노숙자들의 43%는 적어도 두 명의 아이를 갖고 있는 여자들입니다.\n',
#  '결국 그들은 우리가 보지 못하는 눈에 뜨이지 않는 노숙자들인 것입니다. 그리고 그것이야 말로 우리가 정말로 관심을 집중시켜야 하는 것 중의 하나인 것입니다."\n',
#  'sell the customer a collision damage insurance에서\xa0the customer는 간접목적어, a collision damage insurance는\xa0직접목적어이다.\n',
#  '하지만 자동차를 빌리는 많은 사람들은 이미 보호를 받고 있다.\n',
#  '다른 사람들도 그들이 주요 신용카드를 사용하기 때문에\xa0보호를 받고 있다.\n',
#  '그들은 흔히 수수료를 받고 그것이 무엇이든 간에 보험을\xa0팔려고 하는 적극적인 임대 자동차 판매 직원의\xa0매혹적인 표적이 된다.\n',
#  '현재분사 getting은 보어로서, Most car rental companies\xa0are getting 이 된다.\n',
#  'it는 the national ban on the sale of collision damage\xa0insurance를 받는다. are not 다음에는 for it이 생략되었다.\n',
#  '규모가 큰 자동차 임대회사들은 그것에 대해 찬성을 하고 있다.\n',
#  '규모가 작은 여러 회사들은 그렇지가 않다.\n',
#  '우주 비행사들의 증언이나 사진 상의 증거도 역시 충분하지 않았다.\n',
#  '그래서 NASA는 정말로 미국인들이 달에 발을 디뎠다는 것을 보여주는 소책자의 저술을 위임했다.\n',
#  '1969년 7월 20일에 아폴로 11호를 타고 미국인 우주 비행사들이 처음으로 달에 도달했다는 것을 지구 상에 있는 대부분의 사람들은 인정한다.\n',
#  '그러나 그것을 믿지 않는 사람들은 어설픈 의문점들을 제기하기 시작했으며, 그것이 바로 NASA가 대응하려고 하는 것이다.\n',
#  '美 항공우주국은 수십년 동안 크게 드러내지 않고 그런 논쟁을 다루어왔지만, 2001년에 폭스 텔레비전 네트워크가 "음모론:\n',
#  '우리가 달에 착륙했는가?"\n',
#  '아폴로 달 착륙을 의심하는 사람들은 미국은 인간을 달로 보내는 기술이 부족했으며, 필사적으로 소련과의 우주 경쟁에서 이긴 것처럼 보이고 싶어했으므로 영화 세트장에서 달 비행 임무를 꾸며낸 것이라고 주장했다.\n',
#  '그러한 조작은 너무도 어설프게 꾸며졌기 때문에, 미국 국기가 바람에 펄럭이는 것이 나타나있다고 전해지고 있는 미국 국기를 꽂는 우주 비행사들의 사진을 포함해서, 그러한 사기극을 보여주는 충분한 증거가 있다고 달착륙을 의심하는 사람들은 말했다.\n',
#  '달에는 미풍 조차도 없기 때문에 그 사진은 날조된 것이 틀림 없다고 달착륙을 의심하는 사람들은 주장했다.\n',
#  '그러나 우주 비행사들이 달 표면에 미국 국기를 꽂으려고 애쓰면서, 깃발이 고정되기 전에 그들이 깃발을 조금 비틀어 돌리게 되었으며, 그래서 자연적으로 깃발이 펄럭이게 된 것이었다.\n',
#  '그러나 달에서는 그 펄럭임이 (아무런 공기의 저항도 받지 않아) 지속되면서 마치 그것이 바람 에 휘날리는 것처럼 보이게 만들었다.\n',
#  '이 사이트의 개설자인 천문학자 필 플레이트는 자신이 음모 이론가들이라고 부르는 이 달착륙을 의심하는 사람들을 퉁명스럽게 비난하였다.\n',
#  '"NASA의 아폴로 우주선 달 비행 임무가 날조되었다고 생각하는 사람들은 정신이 나간 사람들입니다.\n',
#  '이것에 관해 많은 소문들이 퍼져 있으며, 나머지 사람들은 그 소문들이 모두 완전히 거짓이라고 확신했습니다.\n',
#  'save의 주체는 a Japanese business이고,\xa0목적어 it는 Locky Company를 받는다.\n',
#  '1995년에 일본의 닛본 철강과의 합작 투자로 인런드는\xa0생존하게 되었고, 보다 품질좋은 철강을 생산하게 되었다.\n',
#  'IBM빌딩에서부터 록펠러 센터에 이르기까지 외국\xa0투자가들은 미국 자산을 앞다투어 손에 넣고 있다.\n',
#  'the company having been sold to British interest는 이유를\xa0나타내는 완료 시제의 분사구문이다.\n',
#  '(날씨가 좋았기 때문에 그들은 하이킹을 갔다.) = As it was fine, they went hiking.\n',
#  '외국인들은 이제 미국 제조업의 10%와 미국 은행업의 20%를\xa0장악하고 있다.\n',
#  '그러나 공장, 부동산, 주식과 채권, 그리고 외국 소유\xa0은행의 미국 지사에서의 국제적인 점유가 늘어감에따라\xa0많은 기업들과 통상 전문가들은 어려움을 겪고 있다.\n',
#  '이 문장의 주어는 the issue이고, 동사는 is이다. of whether  helpful은 주어인 the issue를 수식하는\xa0수식어구이다.\n',
#  '미국 내에서의 외국인 투자가 해로운지 도움이\xa0되는지에 대한 문제는 아직 해결되지 않고 있다.\n',
#  '(그 기계에는 무엇인가 잘못된 것이 있다.)\n',
#  '(우리는 더 좋은 것을 생각할 수 없다.)\n',
#  '인디언들이 칼, 값싼 장신구, 그리고 옷 몇 점에 맨하탄을\xa0네델란드인에게 매도한 이래로\xa0그것은 계속되어 오고 있는 것이다.\n',
#  '하지만 두 명의 과학자는 그 작은 알약이 수만마리의 동물을 구할 수 있을 것이라고 밝히고 있다.\n',
#  '전통 중국 의약에서는 발기 기능 장애와 같은 일반적인 신체적 질환을 치료하기 위해 종종 어떤 동물들의 특정한 신체 부위에 의존하고 있다.\n',
#  '세계 야생 생물 기금(WWF)의 얀 베르티퓨일 대표는 서구의 다른 인기 있는 약들이 중국 전통 의약에 영향을 미치지는 않았다고 말했다.\n',
#  '아시아에서는 비아그라와 같은 많은 서구의 치료제들에 대한 의구심이 폭넓게 존재하고 있다고 세계 야생 생물 기금(WWF)의 중국 의학 전문가인 카오 단은 말했다.\n',
#  '"이렇게 서양 의약에 대해 강하게 망설이는 이유 중 하나는 부작용에 대한 우려입니다." 라고 그녀가 말했다.\n',
#  '예를들어, 비아그라는 많은 복용자들에게 심장 질환을 야기시켰다.\n',
#  '발기 부전이 전통 중국 의약에서 주된 문제로 취급되는 것은 아니지만, 사람들이 치료법을 얻기 위해서 기꺼이 지불하려는 가격은 상당한 것이다.\n',
#  '그래서 비아그라는 가격이 저렴하고 입수가 용이하기 때문에 매력적인 대안이다.\n',
#  '몇몇 캐나다 동물 생식기의 거래가 줄어든 것은 좀 더 설득력있게 설명될 수도 있다고 일부 자연 보호 운동가들은 생각한다.\n',
#  '생식기가 아닌 다른 장기들 때문에 물개들이 포획될 수도 있다고 그들은 말한다.\n',
#  '더구나 캐나다의 동물 생식기 수출 감소는 많은 아시아 지역에서의 경제 침체와 시기가 일치하였다.\n',
#  '40년 동안 과학자들은 컴퓨터 연구의 두 첨단 분야에서\xa0진전을 이루기 위해 열심히 노력해 왔다.\n',
#  '수퍼컴퓨터로 알려진 빛처럼 빠른 기계로 일하고 있는 한 그룹은\xa0언제나 보다 더 번쩍이는 속도를 위해 힘쓰고 있다.\n',
#  '인공 지능의 초기 단계를 보여 주는 프로그램을 짜고 있는\xa0다른 그룹은 인간 사고력의 신비를 탐구한다.\n',
#  '컴퓨터 연구의 이 두 분야는 그 생명 주기에 있어 다른 단계에 있다.\n',
#  '인공 지능은 이제 막 시작되었다:\n',
#  '수퍼컴퓨터 조직망의 보급으로 개인 컴퓨터와 전화를 갖고 있는\xa0사람은 누구나 고속의 계산 능력을 이용할 수 있다.\n',
#  '이 목표는 인공 지능을 대신하는 말로 AI라고 불린다. 그리고\xa0그것은 수십년 동안 컴퓨터 프로그래머들에게서 벗어나 있었다.\n',
#  '한국이 세계 에서 가장 부유한 국가들 중에서 가장 효과적인 교육 제도를 갖고 있으며, 일본이 2위이고, 미국과 독일은 거의 밑바닥 수준이다.\n',
#  '이 연구는 14-15세 어린이들의 읽기, 수학, 그리고 과학 능력을 측정하기 위해 실시한 5가지의 서로 다른 시험에 기초한 것이라고 유니세프가 밝혔다.\n',
#  '이번 연구에 있어서 새로운 것은 이 연구는 현재까지 개별 국가들의 교육 제도가 전체적으로 얼마나 잘 기능하고 있는가를 가장 포괄적으로 나타내 보여주기 위해 그 결과로 나타난 점수들을 평균했다는 것이다.\n',
#  '"잘잘못이 오로지 그 나라의 학교에만 있는 것은 아니다.\n',
#  '교육적인 잘못은 학교에서가 아니라 가정에서 발생하는 것이 분명하다."\n',
#  '이번 연구는 교육에 얼마나 많은 비용이 소비되었는가와 같은 요소들의 범위에 관한 결론을 이끌어내지 못했다고 패트릭 맥코믹 유니세프 대변인이 말했다.\n',
#  '이번 연구는 또한 한국이나 일본에서 나타난 결과에서 극심한 경쟁이 한 요인이 되었는지에 관해서도 조사하지 못했다.\n',
#  '"교육과 지식에 대한 강열한 전통을 갖고 있는 독일은 24개국 중에서 18위의 미국 바로 뒤를 이어 19위를 차지하고 있다.\n',
#  '그러나 미국은 개개의 시험과 성인의 식자율(識字率)에서 하위에 머물렀다.\n',
#  '이번 연구는 왜 미국의 성적이 좋지 않았는가를 설명하려고 시도하지는 않았다고 맥코믹이 말했다.\n',
#  '"많은 이민 인구가 있고, 많은 유동 인구가 있고, 빈곤의 격차가 크고, 경제적으로 아주 다양한 국가들은 아마도 교육 자체에 있어서는 이런 종류의 결과를 나타내게 될 것입니다."\n',
#  '부랑자 대책을 위해 정부 보조금 중에서 15억 달러 이상이 시에 지급될 것이다.\n',
#  '충분한 자금 지원을 받는 또 다른 연방정부 도시개발 계획으로 1993년의 국가 봉사법이 있다.\n',
#  '이 8억달러 규모의 정부주도 계획은 2만 명이 넘는 젊은이들에게 최저 임금과, 그리고 전국의 시립 학교나, 병원, 경찰서 등에서 1년 동안 봉사한다는 조건으로 5천 달러의 대학 수업료도 제공하고 있다.\n',
#  '몇몇 시장들이 "아메리코어"라는 새로운 단체에 대해 의구심을 갖고 있다는 것을 국가봉사 프로그램 국장인 엘리 시걸도 인정하고 있다.\n',
#  '"오늘 여러분들과 함께하고 있는 텍사스의 시장들에게 물어 보았습니까?\n',
#  '텍사스 시장들은 알고 있습니다, 왜냐하면 그들은 지난 여름 에 87개의 아메리코어가 텍사스 주를 휩쓸고 지나갔으며, 그 8주간의 과정 동안에 10만4천명이 넘는 아이들에게 그 프로그램이 적용되었다는 것을 보고 들었기 때문입니다."\n',
#  '그리고 저는 여러분들이 2천년 전 아테네의 멸망을 묘사했던 에드워드 기븐의 말을 기억해 주었으면 합니다. 그는 이렇게 썼습니다.\n',
#  "'마침내 아테네 인들이 사회에 베풀려하지 않자. 사회도 그들에게 베풀지 않았습니다.\n",
#  "그들이 가장 원했던 자유가 책임을 지지 않는 자유였을 때, 아테네는 더 이상 자유롭지 않았습니다 '\n",
#  '동료 여러분, 그러한 일이 이곳에서 일어나지는 않을 것입니다.\n',
#  '"단 한 가지가 있다면, 없을 수도 있지만, 그러나 만약 단 하나의 가장 중요한 논쟁거리가 있다면 그것은 직업 훈련이라고 생각합니다.\n',
#  '누군가에게 일자리를 갖고 있도록 하고, 그런 일자리, 의미있는 일자리, 햄버거나 집어던지는 그런 일자리가 아니라, 의미있는 일자리를 얻을 수 있도록 훈련시키는, 그래서 그들이 가족을 부양하고 , 우리가 정상적으로 이야기하는 그런 것들을 달성할 수 있는 자격을 갖추게 하는 능력 말입니다."\n',
#  '그래서 지난 달 행정부는 95군데의 도시 및 농촌 사업지역 뿐 아니라 6개의 대도시와 한 군데의 중도시에 "권한 부여 지역"이라고 알려진 것을 시행할 계획을 밝혔다.\n',
#  '35억 달러의 종합 보조금과 세금 혜택으로 기업들이 경기 침체 지역으로 이동하여 일자리를 마련하게 하고, 지역 경제를 활성화시키도록 유인하고 있다.\n',
#  '그런데 그것은, 뉴욕 타임즈 잡지 기고가이며, "빈민가 재개발 계획은 성공하지 못한다. "라는 제목의 최근 기사의 저자인, 니콜라스 리만에따르면 잘못된 접근 방법이다.\n',
#  '1949년 해리 트루만 대통령의 도시부흥 계획 이후로 모든 여타 도시재건 계획의 대상 지역들이란 새로 고용된 빈곤층들이 빈민가에 그대로 남아서 사는 쪽을 선택할 것이라는 전제를 기초로 하고 있다고 리만 씨는 주장한다.\n',
#  '리만 씨는 사실 많은 사람들이 실제로는 이주해 나갔다고 언급한다.\n',
#  '같은 행태가 수십년에 걸쳐 수백만 번이나 반복되어 오고 있다고 그는 말한다.\n',
#  '보수적인 해리티지 재단의 국내정책 분석가인 로버트 렉터는, 그의 견해로는, 정부가 잘못된 노력으로 수십억 달러의 낭비를 계속하고 있다고 주장한다.\n',
#  '"만약 연방정부의 추가적인 재원으로 미국 도시문제를 해결했을 거라면 우리는 이미 오래, 오래전에 그 문제들을 치유했을거란 것이 현실입니다.\n',
#  '1965년으로 거슬러 올라가 린든 존슨 대통령이 주로 도시 문제에 대한 전쟁이었던, 가난에 대한 전쟁을 시작한 이후로 미국은 복지를 위해 5조 달러를 써왔는데, 그 돈의 상당액은 미국의 도시 빈곤 지역에 투입되었습니다.\n',
#  '렉터 씨는, 자신이 아는 바와 같이, 복지정책에 대한 의존은 많은 가난한 사람들을 비참한 상태에 남아 있도록 한다고 덧붙인다.\n',
#  '"오늘날 도시 빈곤지역의 실업 문제 중의 하나는 도시 빈곤 지역의 실업계층들이 기본적으로 역사적인 이동성을 상실했다는 것입니다.\n',
#  '어떤 지역에 일자리가 고갈되면 관습적으로 미국인들은 일자리가 있는 다른 지역으로 이동을 합니다. 그런데 몇몇 도시 빈곤지역의 문제점들 중의 하나는 그 지역에 일자리가 고갈되어도 사람들이 이동을 하지 않는다는 것이며, 심지어 흑인들 사이에서도 그렇다는 점을 대부분의 연구 결과가 나타내 주고 있습니다.\n',
#  '"흑인들은 우리사회에서 역사적으로 아주 이동적인 인구입니다.\n',
#  '많은 경우에 있어서, 흑인들은 그들이 현재 살고 있는 도시 빈곤지역으로 한 30년 전 쯤에 이주해 왔습니다.\n',
#  '의문점은 어째서 그 지역에 일자리가 고갈되어도 그들이 보다 돈벌이가 잘 되는 지역으로 이동해 가지 않느냐하는 것이며, 그 이유는 우리의 주택 보조금 제도와 모든 다양한 복지 프로그램 등 복지 제도가 그들에게 과도하게 보조금을 지급하여 그들이 그곳에 그대로 남아있게 만들고, 그들이 실직 상태에 남아 있도록 만든다는 것입니다."\n',
#  '미국의 도시 빈곤 지역들이 직면하고 있는 주된 문제는 정부 재원이나 지원의 부족이 아니라 가족의 분열과 도덕적 가치관의 붕괴라고 로버트 렉터는 결론을 내린다.\n',
#  '하지만 위싱턴 DC에 있는 한 두뇌집단인 도시 연구소의 도시 분석가인 죠지 피터슨은 사람들을 설득하는 것이 반드시 성과를 얻게 되는 것은 아니라고 말한다.\n',
#  '그러나 단순히 권유만으로 성공적인 결과를 얻었다는 어떠한 증거도 우리는 갖고 있질 않습니다.\n',
#  '아주 많은 지역사회의 조직이나, 단체들을 세워 도시 근교를 아이들이 살기 재미있는 지역으로 만드는 것과 똑같은 그런 활동을 하도록 장려하는 것이 올바른 방법이라는 정치적 여론이 부상하고 있다고 생각합니다.\n',
#  '예를들어, 보이 스카웃과 걸 스카웃 , 그리고 교회 활동과 방과 후 활동 면에서, 대부분의 빈곤 지역에서는 그런 종류의 지원 조직이 부족하다는 겁니다."\n',
#  '샌프란시스코에서 프랭크 조단 시장은 유대가 긴밀한 지역사회의 중요성에 대해 자기 개인적인 이야기를 하고 있다.\n',
#  '그가 열 살 때 그의 어머니가 돌아가셨기 때문에 그의 아버지는 요즈음 말하는 외쪽 부모가 되었다.\n',
#  '"그 당시에 우리는 우리를 양육해 주는 가족이 없었습니다.\n',
#  '이웃들이 달려 들었고, 그들이 한동안 우리를 도왔죠.\n',
#  '나는 심지어 내 국민학교 급우와 함께 살았습니다.\n',
#  '그의 부모들이 우리 상황을 알고 있었고, 그들은 아주 가까운 이웃에 있었기 때문에 나를 받아들였던 거예요.\n',
#  '교회도 또한 도와 주었습니다.\n',
#  '그들은 하나의 지역사회로서 자발적으로 관여하게 되는 방법을 찾기 시작했습니다.\n',
#  '그렇게 해서 나에게 아주, 아주 도움이 되었던 확대된 가족과 양육 기반을 갖게 되었던 겁니다."\n',
#  '친구와 이웃들이 도움이 필요한 가족을 보았고, 그것이 옳은 일이었기 때문에 그들은 도움을 주었으며, 그로인해 그가 곤경에서 벗어나게 되었다고 프랭크 조단은 말한다.\n',
#  '사람들이 가족처럼 서로를 도우려고 돌아설 때, 미국의 고통받는 도시 빈곤지역들은 부흥하게 될 것이라고 그는 말한다.\n',
#  '본 프로 해설자인 죤 액티브는 알라스카의 베텔 지역에서 오랜 옛날로 거슬러 올라가 자신의 뿌리를 알아 봅니다.\n',
#  '그는 자신이 누구인지 알고 있다고 생각했었습니다.\n',
#  '지금 까지 내내 나는 내가 순수한 혈통의 유픽 에스키모라고 생각했습니다. 그런데 이제 내가 그렇지 않다는 말을 들은 것입니다.\n',
#  '40년이 넘는 세월 동안 나는 유픽족(族)이라는 것을 자랑스러워 했고, 유픽족임에 만족해 왔습니다.\n',
#  '나는 썩은 물고기 머리를 먹는 잔치를 즐겼으며, 모피로 된 의상을 즐겨 입었고, 심지어 수퍼마켓에서 신선한 얼음을 사는 일에도 전문가가 되었었습니다.\n',
#  '내 남은 인생을 어설픈 알라스카인으로 살아가고 싶지 않았습니다.\n',
#  '나는 알라스카의 수도인 주노에 전화를 걸어 알라스카 원주민 권리조종법에 따른 원주민 등록 업무 담당자와 통화를 했습니다.\n',
#  '그 법은 30년 이전에 알라스카 원주민들로부터 부당하게 착취된 토지에 대한 보상을 위한 것이었습니다.\n',
#  '수백만 달러, 수백만 에이커에 이르는 토지에 대한 댓가가 지불되었습니다.\n',
#  '그 때에, 원주민들이 보상을 받도록 하기 위하여, 자격을 입증하기 위한 등록이 이루어 졌습니다.\n',
#  '그리고 총계 조사를 신속하게 하기 위하여 사람들이 고용되었는데, 대부분은 우리에 대해 아는 것이 거의 없는 비알라스카인들이었습니다.\n',
#  '따라서 나는 그들이 우리의 혈통량 등급을 추정했을 것이라 생각합니다.\n',
#  '그 등록 담당자는 내가 내 혈통 조사 수치를 변경하고자 한다면 내 종족 집단의 승인을 거쳐야 할 것이라고 말했습니다.\n',
#  '오늘 나는 머뭇거리며 새로운 친지들에게 나의 민족성을 밝히고 있습니다.\n',
#  '모르겠습니다, 하지만 나는 언제나 창, 칼, 토가, 월계관 등을 숭배해 왔습니다.\n',
#  '어렸을 때에는 내가 인디언으로 자랐으면 하고 바랬으며, 기회가 있었다면 스포츠 팀이 그들의 마스코트에 내 이름을 따 명명(命名)하게 했을 것입니다.\n',
#  '난 롱 죤 액티브라구.\n',
#  '내가 반쪽의 유픽족이라면, 나는 나 자신을 "윱"이라고 불러야 하나요, "픽"이라고 불러야 하나요?\n',
#  '처음 2분 동안은 3달러 95센트입니다.\n',
#  '기술은 과학의 (원리를 이해하는) 지식을 산업을\xa0위한 (일을 하기 위한) 지식으로 변환시킨다.\n',
#  "to the improvement 에서 to는 적용의 대상을 나타내는\xa0전치사로서 to는 to the improvement  and (to) the increase 와\xa0같이 the increase 에도 걸린다는 것에 유의해야 한다. his well-being과 his wealth에서 his는 man's를 대신하는 것이다.\n",
#  '즉, Four essentials  advance가 주부이고,\xa0 are가 동사이며, the right idea, the right method , the right\xa0moment , and availability 는 모두\xa0주격보어이다. put it into effect에서 it는 the right idea를 받는다.\n',
#  '마지막 요소는 매우 중요하다. 그래서 고대의 성공적인\xa0문화는 구석기, 신석기 시대, 청동기 시대, 그리고\xa0철기 시대와 같이 독특한 물질의 제조라는 견지에서 정의된다.\n',
#  '여기에서 how to do things도\xa0명사구로서 전치사 about의 목적어로 쓰이고 있다.\n',
#  '(어디로 갈 것인지를 너에게 알려주겠다.)\n',
#  '중세기까지는 이런 지식의 총량이 상당히 증가했었다.\n',
#  'general 일반적인, 전반에 걸치는 \xa0\xa0shortage 부족 \xa0\xa0skilled labor 숙련된 노동력 \xa0\xa0workshop 작업장, 공장 \xa0\xa0mine 광산, 광업소 번역 :\n',
#  '인력은 기계에 의해 보강되어야만 했다.\n',
#  '그리고 기계를 다루는데 요구되는 새로운 기술을 촉진하기\xa0위하여 수공업 도제 제도의 대안으로서 기술 대학도\xa0설립되었다.\n',
#  '모스코바에서 최근에 있었던 정치가들, 기업인들, 군(軍)관리들의 파티에 아나스타샤는 아주 잘 조화되어 있었다.\n',
#  '어깨까지 내려오는 염색한 금발의 머리를 하고, 손톱에는 빨갛게 매니큐어를 칠한 19살의 (몸무게 51킬로, 키 162센티) 아담한 이 여자는 연인이나 여주인, 파티 걸로서 생각되어졌을 것이다.\n',
#  '그녀는 레스토랑 안팎으로 배회하는 손님들을 날카로운 시선으로 지켜 보았다.\n',
#  '그리고 핸드백 대신에 헐렁한 저고리 안쪽의 가죽 케이스에 마카로브 권총을 지니고 있었다.\n',
#  '요즈음 러시아에서는 때때로 보리스 옐친이 보이지 않는 것처럼 보디가드들이 눈에 뜨이지 않게 되었다.\n',
#  '이 나라에서는 치솟는 범죄율과 마피아의 혈투 덕분에 보디가드 사업은 잘되고 있다.\n',
#  '하지만 보호받고자 하는 모든 러시아인들이 어깨 넓은 양복을 입은 근육질의 남자를 고용하고 싶어하는 것은 아니다.\n',
#  '따라서 현재 이 나라에서는 아나스타샤와 소수의 다른 여자 보디가드들이 활동을 하고 있다.\n',
#  '그게 우리의 강점이죠."\n',
#  '"맞습니다." 보디가드라는 러시아의 새로운 잡지 편집자인 타이샤 플로트니코바는 말한다.\n',
#  '"그들이 아주 몸집이 크고 강인해야 할 필요는 없습니다.\n',
#  '그저 훈련이 아주 잘 되어있기만 하면 됩니다."\n',
#  '모스코바의 알렉스 에이전시에서 일하는 26세의 줄리아 테르요크히나는 2주일간의 무술 훈련을 받은 후에 체중이 7킬로그램이나 줄었고, 온통 상처 투성이가 되었다고 한다.\n',
#  '아나스타샤는 모스코바 교외에 있는 한 작은 보디가드 훈련 학교인 탄뎀에서 2년간의 과정을 마친 4명의 여자들 중 한 명이다.\n',
#  '탄뎀을 운영하는 올레그 후리에브는 자신의 학생들이 비즈니스 환경에 적응할 수 있도록 훈련시킨다.\n',
#  '그의 학생들은 다소 전통적인 가라데 훈련이나 총기 사용법과 함께 컴퓨터, 심리학, 그리고 여성 기업인으로서의 이미지라는 과목도 이수하게 된다.\n',
#  '"시장은 그들에게 넓게 열려 있습니다.\n',
#  '여자들이 그 일을 할 수 있는가?\n',
#  '보안회사를 운영하는 많은 남성들은 그렇게 생각하지 않는다.\n',
#  '그들은 여자들은 신체적으로 적응해 나갈 수 없으며, 또한 찾아 오는 고객들이 남자들을 고용하게 되기를 기대한다고 주장하며, 여성 응모자들을 회의적인 시각으로 바라 본다.\n',
#  '알렉스의 유일한 여자 보디가드인 테르요크히나는 여성 보디가드를 이상하게 여기거나 현지 기업인들의 첩이라고 생각하지 않는 외국의 기업인들만을 위해 일해 왔다는 점을 인정하고 있다.\n',
#  '또한 그녀는 그러한 태도가 빠른 시일 내에 바뀌리라고 기대하지도 않는다.\n',
#  '하지만 여성 보디가드들에게는 만족해 하는 고객들이 많이 있다.\n',
#  '"우리는 그들(여성 보디가드들)에게 아주 만족해 합니다.\n',
#  '그들은 완전히 직업적 전문가들입니다. "라고 미쓰 모스코바 미인 선발대회의 실무국장인 타티아나 안드레에바는 말한다.\n',
#  '"이것은 대단한 발견입니다."\n',
#  '아나스타샤와 그녀의 동료 여성 급우들은 그들이 좋은 결과를 얻을 것이라는 확신을 갖고 있다.\n',
#  '그들의 다음 목표는 그들 자신의 훈련학교를 개설하는 것이다.\n',
#  'full of computers는 a room을 수식하는 형용사구이다.\n',
#  '학교에는 컴퓨터 한 대에 약 11명의 학생들이 있다.\n',
#  '하지만\xa0멀티미디어용 컴퓨터 한 대에는 약 35명의 학생들이 있다.\n',
#  '어떤 학생들은 10년이나 된 컴퓨터로 공부하고 있다.\n',
#  '이것은 우리가 직시해야만 하는 문제이다.\n',
#  '낡은 컴퓨터는 다음과 같은 문제점을 갖고 있다.\n',
#  '대부분의 새로운 소프트웨어들은 CD-ROM, 음성 및\xa0화상 지원 능력을 필요로 한다.\n',
#  '학생들은 그들이 직업 전선에서 사용하게 될 것과\xa0똑같은 장비로 배우고 있지 못하다.\n',
#  'they는 older computers를 받는 대명사이다. if they can은 if they can take advantage of the Internet을\xa0줄여서 표현한 것이다.\n',
#  '최적의 비율은 멀티미디어용 컴퓨터 한 대당 다섯 명의\xa0아이들이 되어야 할 것이라고 전문가들은 말한다.\n',
#  '그러나 그렇게 되기 이전이라도, 비록 (학교들이 예산을)\xa0삭감해야 하는 시기이긴 하지만 학교에서는 컴퓨터를\xa0가장 우선시해야만 한다.\n',
#  'that technology is nice but (it is) not necessary는\xa0명사절로서 think의 목적어이다.\n',
#  '학교에서는 어린아이들에게 이러한 경험을 하게 해\xa0주어야 한다. 왜냐하면 컴퓨터는 그들의 남은 인생 동안\xa0그들 삶의 일부가 될 것이기 때문이다.\n',
#  '그들은 삼바춤과 카니발, 그리고 가는 끈의 비키니를 좋아한다.\n',
#  '서로 눈이 맞은 성인들끼리의 성행위는 다른 사람들의 일이 아니다.\n',
#  '그리고 사람들은 북미 관광객들을 놀라게 할 정도로 거리낌없이 성행위에 대해 끊임없이 이야기하고, 기사를 읽고, 그리고 농담을 한다.\n',
#  '특히 텔레비젼 방송은 이방인들에게 충격을 주게 된다.\n',
#  '학생들이 수업을 마치고 막 집에 돌아 오는 시간에 방송된 최근의 한 이야기에서는 가죽 옷을 입은 여인이 딸의 남자친구와 뒤엉켜 있는 장면이 포함되어 있었다.\n',
#  '하지만 브라질에도 제한은 있다.\n',
#  '민주주의가 방송사들을 구속했던 수갑을 풀어주기 시작한 이후 10년만에 처음으로 브라질 사람들은 한계선을 긋기 시작했다.\n',
#  '"우리의 방송매체들은 사람들이 언제든, 누구하고나 성행위를 할 수 있다는 생각을 심어주고 있습니다.\n',
#  '바로스 뿐만이 아니다.\n',
#  '로마 캐톨릭 교회도 독실한 신자들을 규합하고 있다.\n',
#  '정신이 없을 정도로 비난을 받고있는 정치인들도 공세를 취하고 있다.\n',
#  '한때는 심한 비난의 대상이었던, 극단적인 처방인 검열에 대한 일반 대중의 지지가 높아져 가고 있다.\n',
#  '사실 브라질은 이파네마 해변의 모습이 나타내는 것보다는 훨씬 더 보수적이다.\n',
#  '낙태는 불법이다.\n',
#  '자신의 애인에게 창피를 주거나, 자신이 창녀로 간주되지 않을까 하는 두려움에 자신의 애인에게 콘돔을 끼라고 감히 제안하는 여자는 거의 없다.\n',
#  '오락 산업계는 그런 불명료성을 거부한다.\n',
#  '시청자, 특히 연속 멜로 드라마의 시청자는 방대하다.\n',
#  '브라질 가정에는 냉장고보다는 텔레비젼을 더 많이 보유하고 있으며, 대부분의 텔레비젼은 오후 5시에서 9시 30분 사이 의 연속 멜로 드라마들에 채널을 맞추고 있다.\n',
#  '95건의 누드 장면, 74건의 성행위, 그리고 90건의 음란한 대화.\n',
#  '방송국들은 그들은 단지 사람들이 원하는 것을 제공할 뿐이라고 주장한다.\n',
#  '하지만 방송국은 설득력 있는 주장을 하지 못하는 것 같다.\n',
#  '연방 법무부는 개인과 보수적인 시골의 지방 정부에서 제기된 수백 건의 불만을 처리했다.\n',
#  '상파울로 카톨릭 부모 협의회는 최근 보다 더 분별있는 방송을 요구하는 15,000명의 서명을 받은 청원서를 제출했다.\n',
#  '정부 관료들은 방송국들이 음란한 내용에 대해 시청자들에게 경고를 하도록 요구하고 있는 규정을 조롱하듯 무시하고 있다고 불만을 털어 놓는다.\n',
#  '하지만 게임은 더욱 더 힘들어질 지도 모른다.\n',
#  '연방 상원위원회는 요즈음 매 주일 회의를 갖고 성적인 내용에 대해 한 주일 간의 프로그램들을 재검열하고 있다.\n',
#  '소년 재판소 판사들은 아역 배우들이 등장하는 프로그램에서 대사의 변경을 요구하기 시작했다.\n',
#  '하지만 그는 24시간 경제의 모범적인 수행인이었다.\n',
#  '메인 주의 사냥꾼들이나 어부들은 새벽 4시에 긴 속옷이나 방한모가 필요하면 언제든 L. L.에 가면 된다는 것을 알고 있었다.\n',
#  '그들이 그의 정문에 있는 썰매 방울을 잡아당겨 울리면 그는 물건을 팔기위해 침대에서 일어나 나오는 것이다.\n',
#  '오늘날 L. L. Bean은 사업의 거의 40%가 일과 후에 이루어지고 있는 연 10억 달러 규모의 사업이다.\n',
#  '이제 더이상 밤은 좀도둑이나 불면증 환자, 그리고 한밤중에 근무가 시작되는 자동차 공장의 야간 근로자들에게만 속한 것이 아니다.\n',
#  '그보다는, 월요일부터 금요일까지, 아침식사 후에 시작하여 저녁식사 전에 끝마치는 와드 클리버 시간대 밖에서 그들은 근무일의 절반 이상을 근무하고 있다.\n',
#  '대형 금융서비스점에서 이름도 없는 수리점에 이르기까지 기업들은 집단적인 성급함에 부응하고 있다.\n',
#  '점차적으로, "내가 일어나 있는데, 당신은 왜 안 일어나 있는가?\n',
#  '이런 사람들에게 서비스를 제공하는 사람들은, 이번 에는, 자신들이 편한 시간에 식사를 하고 쇼핑을 하고 싶어한다.\n',
#  '그리고 오후 근무 교대를 하는 사람들은 집으로 오는 도중에 집안 일을 처리하고 싶어한다.\n',
#  '그들은 전국적으로 밤새 영업을 하는 319개소의 월그린 잡화점, 410개소의 세이프웨이 수퍼마켓, 291개소의 월마트에서 그렇게 할 수가 있다.\n',
#  '밤 늦은 시간에 한차례 골프를 치며 긴장을 푸는 것은 더 큰 도전이다.\n',
#  '하지만 디어 파크에 있는 하트랜드 골프 파크는 오전 3시까지 첫 타구를 칠 수 있게 하고 있다.\n',
#  '5월 이후에만 개장을 하는 하트랜드는 자정에도 2시간 반을 기다려야 하는 일이 빈번하다.\n',
#  '"어떤 사람들은 자정에 근무를 마치고 오고, 어떤 이들은 사무실에 나가기 전에 몇개 홀을 돌고 싶어합니다."\n',
#  '"이곳은 쉬애 스태디엄과 같이 환하게 불이 밝혀집니다."\n',
#  '하지만 24시간 경제가 그나름대로의 위험성이 없는 것은 아니다.\n',
#  '하트랜드는 아주 환하게 밝혀져 있어서 연방 항공관리국은 계기 고장의 비행기들이 골프장을 인근 맥아더 공항으로 오인하지 않을까 우려하고 있다.\n',
#  '자동차에서 철강에 이르는 모든 분야의 제조회사들도 부분적으로 가동을 중단시켰다가 다시 재가동시키는 것보다는 공장을 계속 가동시키는 것이 비용이 덜 들기 때문에 여러 해 동안 복수의 근무 교대 제도를 운영해 왔다.\n',
#  '24시간 사업은 서비스 분야에서 진정한 성장을 하였다.\n',
#  '길게 늘어선 도미노와 같이 하나의 24시간 서비스업이 다른 하나를 밀어내어, 연이어 줄줄이 넘어지게 하고 있다.\n',
#  '휴일에 꼼짝없이 근무해야 하는 경우에, 교통편이 없어 오도가도 못하게 되는 것을 원치는 않을 것이다.\n',
#  '"난 크리스마스에 덴버 공항에 있었습니다.\n',
#  '그리고는 내 보험으로 렌트카 비용이 처리되는지 궁금했습니다.\n',
#  '새벽 2시에 내 컴퓨터를 수리해 줄 수 없다면, 좋다.\n',
#  '난 그렇게 해 줄 다른 사람을 찾을 것이다.\n',
#  '뉴욕에서 일하는 신문기자인 앤 애플봄은 어느 금요일 오후 8시에 런던에 기사를 전송하기위해 준비하던 중에 컴퓨터가 고장나 곤란해지게 되었다.\n',
#  '컴퓨터 수리점인 PC컴퓨터 닥터에서 기계를 가져다가 몇시간만에 수리해 주었고, 90일간 수리보증까지 해 주었다.\n',
#  '런던이나 또는 근무시간이 대체로 짧고, 점심시간은 길고, 주말은 침해받지 않으려는 유럽의 어느 곳에서도 그런 서비스는 찾아보지 못할 것이다.\n',
#  '"소위 24시간 영업을 한다고 하는 회사들도 모두 월요일에 다시 전화하라고 말합니다."\n',
#  '멈추지 않는 경제는 그나름대로의 나쁜 점도 있다.\n',
#  '사실 체르노빌이나, 보팔에서의 사고와 엑손 발데즈 기름유출 사고 등을 포함해 세계 최악의 산업재해들 중 몇몇은 밤중 에 발생했다.\n',
#  '하바드 의과대학의 생리학 교수인 무어 이드 교수는 피로의 댓가\n',
#  '는 1년에 800억 달러라는 엄청난 액수에 이른다고 추정하고 있다.\n',
#  '2교대, 3교대 근무를 하는 어른들은 자신들이 완전히 시간감각을 잃었다는 것을 종종 알게 된다.\n',
#  '"다른 사람들이 모두 파티에 도착하고 있을 때 나는 파티장에서 떠나는 사람입니다."\n',
#  '영국인인 미라졸라는 런던 거래소에서 가장 활발히 거래되는 구리, 알미늄 그리고 다른 기초 금속들을 거래하기 때문에 여전히 런던 시간에따라 생활하고 있다.\n',
#  '그녀의 평일 근무는 오전 2시에 자기집 사무실에서 시작되어, 아시아 고객들과 떠들어 대다가, 본격적으로 4시간 동안의 거래를 착수하게 된다.\n',
#  '오전 6시에는 10분 동안 차를 타고 회사 사무실로 간다.\n',
#  '정오가 되면 그녀는 하루 일과를 마친다.\n',
#  '오후 7시에 잠자리에 들기 전에 그녀는 운동을 하고, 쇼핑도 좀 하고, 그녀의 남편과 저녁식사도 하고 싶어한다.\n',
#  '저녁식사 부분은 순조롭지 못하다:\n',
#  '자신들의 산업을 위해 밤을 개척한 회사들은 종종 그 이득이 엄청나다는 것을 발견하게 된다.\n',
#  'IDC는 심지어 선두주자를 뒤쫓아가려는 후발 기업들조차도 수익을 5% 증가시킬 수 있다고 한다.\n',
#  '"오전 4시에 하는 일들 중 어떤 것은 낮 시간에도 하여지는 일이라고 가정해야 하지만, 그 모든 일이 그런 것은 아닙니다."\n',
#  'IDC는 미국 대기업의 40% 이상이, 적어도 그들 사업의 어떤 특정한 측면에서, 밤중 에 일을 하고 있다고 추산하고 있다.\n',
#  'CNN에서 일하는 사람들이 말하듯이 언제나 어떤 곳에서는 방송의 황금시간대인 것이다.\n',
#  '복사점(店) 체인 회사인 킹코스 주식회사는 사람들이 일과시간 후에 실제로 창문을 두들겨대기 시작하자 24시간 근무일정으로 바꾸었다.\n',
#  '그들은 유리창을 두드리며 들여보내 달라고 애원을 하기 시작했어요.\n',
#  '이 회사의 전국 803개 점포는 은밀한 계획이나 제 2의 직업을 추구하는 공상가에서부터 내일 제시할 계획서의 마무리 손질을 하는 기업 임원들에 이르는 모든 사람들을 끌어들이는 곳이다.\n',
#  '시카고에서는 킹코스가 스토우퍼 르네상스 호텔 로비에 사무실을 개설하여 24시간 경제의 다른 차원으로 끼어들어 왔다.\n',
#  '"고객들이 엉뚱한 시간에 내려와서는 해외로 팩스를 보내달라고 부탁을 했습니다.\n',
#  '우리는 그들의 요구를 들어줄만한 시설이 갖추어져 있지 않았어요."\n',
#  '그래서 지난 크리스마스에 스토우퍼와 킹코스가 협력을 시작했고, 지금은 사업이 번창하고 있다.\n',
#  '은행들도 오래전부터 은행 근무시간을 포기해 왔다.\n',
#  '현금 자동 입출기와 자동응답 서비스가 근무 시간 이후의 손님들을 처리했었다.\n',
#  '이제 많은 은행들은 기본적인 계좌 정보 이상의 것을 제공하는 직원을 24시간 충원시키고 있다.\n',
#  '앞서가고 있는 은행 중의 하나가 오하이오 주 콜럼버스에 있는 헌팅턴 뱅크쉐어즈이다.\n',
#  '밤 늦은 시간에 신문을 자세히 살펴보다가 당신이 꿈에 그리던 자동차 광고를 보게 된다면, 헌팅턴의 대출 담당관에게 전화를 걸어라.\n',
#  '그녀는 당신의 꿈이 계속될 것인지 아닌지를 10분 내에 알려줄 것이다.\n',
#  '헌팅턴은 대출의 10%를 근무시간 이외의 시간에 신청받고 있다.\n',
#  '24시간 영업 전화번호에 의해 창출된 업무는 30개의 정식 지점들에 의한 업무와 맞먹는 것이다.\n',
#  '멈추지 않고 업무를 지속시키는 것이 경제적이라는 것은 기본적인 것이다.\n',
#  '펜실바니아 전력회사는 사업용 전기 사용자들에게 정규 근무시간 이후 시간대에 사용한 전기에 대해 약 30% 낮은 가격으로 사용료를 부과한다.\n',
#  '회사가 오전 9시에서 오후 5시까지라는 일상적인 근무시간의 장벽을 깨뜨리게 되면, 24시간 계속 근무제만이 유일한 대안이 되는 것은 아니다.\n',
#  '기간 요원들만이 한밤중 근무 교대조에 필요할 지도 모른다.\n',
#  '그리고, 때로는 2교대만으로 충족될 수도 있다.\n',
#  '시설유지 관리요원들은 흔히 하루의 일부분 동안만 시설을 인수한다.\n',
#  '예를들어 하트랜드 골프파크는 훼손된 잔디를 교체하고, 잔디에 물을 주기위한 2, 3시간 동안만 폐쇄를 하면 된다.\n',
#  '프로그레시브 사(社)는 1991년에 자동차 보험산업의 야간 서비스 관리를 주도해 온 이후로 수백만 달러의 낭비를 줄였으며, 시장 점유율을 두 배로 늘렸다고 말하고 있다.\n',
#  '자동차 사고가 나면 보험 대리인들이 낮이건 밤이건 어느 때라도 도로에 있는 보험 가입자들을 만날 것이라고 주장한다.\n',
#  '변호사가 사건에 개입하지 않으면 허리나 목의 부상을 당한 사람은 보험회사로부터 평균 2,100달러를 받게 되지만, 변호사가 관련되면, 평균 9,400달러에서 해결이 된다.\n',
#  '지속적으로 제공되는 서비스에 의해 창출된 기업에 대한 좋은 이미지는 이윤보다 더 측정하기가 힘들다.\n',
#  '한 예로 L. L. Bean은 그것을 기반으로 기업을 이루었다.\n',
#  '쉬지않는 경제에 의해 제기되는 가장 큰 난제는 심리적인 것일지도 모른다:\n',
#  '어떻게 잠을 자지않고 지새우느냐 하는 것이다.\n',
#  '"우리는 우리 자신이 만들어낸 이런 24시간 근무의 세계에 쉽게 적합하도록 만들어지지 않았다는 것입니다.\n',
#  '우리 내부의 신체 시계는 밤 에 자고, 낮 에 사냥하는 그러한 세계에 최적의 상태로 적응되어 있습니다."\n',
#  '그는 야간 근무자들은 선잠을 자주 자라고 권고한다.\n',
#  'CNN의 비디오 자료 국장으로서 때때로 야간 근무를 하는 코니 리만은 불을 환히 밝히고, 자극적일 정도로 즐거운 분위기를 유지시키고, 낮 동안 충분히 잠자는 것이 자신은 해결책이라고 말한다.\n',
#  '선잠이 우리 신체를 돌보아 줄 지도 모른다. 하지만 우리의 정신은 어떤가?\n',
#  '우리는 24시간 경제를 제지할 수는 없다.\n',
#  '하지만 신조차도 일요일에는 휴식을 취했다.\n',
#  '씰레스티 테일러는 아픈 것은 아니지만, 탬퍼 종합병원을 휩쓸어 버릴 수도 있고, 그녀의 쌍동이 딸아이들의 생명을 앗아갈 수도 있는 치명적인 세균을 보유하고 있다.\n',
#  '"이 큰 마스크 안에 있는 사람이 엄마란다.\n',
#  '이 두 쌍동이가 태어난 바로 직후에 사태는 더욱 나빠졌다.\n',
#  '여러날 동안 씰레스티는 아이들을 보는 것 조차 허락되지 않았다.\n',
#  '아이들이 태어난 지 2주일이 지났는데 의사들은 직접적인 피부 접촉을 허용하지 않고 있다.\n',
#  '그녀의 아이들은 엄마의 얼굴을 아직 보지 못했다.\n',
#  '"모든 사람들이 당신을 이상하게 바라본다면, 당신은 마치 질병을 갖고 있는 것 같은 기분을 느끼게 되겠죠."\n',
#  '씰레스티가 보유하고 있는 것은 병원에서 발견된 가장 무서운 세균 중의 하나인 황색 포도상 구균이다.\n',
#  '이 균은 병약자에게 침투해 치명적인 혈액 감염, 폐렴, 독성 쇼크를 일으키게 된다.\n',
#  '다행스럽게도 그 균이 씰레스티의 혈류에 침투해 있지는 않다.\n',
#  '그녀는 단지 보균자일 뿐이다.\n',
#  '하지만 포도상 구균은 매년 6만명 가량의 미국인들의 생명을 앗아가고 있다. 이 수치는 자동차 사고로 죽는 것보다도 많은 것이며, 이 균을 없애는 것은 거의 불가능한 것이 되었다.\n',
#  '포도상 구균은 진화하며, 돌연변이를 일으켰고, 항생물질에 면역성을 갖게 되었다.\n',
#  '오늘날, 단지 하나의 항생물질만이 씰레스티가 보유한 종류의 포도상 구균에 대해 효력을 나타내는데 그것은 바로 밴코마이신이다.\n',
#  '하지만 얼마나 오래 그 효과가 지속될 것인가?\n',
#  '"현재, 보다 많이 제기되는 질문은 "어째서 아직 그런 상황을 보지 못하고 있는 것인가?\n',
#  '"하는 것이지, "그런 상황을 보게 될 것인가?\n',
#  '"하는 질문이 아닙니다.\n',
#  '따라서 우리는 항생물질이 쓸모없어지는 상황에 아주, 아주 가까이 다가가 있는 것입니다."\n',
#  '"그러나 저 밖에 우리가 대처할 수 없는 세균들이 있다고 생각하는 것은 아직은 충격적인 것입니다.\n',
#  '우리가 ... 일이란 예상했던 대로 일어나는 것은 아닙니다."\n',
#  '왜 이런 일이 일어나는가?\n',
#  '간단히 말해서 항생제의 오용이다.\n',
#  '한 예로, 환자가 처방된 항생제를 끝까지 사용하지 않으면, 아주 약한 세균은 죽어버리겠지만 아주 강한 세균은 살아남게 된다.\n',
#  '"만약 세균이 죽지않고, 내성을 갖게 되면, 그 세균은 그 개체에서 벗어나 누군가 다른 사람에게로 옮겨 갈 수가 있습니다.\n',
#  '실제로 모든 항생물질들을 비웃고 있는 세균들을 보게 되리라 생각됩니다.\n',
#  '펜실바니아 포츠타운 외곽의 이 전원지역에서 한 여인이 의학적 역사를 만들어낸 것이다.\n',
#  '그녀의 경우는 세균들이 얼마나 주변성이 좋아졌는지 입증하는 것이다.\n',
#  '"그래서 나는 생각했습니다. 금요일에 수술을 하면 월요일이나 화요일에는 그녀가 여기서 나가게 될 것이고, 그리고는 ... "\n',
#  '간호사인 케롤 로써멜은 그녀의 여동생인 조안 레이에 대한 수술이 일상적인 것이 될 것이라고 생각했다.\n',
#  '그러나 조안은 수술 후 발병한 감염이 주 원인이 되어 322일 동안이나 병원에 입원해 있게 되고 말았다.\n',
#  '의사들은 밴코마이신을 포함해 다량의 항생물질로 그 세균과 싸웠다.\n',
#  '하지만 시간이 지나면서 그 병균들은 내성을 키워가며 맹위를 떨쳤다.\n',
#  '감염증 전문의인 헨리 프레이모 박사는 여섯달 동안의 항생제 치료 후에도 어째서 조안의 병이 낫지 않는 것인지 그 이유를 알아내려 하고 있었다.\n',
#  '그 이름이 뜻하는 바와 같이 이 세균은 이미 밴코마이신과 모든 다른 항생물질에 대해 면역성을 갖게 되었다.\n',
#  '하지만 조안의 경우에 있어서, 그 유기체는 또 하나의 예기치 못한 비약적 진화를 했던 것이다.\n',
#  '"우리는 우리가 본 것에 무척 놀랐습니다."\n',
#  '그들이 본 것은 조안이 보유하고 있는 세균이 묻혀진 이 배양접시 위에 있다.\n',
#  '밴코마이신을 포함하는 원반이 그 중앙에 있다.\n',
#  '"그리고 당신은 밴코마이신을 내포하고 있는 그 원반 주위에, 이 세균이 자라고 있는 이 배양접시 위의 한 지점을 볼 수 있을 것입니다."\n',
#  '세균은 의약에 저항할 뿐만아니라 의약을 먹고 번성하는 단계에까지 진화한 것이다.\n',
#  '그에 대한 대응으로, 의사들은 조안에게 밴코마이신 투여를 중단했으며, 그래서 세균은 죽어 버렸다.\n',
#  '과학자들이 새로운 세균을 본 것은 이번이 처음이었지만, 이것이 마지막이 되지는 않을 것이다.\n',
#  '세균의 그러한 적응능력이 과학자들을 우려하게 하고 있다.\n',
#  '"나는 이 문제가 개선되어질 거라고 보지 않습니다.\n',
#  '앞으로 일어날 모든 일들은 더욱 나빠지게 될 것입니다."\n',
#  '그들은 어떠한 비상사태에도 신속히 대처하기 위한 특수팀을 대기시켜 놓고 있다.\n',
#  '이러한 유기체(병균)들과의 전쟁이 얼마나 심각한가?\n',
#  '"미생물은 30억년 동안이나 활동해 왔고, 우리는 그 보다 훨씬 적은 기간 동안 활동해 왔습니다.\n',
#  '오늘날 인터넷은 3, 4년 전에 가상 현실이 그랬던\xa0것과 똑같은 흥분감을 갖고 있다.\n',
#  '정보 초고속도로, 인터넷을\xa0이용하기 시작하는 기업들, 인터넷을 통제하기 위한\xa0정부의 계획, 인터넷에 올려진 사생활과 포르노, 또는\xa0인터넷이 제공하는 다양한 정보 등에 관한 뉴스 기사를\xa0접하지 않고 지나는 날은 하루도 없다.\n',
#  '그러한 뉴스를 접할\xa0가능성은 인터넷 자체 만큼이나 폭이 넓다.\n',
#  '아직 넷을\xa0사용하지 않는 사람들은 그것이 무엇이고, 어떻게\xa0접속하는가에 대해 알고 싶어 한다.\n',
#  '인터넷은 여러 통신망을 엮은 하나의 거대한 통신망이다.\n',
#  '하나의 통신망은 모뎀이나 케이블에 의해 호스트\xa0컴퓨터나 서버에 접속되어 있는 일단의 컴퓨터들을 말한다.\n',
#  '이러한 접속으로 고객으로 가입된 컴퓨터들은 하나의\xa0서버에서 다른 서버로 통신을 할 수 있게 된다.\n',
#  '인터넷 상에서는 모든 종류의 컴퓨터들이 서로 직접\xa0통신을 할 수 있으며, 수천개의 다른 통신망으로 들어 갈\xa0수도 있다.\n',
#  '인터넷에 접속하기 위해서는 컴퓨터,\xa0모뎀이나 케이블 접속, 그리고 인터넷에 들어 가는 수단인\xa0서비스 공급자가 있어야 한다.\n',
#  '기업, 대학, 정부 기관들은 대개 자신들의 컴퓨터와\xa0외부세계 사이를 연결시켜주는 개별적인 통로를 갖고 있다.\n',
#  '개인은 아메리카 온라인, 컴퓨서브, 또는 일본에 있는\xa0니프티서브와 TWICS같은 상업적인 공급자를 통하여 작업을\xa0하게 된다.\n',
#  '또 하나 필요한 것은 훌륭한 영어 실력이다.\n',
#  '1969년으로 거슬러 올라가, 미국 국방성은 방위산업체와\xa0군사적인 연구를 하는 대학들을 연결시키는 컴퓨터\xa0망을 만들었다.\n',
#  '캘리포니아에 있는 세 대의 컴퓨터와\xa0유타에 있는 한 대가 상호간의 손쉬운 접촉을 가능하게 해\xa0주었다.\n',
# ...
#  '평균적으로 열심히 달리기를 하는 미국인들은 일주일에 20마일(32km)을 달린다.\n',
#  '따라서 그들은 6개월마다 새 운동화를 사게 될 것이다.\n',
#  '물론, 그렇게 빨리 운동화를 닳아 못쓰게 하는 사람은 거의 없다.\n',
#  '대부분의 사람들은 땀에 흠뻑 젖었다고 느끼기 보다는 스포티한 느낌을 갖기위해 운동화를 구입한다.\n',
#  '그러나 패션의 변화가 달리는 것 만큼이나 빠르게 운동화를 닳아 없어지게 한다.\n',
#  '이는 패션, 효용성, 건강, 운동, 아름다움, 개성, 이 모든 것들을 100만 달러의 광고와 함께 결합시키는 시장 상인들에게는 꿈의 산업인 것이다.\n',
#  '그러나 이것은 조로(早老)현상의 징후를 나타내고 있다.\n',
#  '전세계 135억 달러의 스포츠화 시장의 성장은 대부분이 시장이 형성되는 단계에 이루어진 것으로 여겨지고 있다.\n',
#  '이러한 사실이 아직은 스포츠화 시장의 선두주자로 부상한 미국의 나이키를 괴롭히고 있지는 않다.\n',
#  '나이키는 지난해 같은 기간에 비해 1/4분기 판매가 38% 성장하여, 세금 공제전 이윤이 55% 상승했다고 발표했다.\n',
#  '나이키는 미국 리복의 20.4%, 독일의 가족회사인 아디다스의 10.8%에 비교해 세계 시장의 23.8%를 점유하고 있다.\n',
#  '하지만 이러한 순위는 지난 10년 동안에 계속 바뀌어 왔으며, 다시 또 그렇게 될 수 있을 것이다.\n',
#  '1980년대 중반까지는 아디다스가 분명히 선두주자였다.\n',
#  '하지만 회사 설립자의 아들이 사망함에따라 회사가 표류하게 되었다.\n',
#  '나이키가 값비싼 광고와 판촉활동으로 끼어들었다.\n',
#  '나이키의 전략은 유명 스포츠 인사들을 고용 계약하여, 상표와 그들의 성공을 동일시 하도록 하는 것이었다.\n',
#  '90년대초 미국이나 유럽의 10대들이 영국의 닥터 마텐 부츠나, 다른 촌스러운 패션의 신발을 신기위하여 자신들의 운동화나 연습화를 잡아뜯던 시기에도 나이키는 이런 판매전략을 고집했다.\n',
#  '이제 패션이 다시 제자리를 찾아 유행하게 되었으며, 나이키는 그 보상을 받고 있다.\n',
#  '여성용 신발에 대한 새로운 시장을 개척하는데 초기에 성공을 거둔 이후로 리복은 나이키의 뒤를 따라가고 있는 형편이다.\n',
#  '나이키에 대한 보다 더 큰 위협은 회생한 아디다스이다.\n',
#  '버나드 타피의 지배를 받던 비참한 시기를 보낸 아디다스는 또 다른 프랑스 기업가인 로버트 루이스-드레이퍼스에 의해 1993년에 매입되었는데, 드레이퍼스는 이전에도 부실한 싸치 앤 싸치 광고 그룹을 회생시키는데 도움을 주었다.\n',
#  '루이스-드레이퍼스 씨는 생산의 3%를 제외한 모든 생산을 독일에서 아시아로 이전시켰다.\n',
#  '노동력은 최고 때의 14,300명에서 5,500명으로 줄었고, 신발은 보다 기술적으로 앞섰고, 보다 유행에 맞는 것이 되었다.\n',
#  '아디다스는 또 다른 이점도 갖고 있다.\n',
#  '나이키나 리복은 판매의 3/4이 신발 판매로 이루어지는 반면에 아디다스는 광범위한 의류들도 생산하고 있다.\n',
#  '시장분석 전문가들은 스포츠 의류의 판매가 신발 시장보다 더 빠르게 성장할 것이라고 추산하고 있다.\n',
#  '판매가 약 10%정도 상승하여 아디다스의 작년 하반기 세금 공제전 이윤은 두 배 이상이 되었다.\n',
#  '다음 목표는 미국으로서, 아디다스는 그곳에서 리복을 누르고 현재의 낮은 시장 점유율을 두 배로 늘리길 바라고 있다.\n',
#  '하지만 스포츠화 사업의 미래 이윤의 대부분은 아시아에서 얻게 될 것이다.\n',
#  '신발 산업계의 사람들이 말하는대로 바로 그곳에 발이 있는 것이다.\n',
#  '누군가가 컴퓨터 통신망에 접속하여 하루에 18시간을 보낸다면 무엇이라고 말하겠는가?\n',
#  '연구를 하는 과학자가 아니라 텍사스 주 한 가정의 아이 엄마가 말이다.\n',
#  '만약 그녀가 400달러나 되는 한 달 전화사용료에 대해 그녀의 남편에게 거짓말을 했다면 어떻게 하겠는가?\n',
#  '그녀의 결혼이 파경에 이르고, 그녀가 아이들로부터 남처럼 취급받게 되었다는 이야기를 들었다면 어떻게 하겠는가?\n',
#  '그녀는 보다 많은 미국인들이 인터넷을 대하게 됨에따라 앞으로 발생하게 될 일에 대해 걱정한다.\n',
#  '"나는 인테넷이 정말로 나쁜 것이 되고, 이 나라에 위험이 될 수도 있다고 생각합니다."\n',
#  '컴퓨터 이용에서 그녀가 그랬던 것 처럼, 글렌더는 미래에 대한 평가에서도 지나치게 극단적인지 모른다.\n',
#  '그러나 모든 것을 빨아 들이는 블랙홀 속으로 빨려 들어갈 정도로 무한한 웹의 잠재력에 대해 걱정하는 사람이 그녀 혼자 뿐만은 분명 아니다.\n',
#  '어떤 전문가 들은 컴퓨터 통신을 하는 사람들의 2내지 3%가 심각한 인터넷 중독증을 갖고 있다고 추산하고 있다.\n',
#  '임상 심리학자이자 피츠버그 대학의 조교수인 킴벌리 영은 다음 미국 심리학회 회의를 위해 이 문제에 대한 논문을 제출했으며, 진단 교범에 이 질병이 추가되기를 바란다.\n',
#  '오하이오 대학 대학원생인 리츠 버레트는 1년 전 가까운 친구 두 명의 학자로서의 경력이 점점 나빠지는 것을 본 이후로 "웨버홀릭스"라는 웹페이지를 개설했다.\n',
#  '그 이후로 이 웝페이지는 20만명의 이용자를 끌어들이게 되었다.\n',
#  '"익명의 인터네터스"나 뉴욕의 한 정신병 의사에 의해 설립된 회원수 300명의 "인터넷 중독 지원단"도 있다.\n',
#  '어휘 : psychologist 심리학자\xa0\xa0 tactful 재치있는\xa0\xa0 no less 못지않게\xa0\xa0 discouraging 비관적인, 가망이 희박한\xa0\xa0 give  a label  에 꼬리표를 부치다\xa0\xa0 have a cure 치료를 받다\n',
#  '분명 그렇게 생각될 수도 있다.\n',
#  '캘리포니아주 카슨 출신의 한 대학 4학년 생인 스텔라 유는 자신이 강박관념에서 벗어나려고 애쓰고 있다고 말한다.\n',
#  '그녀는 90년대 후반에 처음으로 컴퓨터 통신을 했다.\n',
#  '지금 21살인 유는 학교에 가기 전 서너시간 동안 컴퓨터 통신에 끼어들기 위해 새벽 5시에 침대에서 일어나 나온다.\n',
#  '그녀는 수업중간의 휴식시간에도 컴퓨터 통신을 하며, 그리고 나서는 파트타임 직장에서도 한다.\n',
#  '일단 집에 오면, 새벽 1시에 잠자리에 들 때까지는 마음껏 즐기게 된다.\n',
#  '"나의 하루는 전부 이 일을 중심으로 계획이 됩니다.\n',
#  '그녀의 학교 성적은 떨어졌고, 450달러나 되는 전화료 청구서때문에 그녀의 아버지와 다투어, 집에서도 내놓은 자식이 되었다.\n',
#  '"나는 항상 그만 두겠다는 약속을 합니다.\n',
#  '공부를 위해서만 이용하겠다고 말입니다.\n',
#  '공부를 위해서는 10분만 컴퓨터를 사용하고, 그리고는 채팅을 하며 2시간을 보내죠."\n',
#  '컴퓨터 통신에 대한 중독을 풍자하기는 쉽다.\n',
#  '사실 피츠버그 대학의 영은 그러한 회의론(懷疑論)을 이해한다.\n',
#  '툴사 대학의 통신학과 과장인 스티브 존스는 걱정이 지나치다고 말한다.\n',
#  '"중독이 될 것이라는 두려움을 불러 일으키지 않고서 광범위한 이용이 이루어질 수는 없습니다.\n',
#  '만약 우리가 영화나 TV, 책을 본다면, 어떻게든 이러한 것들로 인해 우리가 서로 접촉을 하지않게 되고, 인간관계를 만들어 내지 못하게 될 것이라는 두려움이 생기게 됩니다."\n',
#  '죤스의 말은 일리가 있다. 결국, 평균적인 TV시청자들은 일주일에 28시간 이상을 브라운관 앞에서 보내고 있다.\n',
#  '하지만 소수의 사람들은 포로가 된다.\n',
#  '사람들이 중독이 되었다고 느낄지도 모르지만 정말 어려운 문제는 다른데 있다고 MIT의 사회학자이자 임상심리학자인 쉐리 터클은 말한다.\n',
#  '문제가 있는 대부분의 인터넷 이용자들은 채트 룸, 전자 우편, 또는 다른 통신에 시간을 보내고 있다.\n',
#  '그리고 자신을 네트 중독자라고 인정한 사람들은 자신들이 다른 사람들과의 직접적인 접촉에서 보다는 통신상으로 더 가치가 있다고 생각한다.\n',
#  '자신들이 컴퓨터 통신 상에서 애정이 있고, 영리하고, 유머가 있고, 친절하다면, 이러한 특질들은 자기 자신에게 속하는 것이라고 평가해야 할 필요가 있는 것이다.\n',
#  'serving in the military에서 serving은 현재분사로서\xa0women을 수식한다.\n',
#  '한 조사에따르면 공군은 97%의 일자리를 여성에게\xa0개방함으로써 가장 좋은 고용기회를 제공하고 있다.\n',
#  '하지만 해병대는 겨우 20%의 일자리를 여성에게\xa0개방함으로써 아주 배타적인 남성의 영역으로 남아 있다.\n',
#  '비록 오늘날의 전쟁터에서는 여성들도 사상자들 중에\xa0포함되기는 하지만 여성들은 여전히 직접적인\xa0전투 임무에서 배제되고 있다. 번역 :\n',
#  '그런데 대부분의 여성 군인들은 배제되는 것을 원하지 않는다.\n',
#  '그리고 위험한 군 임무에 보다 많이 노출이 됨으로써\xa0많은 사람들은 미 군대에 남아 있는 장벽들이\xa0무너지기를 희망하고 있다.\n',
#  '아시아는 무서운 속도로 산업과 경제를 발전시키고 있으며, 동시 에 환경문제의 해결을 위한 수십억 달러의 필요성도 야기시키고 있다.\n',
#  '세계은행은 가장 도움이 필요한 분야로서 다음과 같은 영역을 언급했다:\n',
#  '대기오염, 수자원, 삼림 훼손과 토양의 침식, 에너지 수요의 증가, 유해 폐기물의 처리와 제거, 그리고 쓰레기 폐기.\n',
#  '환경 관련 상품과 서비스의 국제시장에서 아시아 지역만의 수요가 600억 달러를 초과할 것으로 예상되고 있다.\n',
#  '아시아 전역에 걸쳐 환경보호입법은 놀라울 정도로 잘 개발되어 있으며, 세밀하게 되어 있다.\n',
#  '그러나 싱가폴을 제외하고는, 각국 정부들이 환경보호와 경제개발의 필요성을 조회시키기 위해 애쓰고 있기 때문에 법의 이행과 집행이 반드시 뒤따라 이루어지고 있지는 않다.\n',
#  '환경과학 및 공학 자문단인 CMPS&F의 단장인 피터 네이드 봄은 선진개발국들은 적절한 환경관계 법률과 정책을 갖고 있지만, 미개발국들은 그러한 법률과 정책을 감당할 여유가 없다고 말했다.\n',
#  '당장 요구되는 경제적 생존과 환경보호를 위한 보다 장기적인 필요성 사이 에서 균형을 이루어야 할 필요가 있습니다."\n',
#  '산업 폐기물이 강이나 하수구로 직접 배출되고 있는 개발도상국에서는, 위험한 폐기물이란 개념이 없고, 따라서 법규를 이행하려는 의지에는 어떤 긴박감이 결여되어 있다는 것이 문제이다.\n',
#  '경제적으로 생존해나가려고 애쓰는 나라에서는 큰 댓가를 치르고 난 후에야 환경 법규가 생겨나게 된다.\n',
#  '생존이란 단기적인 사고를 요구하지만, 환경 보호는 장기적인 비현실성의 영역이다.\n',
#  '어디엔가 그 균형점이 있다.\n',
#  '급속히 확대되고 있는 아시아 태평양 지역의 중산층들에 의해 그 균형이 그들 정부에 요구되고 있다.\n',
#  '인도네시아, 타이랜드, 중국, 한국, 대만, 그리고 말레이지아 같은 나라에서는 변화를 위한 일정을 정하고 있다. 그런데 이들 나라에서는 수질이 최우선적인 문제의 촛점이며, 그 뒤를 이어 대기오염, 그리고 폐기물 관리문제가 뒤따르고 있다.\n',
#  '인도네시아의 환경은 전세계 생물학적 다양성의 60 내지 70%를 내포하고 있는 특출한 과학적 보존가치를 갖고 있다.\n',
#  '많은 개발도상국들과는 대조적으로, 인도네시아는 석유 자원과 비석유 자원, 비옥한 토양, 울창한 산림을 포함해 풍부한 천연자원을 갖고 있기도 하다.\n',
#  '인도네시아는 일찍이 건실한 환경관리의 기초 개념을 천명했으며, 경제개발과 환경보호를 통합하려는 오랜 역사를 갖고 있다.\n',
#  '그러나 다른 개발도상국들과 마찬가지 로, 이 나라도 한꺼번에 모든 우선순위 분야에 자금지원을 할 수 없었으며, 그 결과로서 환경은 개발 과정에서 병들어 갔다.\n',
#  '인도네시아의 산업 발전은 아주 급속히 이루어졌기 때문에, 산업 전반에 거쳐 환경문제가 심각한 정도로 전면에 나타나게 되었다.\n',
#  '폐수 처리기술이 크게 요구되는 분야로는 농산물 사업, 음식물 처리가공, 섬유, 제혁, 전기도금, 그리고 증류주 제조 등이 포함된다.\n',
#  '하지만 더 많은 소득과, 더 나은 생활수준을 추구하는 점점 더 많은 사람들의 이해 관계와 사회적, 환경적 관심사를 조화시키는 것은 모두에게 가장 커다란 난제인 것이다.\n',
#  '예를들어, 농부들은 수익을 증대켜 왔으며, 또한 농토의 산출량을 증가시킨 다양한 농작물, 관개, 비료, 살충제의 개선에따라 보다 많은 사람들이 계속 남아 농사를 지을 수 있었다.\n',
#  '그에따라 경작지역을 확대하기 위하여 산림과 다른 자연적 식물의 식생지가 개간되어 왔다.\n',
#  '새우 양식장은 맹그로브 산림과 다른 자연 식물 식생지를 희생시켜가며 고용기회를 증대시켜 왔다.\n',
#  '1960년대 중반 이후로 성장해 왔고, 지금은 국내의 합판 및 다른 목재산업의 급격한 확장으로 더 한층 증대된 상업적 벌목산업이 더 많은 고용과 수익을 창출하였다.\n',
#  '채광업과 자원 산업, 특히 석유, 가스, 소규모 금광과 건설 자재를 위한 채석업 등이 경제적인 보상과 상당한 고용 증대를 야기시켰다.\n',
#  '도처에서 새로운 산업이 생겨났으며, 그중에는 국내의 농산물 처리를 위한 산업도 있고, 수입 대체품을 위한 산업도 있다.\n',
#  '게다가 수백만 명의 사람들이 수입과 일자리를 찾아 도시 지역으로 이주하였다.\n',
#  '이러한 모든 변화는 특히 수질과 비교적 손상을 입지 않은 지역의 동식물군(動植物群)의 손실에 심대한 환경적 영향을 미쳤다.\n',
#  '생물학적 다양성은 감소되었다.\n',
#  '미세입자와 화학 물질에 의한 대기 오염과 고체 폐기물의 처리로 생긴 문제들도 또한 성장의 환경적 결과들이다.\n',
#  "미국에서의 음식 스타일에 많은 변화가 일어나고 있다. its는 the United States'를 대신한다.\n",
#  '미국은 전통적으로 고기와 감자를 먹는 아주 변함없고\xa0한결같은 식사 습관으로 유명하다.\n',
#  'to choose from은 alternatives를 수식하고 있다.\n',
#  '민족 고유 음식점들과 수퍼마켓은 미국에서는 평범한 것이다.\n',
#  '미국은 이주민들의 나라이기 때문에 거대한 다양성이 존재한다.\n',
#  '사람들이 자신들의 신체적 행복을 보다 진지하게 생각하기\xa0시작하면서 건강 음식이 인기를 얻었다.\n',
#  'to help it last longer는 preservatives를 수식하는\xa0형용사구이다.\n',
#  '간이 음식점들은 지금 전국적으로 급속히 확산되고 있다.\n',
#  '미국에서는 속도가 아주 중요한 요소이다.\n',
#  '사람들은 흔히 짧은 점심 시간을 갖거나,\xa0또는 그저 먹는 데 시간을 낭비하고 싶어하지 않는다.\n',
#  '음식에 대한 미국의 태도 또한 변화되고 있다.\n',
#  '전통적으로 양이 많은 아침식사와\xa0오후 6시에 먹는 저녁식사는 인기를 잃어가고 있다.\n',
#  '다른 문화권의 많은 사람들과 같이 많은 미국인들은,\xa0비록 아직은 햄버거 가게에서 서둘러 점심을\xa0끝내기는 하지만, 편히 쉬면서 저녁식사에서 좀 더\xa0훌륭한 맛을 즐기기 위한 시간을 내고 있다.\n',
#  '환경법규의 도입은 고통스러운 과정이다.\n',
#  '대규모 사업의 환경영향평가에는 반드시 환경적 전문지식이 집중적으로 이용된다.\n',
#  '해로운 환경적 관행으로 이끌리지 않도록 하기 위하여 가격장려 요인은 신중하게 검토되어야만 한다.\n',
#  '예를들어, 상업적 폐기물은 생산 부품비로서 원가계산이 되어야만 한다.\n',
#  '수도물과 에너지 사용료에 대한 정부보조는 자원의 낭비를 초래하게 된다.\n',
#  '인도네시아는 폐기물의 최소화 및 처리, 그리고 가능하다면 재생과 재활용을 위한 새로운 기술과 관리 씨스템을 찾고 있는 중이다.\n',
#  '환경을 보호하는 사람들과 환경문제를 야기시키는 사람들 사이에 더 많은 조화가 이루어지고 있다.\n',
#  '환경정책의 감시와 시행을 위한 법규들 또한 강화되고 있다.\n',
#  '인도네시아는 성공적인 5개년 개발계획에서의 급속한 경제성장으로 환경에 부담이 더해지고 있다는 것을 인정했다.\n',
#  '자원보존 기본법은 지역사회의 참여를 강조하고, 환경영향평가를 위한 기초를 제공하고 있다.\n',
#  '아주 대조적으로, 중공업 및 제조업체로부터 많은 양의 다양한 유해폐기물이 발생하고 있는 작은 섬나라인 싱가폴은 엄격한 환경법을 갖고 있다.\n',
#  '싱가폴의 270만 인구가 626평방킬로의 면적에 살고 있다.\n',
#  '섬의 48%가 상업용, 주거용, 그리고 산업용으로 이용되고 있다.\n',
#  '약 12%가 농업용으로 이용되고 있고, 나머지 40%는 산림, 보호지, 기타 건축규제지역으로 되어있다.\n',
#  '싱기폴 경제의 주요한 분야는 제조, 무역, 금융 및 기업서비스, 교통 및 통신분야이다.\n',
#  '중공업과 제조업은 주로 섬 남서부지역의 주롱 공업단지 내에 위치해 있다.\n',
#  '경공업과 전자 같은 비공해 산업체들은 인구밀집 지역 근처에 산재해 있다.\n',
#  '환경부의 공해통제국은 유해 폐기물을 통제하고, 그러한 통제는 새로운 공장의 설립 계획 단계에서부터 시작된다.\n',
#  '싱기폴은 폐유, 사용하고 난 솔베트나 부식산(酸), 그리고 폐침전물 같은 다양한 유해 폐기물을 발생시키고 있다.\n',
#  '그러한 시설을 갖고있지 않은 업체는 폐기물을 수집하여 재생, 처리할 자격이 있는 폐기물 처리 하청업자들을 고용하도록 되어 있다.\n',
#  '사설 폐기물 처리업자들이 운영하는 시설에는 폐기물을 재생하거나 유독성을 제거하기 위한 증류기, 소각로, 화학 처리 공장, 응축 시설, 전기분해 시설 등이 있다.\n',
#  '재생될수 없는 폐기물은 처분해도 안전한 상태로 처리되거나 정제되어야만 한다.\n',
#  '싱기폴은 유해 폐기물의 처리와 방류를 위한 여러가지 방법과 기술을 이용한다:\n',
#  '- 미생물로 분해할 수 있는 액체 폐기물을 위한 생물학적 처리\n',
#  '침전, 중화와 같은 물리적, 화학적 처리\n',
#  '- 화학적 물질의 토양 침투를 막기 위하여 매립하기 전에 유해\n',
#  '대부분의 액체 폐기물은 회사내 처리 공장에서 처리된다.\n',
#  '처리가 된 액체 폐기물은 보통은 오물 처리장에서 다시 처리하기 위해 하수구로 버려진다.\n',
#  '이 지역의 다른 곳인 홍콩은 하루에 390,000톤의 공해 물질을 발생시키고 있는데, 이 공해물질들은 대체로 아황산가스, 이산화질소, 일산화탄소, 거기에다 셀 수 없이 많은 량의 공중에 떠있는 미립자로 나뉘게 된다.\n',
#  '이 지역은 또한 세계 에서 가장 활발하다고 여겨지는 건축 붐이 일고 있기도 하다.\n',
#  '토지 개간 구역으로 이용되고, 또 새로운 체크 랩 콕 공항을 위해 섬과 산 전체가 모습을 잃어가고 있다.\n',
#  '이러한 건설의 단 한가지 측면을 보면, 7천만 입방미터의 부드러운 바다진흙이 해저에서 채취되어야만 하고, 그곳은 다시 바다의 다른 지역에서 굴착된 7천6백만 입방미터의 모래로 채워져야만 하는 것이다.\n',
#  '그러나 하청업자들은 홍콩 환경보호국의 까다로운 조건을 충족시켜야만 한다.\n',
#  '환경보호국은 홍콩 영해(領海)를 지키는 60개소의 수질감시소와 2척의 선박에 산소용해도, 혼탁상태, 부유물질, 수온 등을 감시하도록 위임했다.\n',
#  '공항(건설)과 그와 관련된 사업에 종사하는 채취업자들은 반드시 지정된 장소에 바다 진흙을 버리도록 되어 있다.\n',
#  '이 규정을 준수했는지 확인하기 위하여 이들에게는 위성항법장치가 갖추어져 있다.\n',
#  '소련의 코카서스 지방에서는 매 10만 명 중에서\xa050명 가까운 사람들이 100번째 생일을\xa0기념할 만큼 오래 살고 있으며, 많은 사람들은\xa0100살에서 멈추지도 않는다.\n',
#  '하지만 이 소련의 노인들만이 그런 것은 아니다.\n',
#  '이런 사람들은 그러한 시간의 경과에도 불구하고\xa0신체적으로 정신적으로 여전히 건강하다.\n',
#  'to survive to such 의 to survive와 to survive so\xa0well의 to survive는 둘 다 this ability를 수식하는\xa0형용사적 용법의 부정사이다.\n',
#  'first of all 무엇보다도 \xa0\xa0hard 힘든 \xa0\xa0physical work 육체 노동 \xa0\xa0a way of life 생활의 방편 번역 :\n',
#  'factor 요소, 요인 \xa0\xa0contribute 기여하다 \xa0\xa0good health 건강 \xa0\xa0isolation 고립, 격리 번역 :\n',
#  '그들은 그들의 신체가 필요로 하는 것보다\xa0더 많은 음식을 절대 먹지 않는다.\n',
#  '도시의 스트레스와 오염으로부터의 격리, 깨끗한\xa0산의 공기, 일상적인 고된 노동, 절제된 식사, 좋은\xa0유전자, 그리고 삶에 대한 발랄한 접근, 이 모든 것들이 이 모든\xa0사람들의 건강과 놀랄 만한 장수에 기여하고 있다는 것은 분명하다.\n',
#  '- 난 무엇인가 기묘한 것을 보았습니다.\n',
#  '- 하늘에서 푸드득거리며 비행하는 작은 불빛들 같았어요.\n',
#  '- 그것들은 저 외계의 초자연적인 기술로 작동되고 있었습니다.\n',
#  '- 외계인의 기술 말입니다. - 가장 중요한 것은...\n',
#  '네바다의 375번 고속도로는 끝없는 직선과도 같이 사막 한가운데의 풍경을 가로질러 쭉 뻗어 있다.\n',
#  '왜냐하면 이 길은 존재하지 않는 장소로 우리를 데려다 주기 때문이다.\n',
#  '이 산 넘어 어딘가에, 라스베가스에서 2시간 반 정도 벗어나면, 스텔스 전투기와 블랙버드 같은 정찰기들이 처음 비행시험을 했던 비밀 공군기지가 있다.\n',
#  '하지만 소련과 미국 정부에 의해 촬영된, 우리가 발견한 이 오래된 위성사진에서는 그 기지를 찾아볼 수 있을 것이다.\n',
#  '우리는 활주로, 건물, 그리고 거대한 참호같이 보이는 것들을 보게 된다.\n',
#  '그것들은 무엇을 하기 위한 것인가?\n',
#  '어떤 비공식적인 해답을 찾기위해 우리는 우리가 찾을 수 있었던 가장 가까운 마을인 네바다 주의 자그마한 레이첼에 머물렀다.\n',
#  '개 한마리, 국기 계양대 하나, 그리고 리틀 에일레인이라는 술집이 하나 있었다.\n',
#  '- 저 밖에서 무슨 일이 일어나고 있다고 생각하십니까?\n',
#  '- 저 곳에는 간담을 서늘하게 할 만한 일들이 있죠.\n',
#  '- 내 생각에는 저 곳에 많은 외계인들이 있는 것 같습니다.\n',
#  '- 아주 특이한 일들을 많이 보게 되는데, 그것에 대해 이야기하는\n',
#  '이곳의 사람들은 하늘에서 이상한 불빛들을 본 것과 나포된 미확인 비행물체가 비밀 격납고 안에 들어 있다는 소문에 대해 우리에게 말해주고 있다.\n',
#  '하지만 길을 따라 내려가면, 51구역 연구센터에서 우리는 전혀 다른 이야기를 듣게 된다.\n',
#  '- 이곳에서 떠도는 외계인 이야기는, 그 이야기들 중 대부분은,\n',
#  '글렌 캠프벨은 51구역 안의 작업 내용을 밝혀내는 일에 전념하기 위해 컴퓨터 회사의 일자리를 그만 두었다.\n',
#  '- 이곳은 국내에서 가장 잘 알려진 비밀기지입니다.\n',
#  '- 기지가 거기에 있다는 사실을 인정하지 않을 것입니다.\n',
#  '- 얼마나 오랫동안이나 이 기지 안을 조사해 오고 있습니까?\n',
#  '- 2년 동안 이곳에 있었습니다.\n',
#  '- 그러면 저 기지 안에서 벌어지는 일에 대해 무엇을 알고 있습니까?\n',
#  '- 정말이지 아는 게 없습니다.\n',
#  '기지의 몇몇 일상적인 업무 과정을 알고 있습니다.\n',
#  '- 하지만 그 안에서 무슨 일이 일어나고 있는지는 모릅니다.\n',
#  '- 그리고 솔직히 많은 근로자들도 그 안에서 일어나는 일에 대해\n',
#  '- 모르고 있습니다.\n',
#  '이 기지는 냉전의 유물이다.\n',
#  '정부가 비밀을 유지할 수 있는 완벽한 장소, 그리고 전해진 바에 의하면, 범죄를 저지르기에 완벽한 장소이다.\n',
#  '기지 근로자들은, 투옥될 위험을 무릅쓰고 나서서, 정부 하청업자들이 51구역을 비밀 폐기물 처리장으로 어떻게 이용하고 있는지 전해들은 말들을 우리들에게 말해주고 있다.\n',
#  '무장경호원의 감시하에 기밀 취급되는 물질들이 덮개없는 커다란 참호 안에 폐기되어 소각된다는 것을 설명해주고 있다.\n',
#  '근로자들은 그 연기를 들어마신 후에 건강 상의 문제가 생겼다는 것을 말하고 있다.\n',
#  '그들의 불만에 대한 호소가 무시되었고, 보호복에 대한 요구도 거부되었다고 그들은 말한다.\n',
#  '법학 교수인 조나단 털리가 군(軍)당국에 대한 소송에서 프로스트 여사와 기지 근로자들을 대변하고 있다.\n',
#  '그러나 존재하지도 않는 기지를 어떻게 고소하려고 하는가?\n',
#  '- 우리는 현 정부에 단지 한 가지 질문만을 했습니다. 그리고\n',
#  '- 그래 그들이 당신에게 뭐라고 말했나요?\n',
#  '- 그들은 "우리는 그 질문을 이해조차 하지 못한다. "라고\n',
#  '- 어째서 그렇게 대단한 것입니까?\n',
#  '- 일단 기지가 그곳에 있다는 것을 인정하게 되면, 그곳에서\n',
#  '- 벌어지고 있는지도 모르는 어떤 범죄에 대한 책임을 지게 되겠죠.\n',
#  '우리는 캠프벨과 약 30명 가량의 다른 아마츄어 스파이들을 따라 51구역의 일부분이 일반인들의 시야에 드러나 보이는 공유지의 산등성이로 갔다.\n',
#  '- 산등성이 뒷쪽에 무엇이 감추어져 있다고 생각하십니까?\n',
#  '그저 편안한 마음으로 경치를 즐기는 것이다.\n',
#  '- 여보, 이쪽이야, 아니면 저쪽이야?\n',
#  '- 당신은 그 시설들의 일부를 지금 볼 수 있습니다.\n',
#  '- 네, 보이는군요.\n',
#  '쌍안경으로 우리가 발견해 낸 특징이 없는 건물과 격납고들은 놀랍게도 쉽게 눈에 뜨인다.\n',
#  '- 정부는 언제나 우리의 움직임을 염탐하지만, 이제는 반대로\n',
#  '- 우리가 염탐을 할 수 있죠.\n',
#  '하지만 밝혀진 바대로, 그날 사막에서 잠복을 했던 것은 우리들만이 아니었다.\n',
#  '우리가 기지를 살펴보고 있을 때 흰색 차량을 탄 경비원들은 멀리서 우리를 지켜보고 있었다.\n',
#  '"디즈니사는 그들이 거대하기 때문에 우리가 그들을 해칠 수 없다고 생각합니다.\n',
#  '그러나 반바지가 맞지않을만큼 여러분들이 너무 커버리면 문제가 생기게 됩니다.\n',
#  '왜 그토록 건전해보이는 회사가 대상이 되는가?\n',
#  '미국 가족협회가 도덕성에 의구심을 갖는 오락물을 디즈니사가 만들고 있기 때문이다.\n',
#  '더욱이 디즈니사는 동성 연애자 직원들과 동거하는 사람에게까지 의료혜택을 확대했다.\n',
#  '윌드먼이 지지자들을 동원하자 미키 마우스가 큰 신발을 신고 떨고 있는가?\n',
#  '존 드라이어 대변인은 냉소적으로 이렇게 말한다:\n',
#  '디즈니사만이 아니다.\n',
#  '지금은 분리된 왈든북스사업부에서 플레이보이지를 팔고 있었기 때문에 그의 단체가 K마트에 불매운동하고 있었다\n',
#  '미국 노동 총연맹 산업별 회의 회원들은 K마트가 심각한 쟁의가 진행중인 디트로이트 신문사에 광고를 게재하기 때문에 K마트를 멀리 해버렸다.\n',
#  '불매운동가들의 시선을 끌고 싶은가?\n',
#  '빅맥에 라틴 아메리카 우림지역의 개간된 농토에서 사육된 젖소의 고기가 들어있다는 거짓의 그러나 지독하리만큼 끈질긴 루머를 퍼뜨린 환경주의자들에 의해 맥도날드는 수년동안 괴롭힘을 당했다.\n',
#  '맥도날드의 대변인 척 에벨링은 한숨을 쉬며 말한다.\n',
#  '\'\'전국에 만 개의 점포를 갖고 있는 우리는 이런 문제에 대해서는 피뢰침과 같이 최우선적 피해자가 될 수 있습니다."\n',
#  '성난 소비자들이 자의적으로 표결을 하게 할 만큼 회사의 규모가 커지고 눈에 뜨이게 되면 불매운동으로 큰 영향을 끼치기에는 회사가 너무 커져 있다는 것이 아이러니하다.\n',
#  '10월에 위스콘신의 축산업자, 소비자 단체, 그리고 환경주의자들이 연대하여 유전 공학적으로 만들어진 상품이 안전하지 않다며 몬산토에 대한 불매운동을 발표했다.\n',
#  '몬산토는 한 기자가 세인트 루이스에 있는 본사에 전화를 걸어 해명을 부탁할 때까지 불매운동 사실을 몰랐다.\n',
#  '그런데 사용하지 않는 물건에 대해 불매운동을 하는 목적은 무엇인가?\n',
#  '캔자스와 그외 지역의 기독교 근본주의자들은 쿠어스 기업의 매우 보수적인 성향으로 보아 다소 뜻밖의 상품인 쿠어스 맥주를 불매하고 있다.\n',
#  '그러나 그 맥주회사는, 디즈니사처럼, 불매운동 지도자인 프레드 펠프스 시니어가 불결한 동성연애자라고 언급한 사람들에게 의료보험의 혜택을 주고 있다.\n',
#  '더욱 더 이상한 것은 침례교도들이 예배 후에 차가운 맥주를 조금이라도 마실 사람들처럼 보이지는 않는다는 것이다.\n',
#  '죠 퓨엔테스 쿠어스 대변인은 철강산업 노동자들과 트럭 운전자들 같은 사람들이 포함된 80년대 후반의 미국 노동 총연맹 산업별 회의의 불매운동이 훨씬 더 심한 타격이었음을 인정한다. 분명히 그것은 그랬었다.\n',
#  '컴퓨터 네트워크 상의 가상공간에 있어서 중국은 실제와는 전도되어 희화된 것처럼 보인다.\n',
#  '수십군데의 웹사이트에는 북경 거리에서는 금지된 비판적인 견해들이 제시된다.\n',
#  '천안문 사태의 유혈 진압 사진들도 공개된다.\n',
#  '그래서 북경 당국이 컴퓨터 가상공간의 힘을 두려워하는가?\n',
#  '지난 달 에 북경 당국은 중국의 30개 성과 지역에 인터넷 접속 서비스를 제공해줄 달라스에 본사를 둔 한 회사와의 거래에 서명했다.\n',
#  '아시아는 전세계 약 1억4천만으로 추산되는 이용자 중 적은 부분을 차지하고 있었다.\n',
#  '그러나 21세기 세계 경제 성장의 중심지로 예상되고 있는 이 지역에서의 이용은 폭발적으로 증가되어 오고 있다.\n',
#  '수년전에 완벽한 접속 서비스를 개시한 인도나 한국에서의 이용자 수는 기하급수적으로 증가했다.\n',
#  '정보를 제공하는 컴퓨터인 인터넷 "호스트" 의 수는 필리핀에서는 5배, 인도네시아에서는 10배 증가했다.\n',
#  '유교에서 공산주의에 이르는 정책으로 인하여 자유로운 의사 교환이 어려웠던 아시아국가들에게 있어 그 영향은 엄청나다.\n',
#  '이것은 정보가 더욱 불길하고, 심지어는 파괴적인 양상을 띠게 될 것이라는 정부의 두려움을 증가시켰다.\n',
#  '사실 많은 나라들이 규제가 심한 섬나라인 싱가포르를 모델로 주시하고 있다.\n',
#  '싱가포르 당국은 1994년에 한 영업용 컴퓨터 통신망에서 8만 개의 파일을 검색함으로서 커다란 소란을 불러 일으켰다.\n',
#  '다섯 개의 음란물을 적발했을 때 그들은 위반자들에게 엄중한 경고장을 보냈다.\n',
#  '그러나 당국은 인터넷의 폭발적인 증가를 따라잡기 힘들어 지고 있다.\n',
#  '싱가포르 국립대학의 한 연구에따르면, 인터넷으로 전달하는 정보의 양은 4배로 늘어났다고 한다.\n',
#  '싱가포르의 경제 입안자들은 싱가포르가 2000년 말까지는 모든 가정과 기관이 중앙 인터넷 접속장치에 연결되는 "전산망의 섬"으로 변모되기를 희망하고 있다.\n',
#  '그것은 검열관에게는 악몽과 같은 일이다.\n',
#  '싱가포르는 단지 "공공분야"만을 단속할 계획이다.\n',
#  '인도네시아에서는 군부에서 거부감을 갖는 정보는 삭제하겠다고 제안하고 있다.\n',
#  '그러나 현재로서는 정부에 찬성하는 정보를 많이 제공하는데 촛점을 맞추고 있다.\n',
#  '중국에서도 역시 정부는 단지 컴퓨터 통신상의 반체제 인사들을 쫓아내려고만 할 지도 모른다.\n',
#  '북경 당국은 심지어 계획된 "행동 규제조항"을 발간하기 전에 새로운 인터넷 서비스를 널리 광고하고 있다.\n',
#  '학문적인 교류와 새로운 사업의 기회를 장려하고 있는 것이다.\n',
#  '북경은 심지어 자체 공식 전자 잡지인 "더 차이니즈 스칼라"를 선보였다.\n',
#  '어떤 사람들은 너무 과민반응하고 있는 것이라고 말한다.\n',
#  '중국의 인터넷에 대한 두려움은 많이 과장되어 왔다.\n',
#  '많은 반체제 인사들이 십년동안 컴퓨터 통신을 해오고 있으며, 실제로 그들은 아무것도 뒤엎은 것이 없다.\n',
#  '환경 보호가 이제 더 이상 경제 개발의 종말을 의미하지는\xa0않는다;\n',
#  '상업과 지구가 모두 번성할 수 있다.\n',
#  '1976년 이래로 아마존 정글의 10% 내지 12%가 파괴되어 왔다.\n',
#  '소 목장주, 금광 채굴업자, 그리고 농장주들은\xa0필요악이라고 말한다.\n',
#  '돈을 벌고 싶으면 토지를 개간해야 한다.\n',
#  ...]

# %%
eng_sentences
# Out:
# ['Much of personal computing is about "can you top this?"\n',
#  'so a mention a few weeks ago about a rechargeable wireless optical mouse brought in another rechargeable, wireless mouse.\n',
#  "Like all optical mice, But it also doesn't need a desk.\n",
#  'uses gyroscopic sensors to control the cursor movement as you move your wrist, arm, whatever through the air.\n',
#  "Intelligence officials have revealed a spate of foiled plots on ships in Southeast Asia and are warning that a narrow stretch of water carrying almost one third of the world's maritime trade is vulnerable to a terror attack.\n",
#  "After learning of several foiled al Qaeda attempts on U.S. and commercial ships in the area, experts are warning that the terror network still wants to cripple the global economy, the world's economic jugular vein in Southeast Asia is at risk.\n",
#  'Caffeine can help increase reaction time and improve performance for military servicemen who must perform complex tasks or who need help staying alert for longer periods of time, according to a new report by the National Academy of Sciences.\n',
#  '"Specifically, it can be used in maintaining speed of reactions and visual and auditory vigilance, which in military operations could be a life or death situation," according to the report.\n',
#  '"Something that will boost their capabilities at crucial moments is very important."\n',
#  'Researchers are already exploring ways to put caffeine in nutrition bars or chewing gum as alternatives to coffee, Archibald said.\n',
#  'A similar dose of caffeine, about 200-600 mg, also appears effective in enhancing physical endurance and may be especially useful in returning some of the physical endurance lost at high altitude, the study found.\n',
#  'The Institute of Medicine is part of the National Academy of Sciences, a private organization chartered by Congress to advise the government on scientific matters.\n',
#  'thanks to robust demand in Asia, boosting the trade surplus to 1.055 trillion yen ($8.47 billion), the Ministry of Finance said.\n',
#  'But the prospect of a slowing U.S. economy and weak demand at home overshadowed any optimism for the months ahead.\n',
#  'More than 750 hostages were rescued, including all 75 non-Russians and 25 children, when special forces stormed the building.\n',
#  'Russian special forces used a sedative gas before storming the theatre.\n',
#  'Many captives were taken to hospital suffering from the effects of the chemical.\n',
#  "marking a historic shift to the left for Latin America's largest country.\n",
#  "hours after Silva's Workers Party had declared their candidate the winner.\n",
#  "Thousands of Silva supporters gathered in the streets of Sao Paulo and Rio de Janeiro, waving his party's red flag in celebration.\n",
#  'Amid mounting pressure on North Korea to abandon its nuclear weapons program Japanese and North Korean diplomats have resumed talks on normalizing diplomatic relations.\n',
#  "The two days of meetings in the Malaysian capital, Kuala Lumpur, are expected to be dominated by Japanese concerns over the North's bomb-making efforts, as well as calls for a fuller explanation over the kidnapping of Japanese civilians in the 1970s and 80s.\n",
#  'At least 54 people have been confirmed dead but that figure is expected to rise, possibly to over 100\n',
#  "after a fire tore through a six-storey building in Vietnam's Ho Chi Minh City that housed shops, a disco and several foreign companies.\n",
#  "Initial reports indicated it may have been sparked by a short-circuit in the Blue Disco on the building's second floor.\n",
#  'prevented firefighters from entering the building for about four hours with firefighters taking more than five hours to extinguish the inferno.\n',
#  'Mobile bomb-fighting robots can already inspect suspicious cars, buildings or mail for explosives or hazardous materials, according to Jan Karlsson, an expert at the U.N.\n',
#  'The Geneva-based commission, in its annual study of the industry titled “World Robotics 2001,” said a record 100,000 robots were installed last year, up 25 percent on 1999.\n',
#  '“There is definitely a much higher incentive to invest in automated technology to fight terrorists,” Karlsson said.\n',
#  '“It could be used in post offices, in surveillance of offices after hours and to inspect suspicious cars.”\n',
#  'Postal Service - whose postmaster told a Senate panel that the financial impact of the anthrax crisis could be several billion dollars - uses robots to sort parcels, but other automated equipment sorts letters.\n',
#  'At the same time, labor costs are more and more.”\n',
#  '“For industrial robots, 2000 was the best year ever,” added the Swede.\n',
#  '“Not only in Japan and Europe and North America, but they have also started to take off in some developing countries, for example in Brazil, Mexico, China and South Africa.”\n',
#  'Annual sales of robot units are estimated at $5 billion to $6 billion.\n',
#  'But with the cost of installing necessary software and integration systems, the total robotics market could be worth closer to $25 billion.\n',
#  'About 50 systems of firefighting and bomb-disposal robots have been sold through 2000 in countries including Israel and Britain.\n',
#  'The study, written before the devastating U.S. attacks, predicts sales of 120 systems by 2004.\n',
#  'About 2,300 robots work in demolition, servicing or dismantling nuclear, chemical, waste or other hazardous complexes, the report said.\n',
#  'Another 60 robots work in surveillance.\n',
#  '“Guard robots are used privately and professionally to detect intruders or fire,” Karlsson said.\n',
#  '“The Pentagon have several, and they are used in nuclear plants in the United States and Europe, but the market is still rather marginal."\n',
#  'Five United States Congressmen have written to President Bush urging him to punish North Korea for continuing with its nuclear weapons program and push for a change of government in the isolated Stalinist state.\n',
#  'In a letter to the administration, Republican Senators Jesse Helms, Bob Smith and John Kyl, Republican Representative Chris Cox and Democrat Representative Ed Markey called on the president for the U.S. to provide North Korea with fuel oil.\n',
#  "Four days of peace talks between the Sri Lankan government and Tamil rebels have ended on a high note as both sides bid to end one of Asia's longest-running conflicts.\n",
#  'Both sides declared success in Thailand, after they agreed to set up three committees to look at issues that lie at the heart of the 19-year-old war that has killed nearly 65,000 people and displaced more than 1.5 million.\n',
#  'The government says the new bodies will address ethnic and power-sharing issues and will also oversee a resettlement of refugees and restoration of areas destroyed by the decades-old civil war.\n',
#  'A 194-vehicle pileup on a freeway south of Los Angeles left more than 40 people injured, five seriously, The accident occurred shortly before 7 a.m.\n',
#  'and prompted the California Highway Patrol to close a two-mile stretch of Interstate 710 in both directions Traffic was being diverted to alternate routes.\n',
#  'Thick fog may have been a factor in the accident, California Highway Patrol officers said.\n',
#  'The best man raises his wine glass and out comes a drunken diatribe.\n',
#  "It's a wedding couple's nightmare, but a growing number of love birds are shielding themselves by having Web sites ghostwrite the perfect toast.\n",
#  'For the right price, dozens of sites promise to find the right words for just about any occasion:\n',
#  'But toasts for the happy couple are the most frequent requests.\n',
#  'In a stunning and historical night for the GOP and President Bush, Republicans seized control of the Senate, held onto their majority in the House and savored wins in two hot gubernatorial races.\n',
#  'The Republicans will have at least a 51-seat majority Republicans won at least 226 seats, up from the 223 they had going into the election.\n',
#  "China has unveiled plans for the largest water-diversion in its history and possibly one of the world's most expensive at $60.4 billion.\n",
#  "The project will channel water from the country's longest river, the Yangtze, to three rivers in the north, the Yellow, Huai and Hai, whose basins are running dry.\n",
#  'The ambitious South-to-North Water Transfer Project will move water along three channels linking the wetter flood-prone southern basin to parched northern climes.\n',
#  "This is just one of the latest of China's massive public works projects, recent ones including the Three Gorges hydroelectric dam, a proposed 4,000-kilometer natural-gas pipeline and the world's highest railroad from Qinghai to Tibet.\n",
#  'Authorities from the Water Resources Ministry plan to begin construction next year on the controversial and hugely expensive project.\n',
#  'Vice Minister of the Water Resources ministry Zhang Jiyao said plans for the project would be submitted for approval to the cabinet by the end of the year.\n',
#  'Environmental experts say the new project could cause widespread corruption, human hardship and environmental damage, and could dry up the Yangtze in 30 years.\n',
#  'They urge China to take simpler steps like raising water prices, curbing rampant well-digging, stopping up leaks and improving water treatment.\n',
#  "European officials have expressed concern the U.S. president will now be more emboldened, following his Republican party's mid-term election gains.\n",
#  'Europe and Bush have been at loggerheads over whether the threat of military action should be included in a new U.N. draft resolution on Iraq, and European leaders have also voiced concern about U.S. calls for "regime change" in Iraq.\n',
#  'The two sides have also had spats over a wide range of issues including global warming and the new International Criminal Court.\n',
#  '"Apocalypse Now," Francis Ford Coppola\'s anti-Vietnam War classic, is the greatest film of the past 25 years, according to a survey of British film critics and writers.\n',
#  "Two movies by Martin Scorsese also made the top 10 in the poll released by the British Film Institute's Sight & Sound magazine.\n",
#  'The 50 respondents chose Scorsese\'s "Raging Bull" as the second-best movie of the past quarter-century, followed by Ingmar Bergman\'s "Fanny And Alexander" in third place.\n',
#  'The Philippine Coast Guard and navy frogmen are searching for survivors in Manila Bay Two days after the crash, they had rescued 16 passengers and found 14 others who had died, navy officials said.\n',
#  'Four others are still missing.\n',
#  'Survivors have been taken to hospitals around Manila Bay, a shore region off the Philippine capital of Manila.\n',
#  'Emergency workers and stunned residents across the South and Great Lakes regions picked through shattered homes and buildings after a string of tornadoes left at least 36 people dead and dozens injured.\n',
#  'after more than 70 tornadoes touched down.\n',
#  'Most of those killed were in Tennessee, Following the Iraqi parliament\'s unanimous recommendation to reject the return of U.N. weapons inspectors, he is "looking forward" to receiving the country\'s final decision.\n',
#  'Iraq\'s ambassador to the United Nations, Mohammad Al-Douri, delivered a letter of acceptance to Kofi Annan, telling reporters that "Iraq will not have any mass destruction weapons.\n',
#  'So we are not worried about the inspectors when they will be back in the country.\n',
#  'especially if combined with weight-training, a Harvard study of more than 40,000 men suggests.\n',
#  'High-intensity exercise includes running or jogging at 6 mph, while low-intensity activities include walking at a pace of about 2 mph.\n',
#  'Researchers also have debated whether weight-training has a big impact on the heart, since it does not give the heart and lungs the kind of workout they get from aerobic activities such as brisk walking or running for at least 20 minutes.\n',
#  'But in the Harvard School of Public Health study, men who engaged in weight training for 30 minutes or more weekly had a 23 percent lower risk of heart disease than men who did not pump iron.\n',
#  'The researchers said the benefits may result in part from reductions in blood pressure and body fat achieved through weight training.\n',
#  'Given the independent results from weight training, the researchers theorized that adding weight training to a high-intensity exercise program would reap even greater benefits.\n',
#  'The study is based on medical records and questionnaires given periodically to 44,452 health professionals from 1986 to 1998.\n',
#  'Participants were ages 40 to 75 at the outset.\n',
#  'Heart disease was ultimately diagnosed in 1,700 participants.\n',
#  'Men who ran for an hour or more weekly at 6 mph or more were 42 percent less likely to develop heart disease than non-runners.\n',
#  'Men who did brisk walking at a moderate pace of at least 3 mph for at least a half hour daily were 18 percent less likely to develop heart disease than those who did not.\n',
#  'There were no significant heart benefits found from low-intensity walking.\n',
#  'Gerald Fletcher, an American Heart Association spokesman.\n',
#  'He said the findings correspond with AHA guidelines, which recommend aerobic exercise at least six days a week and weight-training two or three times weekly.\n',
#  'But Fletcher said, "A little is better than sitting in front of the television."\n',
#  'Days before the premiere of "Harry Potter and the Chamber of Secrets," the film\'s producer said it fears pirated copies are showing up on the Internet.\n',
#  'an illegal copy of the film has appeared on the Internet, which often contains bootleg copies of films, even before they hit theaters.\n',
#  "The studio later retracted the statement, saying reports of bootleg copies hadn't been substantiated, but an AP search discovered what appeared to be the movie available on a site hosted in Europe.\n",
#  'it has developed a nuclear weapon.\n',
#  'the country "has come to have nuclear and other strong military weapons to deal with increased nuclear threats by the U.S. imperialists," according to the Yonhap news agency which monitors North Korean broadcasts.\n',
#  'It was unclear, however, whether the report referred to a plutonium- or uranium-based weapon.\n',
#  'despite the high-tech industry\'s downturn, co-founder Bill Gates said as he unveiled a strategy to push "smart" computing technology into everyday gadgets such as alarm clocks and pens.\n',
#  'Gates, who opened the 23rd annual Comdex trade show, said there was a negative perception of high tech following the collapse of the tech bubble about two years ago.\n',
#  "carrying more than 19.6 million gallons of heavy fuel oil sank 130 miles off Spain's northwest coast, leaving Spanish authorities scrambling to protect the coastline in the region where fishing is the primary industry.\n",
#  "The World Wildlife Fund warns that if all of the oil leaked, it would be one of the largest oil spills ever more than twice the size of the 1989 Exxon Valdez spill in Alaska's Prince William Sound.\n",
#  'Space boulders big enough to wipe out a major city slam into the Earth about once every 1,000 years, much less frequently than previously thought.\n',
#  'The revised calculations come from an unprecedented examination of years of data that scour the ground for nuclear explosions.\n',
#  'Choi In Won wants to perfect his badminton game.\n',
#  'Kim So Hyon would just sleep a lot.\n',
#  'The three wage warriors and millions of fellow countrymen are busy spending future leisure time in their heads, as South Korea considers moving from a six-day workweek to the five-day version that is standard in the U.S., Japan and Western Europe.\n',
#  'Korea also hopes to accomplish the shift in apparent defiance of conventional economic logic.\n',
#  'A government proposal, strongly supported by labor unions, calls for employees to work 300 to 500 fewer hours a year\n',
#  'The government thinks it can pull off this trick because it did so once before.\n',
#  'In 1989, South Korea told companies to trim work hours to 2,500 annually from 2,700 without paring their payrolls.\n',
#  "The big difference this time, employers say, is that South Korea isn't the insular, command economy it was in the late 1980s and its workers aren't exploited, underpaid victims.\n",
#  'The economy is far more dynamic, and workers are well organized, politically active and the beneficiaries of wage increases that routinely outpace productivity.\n',
#  "Labor unions say there's never a perfect time, that higher wages will force South Korea to shift into more sophisticated industries and that employees and Korean society will be happier, healthier and more relaxed.\n",
#  "Koreans toil long hours, but they don't necessarily toil effectively.\n",
#  'According to the International Labor Organization, Koreans work 2,474 hours a year, compared with 1,979 for Americans and 1,859 for the Japanese.\n',
#  "But they're also 62% and 45% less productive, respectively.\n",
#  'Sleeping, eating, lounging, Internet shopping, stock trading and card playing are common during workdays that can last from 8 in the morning until 10 at night.\n',
#  "Analysts attribute the widespread mixing of work and play in part to South Korea's rapid shift from farm to factory to fluorescent-lighted offices.\n",
#  '"The U.S. had hundreds of years of commercial activity, while Korea\'s had only a few."\n',
#  'In what was hailed as a "truly defining moment" for NATO, the alliance has formally agreed to invite seven former Communist states to join NATO was as significant to them as the fall of the Berlin Wall.\n',
#  'are due to be admitted to the North Atlantic Treaty Organisation in 2004 after being formally approved by all 19 current members.\n',
#  'The FBI is investigating whether the Saudi Arabian government funneled money to associates of two of the September 11 hijackers.\n',
#  'Findings from an inquiry by the House-Senate Joint Intelligence Committee money from the Saudi Arabian government could have made its way to the two hijackers President Bush signed into law legislation creating a Cabinet-level Department of Homeland Security a move that sets into motion the largest reorganization of the federal government in about half a century.\n',
#  'who has been director of the White House Office of Homeland Security, as his nominee to lead the vast, new department.\n',
#  "The department is a direct result of the September 11, 2001 terrorist attacks, which exposed security lapses and intelligence failures, and led to calls for sweeping changes to the nation's defense, intelligence and law enforcement sectors.\n",
#  'It appears to be "Heartbreak Hotel" for Lisa Marie Presley and Nicolas Cage less than four months after the Hollywood couple tied the knot.\n',
#  'Details were not released about the breakup, but statements from both parties seemed to indicate irreconcilable differences.\n',
#  'President Bush has apologized for the deaths of two South Korean girls more than five months ago.\n',
#  'Mark Walker of the 2nd Infantry Division were acquitted of negligent homicide charges in the June 13 road deaths of Shim Mi-son and Shin Hyo-sun, both 13.\n',
#  'For Park Kang Woo, policy director of the Korean Confederation of Trade Unions, the solution is clear:\n',
#  "Drop working hours to a reasonable level and you'll see fewer accidents and higher productivity.\n",
#  'There is a precedent.\n',
#  'In 1998, Yuhan Kimberly Corp., a maker of household products, switched to a five-day week without paring paychecks.\n',
#  'Accident and defect rates fell and productivity gains were enough to cover the reduced time, a company spokesman said.\n',
#  "Still, the experience of one internationally managed company doesn't reflect what might happen across an entire economy, economists say, and employers are being asked to pay out in advance what could amount to a 15% hourly wage hike for benefits that may not materialize.\n",
#  'Why the hurry to accomplish such a Herculean feat?\n',
#  "Japan took 10 years to make a similar transition starting in 1987, when it had a per capita income of about $19,000, compared with South Korea's $9,700 today.\n",
#  'Greece and Portugal started their switch-overs in 1997, and are giving themselves a decade as well.\n',
#  'And Hong Kong and Singapore are easing in that direction under a more voluntary process.\n',
#  'The government says the move is a way to show that South Korea is a developed nation.\n',
#  "The change also will boost flagging consumption, spur regional tourism and help local economies as city dwellers head for the country to enjoy nature's beauty.\n",
#  '"It\'s politically motivated," said Kim of the Korean Employers Federation.\n',
#  '"It\'s hugely popular, and the government wants to get credit for it, especially with local and national elections coming next year."\n',
#  'Among the many thorny issues is holidays.\n',
#  "Koreans now enjoy 17 national days off, two weeks of annual leave, an added day's vacation per year worked and 12 additional bonus days annually.\n",
#  'Large companies often add three or four more personal days, and women get an additional 12 menstruation days.\n',
#  'Add these to the 52 days gained by not working Saturdays, and South Korea would race to the head of the global vacation class, trumping even the cafe-lounging French.\n',
#  "By some counts, the days-off total could soar as high as 165, compared with France's 145 and the U.S.\n",
#  "Another worry is whether too much relaxation might undermine South Korea's power, accomplishments and work ethic.\n",
#  '"We just can\'t afford to be lazy or relaxed," said Choi In Woong, a civil engineer.\n',
#  '"If we do, the next generation will become even lazier."\n',
#  'Chong Do Won, manager of a small advertising company, frets that all this free time would boost social tension in a country that has traditionally prided itself on its homogeneity.\n',
#  '"People would become very jealous and hateful if one person goes off skiing and the other is sitting in their dingy apartment," he said.\n',
#  '"It\'s a big problem."\n',
#  'The 14-year-old Mir space station will be ditched in February in a controlled descent that will send it hurtling into a remote area of the Pacific Ocean, officials said today.\n',
#  'The decision to abandon the ailing space station was taken at a meeting of the Russian Cabinet.\n',
#  'Officials have wrestled for months over what to do with the Mir, which Moscow can no longer afford to maintain.\n',
#  'President Bill Clinton arrived in Ho Chi Minh City, Vietnam, following a visit to the crash site of a U.S.\n',
#  "Thousands of Vietnamese lined the president's route from Tan Son Nhut Airport to his hotel, many waving and cheering in stark contrast to Clinton's earlier visit to the site where Air Force Capt.\n",
#  'An Internet oversight board gave the Web a new batch of domain names, choosing .biz, .name, .info, .pro, .museum, .aero, and .coop to help ease the dot-com name crunch.\n',
#  'The decisions by ICANN capped a half-decade of discussion about how to relieve the crowded field of addresses ending in .com, which has some 20 million registrations worldwide.\n',
#  'The new suffixes could appear in use by the middle of next year.\n',
#  'Stanley "Tookie" Williams is co-founder of one of the nation\'s most notorious gangs, and a death-row inmate convicted of killing four people in 1981.\n',
#  "He's also a nominee of the 150 people nominated for the 2001 Nobel Peace Prize.\n",
#  'From his tiny San Quentin cell, Williams leads a campaign to stop children from making the same mistakes he did.\n',
#  'He writes gritty books about his experiences as a founder and leader of the street gang, the Crips.\n',
#  "The Florida Supreme Court gave Al Gore a key legal victory in his presidential campaign, ruling that ballots being recounted by hand in three heavily Democratic counties must be included in the state's final vote tally in its election for the nation's 43rd president.\n",
#  "The state's highest court, a panel of seven justices, said those counties, Palm Beach, Broward and Miami-Dade, must complete their recounts and submit results by 5 p.m.\n",
#  'An explosion rocked the Israeli town of Hadera killing at least two and injuring more than 36 people, a local Israeli official said.\n',
#  "Israeli TV reported that a car bomb went off next to a bus on Hadera's main Hanassi Street.\n",
#  'The car that carried the bomb is now a pile of twisted, smoking metal.\n',
#  'The blast was so powerful, it caused the bus to slam into a nearby store.\n',
#  'Several stores also caught fire.\n',
#  'There was no immediate claim of responsibility for the explosion, although "Izz el-Deen al-Qassam", the military wing of the militant Islamic group Hamas, said in a statement today it would bring death to every Israeli home.\n',
#  'After months of speculation, the elusive gizmo referred to as "IT" or "Ginger" has been unveiled to the public.\n',
#  'The ABC television program "Good Morning America" demonstrated the invention Monday, a two-wheeled, self-propelled scooter that can travel at about 12 mph.\n',
#  '"This is the world\'s first self-balancing human transporter," Kamen said.\n',
#  'it has a computer that does what your brain does for you.\n',
#  'It\'s got those tires that do what your feet do for you."\n',
#  'Kamen said the invention - called the Segway HT - will be going out in limited quantities over the next few weeks, and by the end of next year, it should be widely available.\n',
#  'The price is expected to be around $3,000.\n',
#  "Kamen's invention has won over some bigwigs in California's Silicon Valley who have seen Ginger and reportedly thrown money behind it, according to initial reports in January on the news Web site Inside.com.\n",
#  'Investing icon John Doerr has called Kamen a blend of Thomas Edison and Henry Ford.\n',
#  'Apple Computer\'s Steve Jobs was quoted as saying that people will erect entire cities around "IT."\n',
#  "Amazon.com founder and CEO Jeff Bezos has taken a special liking to the invention, featuring it on Amazon's Web site.\n",
#  'News of Ginger was first uncovered when it was revealed that the Harvard Business School Press had offered Kamen $250,000 to chronicle the making of Ginger in a book with the help of a writer.\n',
#  "Kamen's work is based out of a Manchester, New Hampshire, lab called DEKA Research & Development.\n",
#  'the worldwide information technology industry is expected to grow by more than 5 percent next year.\n',
#  'spending on IT and communications resume, driving a worldwide growth rate of 5.8 percent for the industry," said John Gantz, IDC\'s chief research officer.\n',
#  'Still, growth next year is expected to be anemic.\n',
#  'The research firm also cautioned that a prolonged war in Iraq or collapse of the stock markets could limit spending.\n',
#  'entitled "Unexplained Lights," Air Force lieutenant colonel told how he witnessed an object emitting a "red sun-like light" moving through the trees of Rendlesham forest.\n',
#  'He dangled his infant son and his morbidly altered face just gets weirder.\n',
#  'As the trial resumes in a lawsuit filed against the 44-year-old entertainer his erratic behavior has once again eclipsed his musical talent.\n',
#  'About a dozen police and 30 town officials were searching for the monkey, said Shigeru Arai, deputy chief of police in Suwa town, about 160 kilometers northwest of Tokyo.\n',
#  'The attacks began Monday, when the monkey bit 14 women as they put out garbage or left home for work.\n',
#  'Nine more women were attacked Tuesday.\n',
#  'Most of the victims were ages 50 to 80.\n',
#  'The International Atomic Energy Agency called on North Korea to end any nuclear weapon program and open "all relevant facilities" to inspections immediately.\n',
#  'North Korean officials, however, refused that demand.\n',
#  "And the United States has called North Korea's refusal to allow inspectors into its nuclear facilities it will continue to work with allies to convince Pyongyang to give up its nuclear weapons program.\n",
#  'Caffeine is a substance naturally found in coffee.\n',
#  'When caffeine is removed from coffee it is called decaffeinated coffee or “decaf.”\n',
#  'Rheumatoid arthritis is a disease in which the body’s defense system attacks the tissue surrounding the joints, the places where bones are joined.\n',
#  'The disease affects women more than men.\n',
#  'Researchers from the University of Alabama in Birmingham reported their study at the yearly meeting of the American College of Rheumatology in San Francisco, California.\n',
#  'They studied more than 31,000 women between the ages of 55 and 69.\n',
#  'The women were included in the Iowa Women’s Health Study from 1986 through 1997.\n',
#  'The researchers studied 158 women who developed rheumatoid arthritis during that period.\n',
#  'They also studied women who did not develop the disease.\n',
#  'Women who drank four or more cups of decaffeinated coffee a day were two times more likely to develop rheumatoid arthritis than women who never drank decaf.\n',
#  'The women who drank more than three cups of tea a day had a sixty percent lower chance of developing the disease than those who never drank tea.\n',
#  'Researchers from Boston University in Massachusetts reported about another study.\n',
#  'It involved rheumatoid arthritis among 64,000 black women.\n',
#  'The women were involved in the Black Women’s Health Study that began in 1995.\n',
#  'The researchers found that drinking more than one cup of decaffeinated coffee a day seemed to increase by four times the chance of developing the disease.\n',
#  'However, in this study, drinking tea seemed to increase the chance of developing rheumatoid arthritis.\n',
#  'The researchers said they believe these are the first studies to show a link between decaf coffee and rheumatoid arthritis.\n',
#  'But they said people should not stop drinking decaf or tea until more studies are done.\n',
#  "When it comes to DNA, there's not that much difference between mice and men.\n",
#  'Mice and humans each have about 30,000 genes, yet only 300 are unique to either organism.\n',
#  'Both even have genes for a tail, even though it\'s not "switched on" in humans.\n',
#  'The mouse is the only mammal, whose genome has been sequenced.\n',
#  "and Larry Lindsey, the White House's top economic adviser, in a dramatic shakeup of the Bush administration's team charged with reviving the nation's troubled economy.\n",
#  'No successors have been announced.\n',
#  "Presidential spokesman Ari Fleischer wouldn't comment directly when asked if the two were forced out, saying only that each had resigned.\n",
#  'could return to your kitchen table not as leftovers, but as plastic wrap.\n',
#  'Pentagon officials said that U.S. military weapons specialists have found at least a dozen Scud missiles several hundred miles off the coast southeast of Yemen in the Indian Ocean.\n',
#  'But U.S. officials said there is no indication the ship was headed to Iraq.\n',
#  'Scuds are the type of ballistic missiles that Iraqi leader Saddam Hussein used to attack both Saudi Arabia and Israel during the Persian Gulf War.\n',
#  'may have come up with the most attentive and perhaps honest car dealer ever in its child-size walking robot Asimo.\n',
#  'how to walk, climb stairs and recognize voices.\n',
#  'The robot is used as a promotional tool, reciting information about cars in showrooms and appearing in commercials and at Honda events.\n',
#  "never ask a question to which you don't know the answer.\n",
#  'Diplomats generally operate on the same basis.\n',
#  'So when the Bush Administration presented evidence to North Korean leaders that their country was developing nuclear weapons, it expected the regime to lie about it.\n',
#  'A day later came the shocker.\n',
#  '"Yes, we\'ve been secretly working to produce nukes," a top aide to "Dear Leader" Kim Jong Il told astonished U.S. envoy James Kelly.\n',
#  'And, he added, "we\'ve got more powerful weapons"\n',
#  'presumably meaning biological and chemical agents.\n',
#  'He was not apologetic at all, says a U.S. official, but "assertive, aggressive about it."\n',
#  'Tightly controlled countries like North Korea typically stonewall such sensitive inquiries.\n',
#  'So the admission did more than just confirm long-held suspicions in Washington that North Korea, a charter member in Bush\'s "axis of evil," had pursued weapons of mass destruction despite a 1994 agreement to stop.\n',
#  'Why, everyone wondered, was Kim confessing now?\n',
#  'And why had Bush pressed the issue, when he was already immersed in two major global confrontations?\n',
#  'No wonder the Administration sat on the news for 12 days while it scrambled to figure out how to downsize the crisis.\n',
#  'By the time the Bush team went public with the news last week, it was also trying to reassure citizens and allies that this standoff would be addressed, at least for now, with diplomacy, not military might.\n',
#  'So who assisted the Koreans?\n',
#  "Pakistan had the Bomb but no missiles to deliver it, and North Korea is the world's most active missile proliferator, especially to customers who can't shop elsewhere.\n",
#  'In 1998 Pakistan tested a homemade Ghauri medium-range ballistic missile that the U.S. believes originated in North Korea.\n',
#  'War with North Korea, Bush told his aides, was out of the question.\n',
#  "He could not let Kim alter the fragile balance of power on the Korean peninsula, where 37,000 U.S. troops stand across the DMZ from a million-man army close enough to destroy Seoul, South Korea's capital, in a blitzkrieg.\n",
#  "By Bush's own doctrine of pre-emption, the U.S. should strike against any state with weapons of mass destruction and an irresponsible dictator.\n",
#  'But the consequences of attacking Pyongyang are unacceptable.\n',
#  'What Bush apparently never anticipated was a brazen admission that the evidence was right.\n',
#  'Scientists in Britain and the United States shook hands.\n',
#  'No big deal, one might think, but the men in question were 3,000 miles apart, connected only by the Internet.\n',
#  'one in London and one in Boston\n',
#  'picked up a computer-generated cube between them and moved it, each responding to the force the other exerted on it.\n',
#  '"We can actually feel the object being pushed against our hands.\n',
#  'UCL said the secret behind the technology is the speed at which the successive impulses are sent.\n',
#  'Not only can scientists feel the force being exerted by colleagues across the Atlantic Ocean, they can also feel the texture of the object they are feeling.\n',
#  'The implications of the experiment could be vast, said UCL, which described the event as the world\'s "first transatlantic handshake over the Internet."\n',
#  'For example, trainee surgeons could use it to practice operations via the Internet.\n',
#  'It would also have recreational uses, allowing people to touch and feel each other over the Internet.\n',
#  '"I don\'t think it\'ll be available to the public for years\n',
#  'at least five years," Jordan said.\n',
#  'That is greater than the $49.0 billion in imports that Japan took from the United States and the $36.6 billion it took in from the European Union.\n',
#  'Need to pay down credit card debt?\n',
#  'Desperate for money for music lessons?\n',
#  'Simply tired of working and too embarrassed to stand on the corner with a tin cup?\n',
#  'after Web strangers contributed more than $13,000 to her cause, according to her Web site.\n',
#  'Yahoo started a "begging" category But the recent spike in activity and diversity of sites led Yahoo to rename the category e-panhandling.\n',
#  "The United States says it had no intention of attacking North Korea but has rejected Pyongyang's call for negotiations saying North Korea must first take concrete steps to end its nuclear weapons program.\n",
#  '"The issue of a treaty suggests that we should pay something right now for their misbehavior," Secretary of State Colin Powell said.\n',
#  '"What we can\'t do and won\'t do is reward North Korea for their behavior."\n',
#  "A herd of wild elephants driven berserk by country liquor trampled to death six people, among them four children, during a rampage in India's northeastern state of Assam.\n",
#  'The animals came out of the forest, and drinking country liquor stored by villagers in Tinsukia.\n',
#  'after consuming huge quantity of country-made liquor, killing six people on the spot.\n',
#  'President Bush announced plans to deploy the first phase of a limited system designed to protect the United States against a ballistic missile attack.\n',
#  'the United States will take every measure against what is perhaps greatest danger of all that may result from hostile states or terrorist groups armed with weapons of mass destruction," Bush said in a written statement.\n',
#  'Army used a high-energy laser to shoot down an artillery shell in mid-flight in a defense industry breakthrough, the Army and the manufacturer said.\n',
#  'The Army and TRW Inc., which developed the weapon, said in a joint statement that the laser tracked, locked onto and fired a burst of concentrated light energy photons at the speeding shell over the White Sands test range in New Mexico.\n',
#  'The Mobile Tactical High Energy Laser (MTHEL) is being developed by TRW for the Army and the Israeli Defense Ministry.\n',
#  'Lasers have been used in past tests at the range to shoot down slower Katyusha Rockets similar to those fired at Israel by militant guerrilla groups in neighboring Lebanon.\n',
#  '"This shootdown shifts the paradigm for defensive capabilities.\n',
#  'We\'ve shown that even an artillery projectile hurtling through the air at supersonic speed is no match for a laser," said Army Lt.\n',
#  'Joseph Cosumano, head of the missile defense command.\n',
#  '"Tactical high energy lasers have the capacity to change the face of the battlefield," he added.\n',
#  'The laser was fired from a static testbed in a carefully controlled test, but TRW officials said they looked forward to producing a truly mobile version as the program progressed.\n',
#  'In earlier tests in 2000 and 2001 the testbed focused on the threat of artillery rockets and shot down 25 Katyushas fired singly and in salvos.\n',
#  'The U.S. military has shot down dummy intercontinental missile warheads in tests both inside and outside the atmosphere using projectile weapons and is also examining the possible use of long-range lasers to burn up such warheads in flight.\n',
#  "The Nasdaq composite and the Standard & Poor's 500 index The retreat accelerated for blue chips after Hans Blix, the U.N. chief weapons inspector, said he was not satisfied with Iraq's dossier on its weapons program.\n",
#  "Concern is mounting over North Korea's seeming determination to press ahead with reactivating its mothballed nuclear facility in defiance of an international agreement.\n",
#  'it had cut most of the seals that international inspectors placed on a deactivated nuclear reactor and has blocked monitoring equipment at the reactor.\n',
#  'the Nyongbyong reactor is capable of producing weapons-grade plutonium.\n',
#  'The top Chinese official in Xinjiang has vowed to crack the whip on separatists and terrorists just a few days after an American human rights team visited the autonomous region.\n',
#  'District Judge J. Frederick Motz handed down a preliminary injunction at the request of Sun Microsystems Inc.\n',
#  'Microsoft had "leveraged its PC monopoly in which it is unfairly advantaged."\n',
#  'Side effects from the cancer-fighting drug Gefitinib have resulted in 124 deaths in Japan.\n',
#  'The dead were among 494 patients who have developed debilitating lung disorders including interstitial pneumonia blamed on the drug.\n',
#  "The figure is up from 39 deaths by the drug's manufacturer, Anglo-Swedish pharmaceutical giant AstraZeneca.\n",
#  'Gefitinib has been taken by at least 10,000 cancer patients since it was cleared for use in Japan in July.\n',
#  'President Bill Clinton has unveiled a $3.5 billion five-year program called "Empowerment Zones" which is designed to revive America\'s troubled inner cities.\n',
#  'Depressed urban areas like south central Los Angeles which was devastated by riots several years ago will be targeted for government assistance as well as business investment.\n',
#  'Smaller sums would go to 95 other urban and rural areas.\n',
#  'The program rivals any of the so-called "Great Society Antipoverty" programs of the 1960s, but will this one succeed where the others failed?\n',
#  'In remarks at a White House ceremony the president eluded to widespread skepticism about the workability of another costly federal program to save the cities.\n',
#  'In 1949, then-President Harry Truman launched his urban renewal initiative.\n',
#  'Subsequent administrations spent billions of dollars on programs with names like "Community Action," "Model Cities," "Community Development Block Grants," and "Urban Development Action Grants."\n',
#  'Today, though, most of the inner cities remain essentially, shockingly unchanged, in some cases even worse.\n',
#  'George Peterson, urban policy analyst for the Urban Institute in Washington, D.C., describes the typical inner city landscape beset by crime, poverty and neglect.\n',
#  '"Two-thirds of the lots are vacant.\n',
#  "A large part of the population is a street population that doesn't live in the houses at all.\n",
#  'And you have a feeling of very intense personal fear not just because you\'re an outsider, but the people that live there have a fear that pervades their lives."\n',
#  'And it\'s a frustration of not being able to be part of a community reinforced by this physical desolation, that once you walk in an area like this, you\'ll never forget it."\n',
#  "In our Focus report, Bob Dody examines the plight of U.S. cities in the 1990s and what's being done to revive them.\n",
#  'Conference of Mayors in Washington, U.S.\n',
#  '"Their policy prescription is simple.\n',
#  'There are things that are working."\n',
#  'But the evidence as a whole indicates otherwise.\n',
#  '"Civilization as we know it is beginning to unravel around us and an increasing violence is a primary cause.\n',
#  'And there\'s no doubt about it from my over thirty years of experience in law enforcement and now the last two years as mayor of San Francisco."\n',
#  'Violent crime is the number one problem in American cities, like Chicago where Matt Rodriguez is the police superintendent.\n',
#  '"Chicago experienced a 9% decline in homicides last year, but murders of young people, ages 11 to 20, rose to record levels.\n',
#  'Three out of every ten murders in Chicago now involve victims in this age group.\n',
#  'And 92%, 92% of them are killed with firearms.\n',
#  'Nationwide children under the age of 18 are 244% more likely to be killed by guns today than they were in 1996."\n',
#  'John Rich sees many crime victims in the emergency room.\n',
#  '"In a given evening there may be three or four individuals who come in, who\'ve been shot or stabbed as well as people with a number of other health problems.\n',
#  'I mean, many times what happens, specifically as the people are taken into the trauma room, many times rushed up to the operating room, their wounds are cared for, they\'re hospitalized many times with severe, severe injuries such that they require sometimes life support for a period of time."\n',
#  'Louis Mayor Freeman Bosley Jr., chairman of a task force on hunger and homelessness for the U.S.\n',
#  'Conference of Mayors, offers a startling profile of many people who are homeless.\n',
#  '"Over 50% of the people that are homeless are employed.\n',
#  "The salaries or the wages that they're making are just so, so little that they cannot afford basic rent or can't afford to buy a home.\n",
#  'A lot of times when people think about someone being homeless, they think about the man sleeping on the park bench or the lady walking down the street with the bags.\n',
#  '43% of the people that are homeless are women with at least two children.\n',
#  'So those are the invisible homeless people that we really don\'t see, and that\'s one of the things that we really need to be focusing on."\n',
#  'A car rental agent tries to sell the customer / a collision damage insurance / costing from an extra $3 to $19\xa0a day.\n',
#  'But many car renters are already protected.\n',
#  'Others are covered / because they use a major credit\xa0card.\n',
#  'They become tempting targets / for an aggressive rent-a-car sales force, / often on commission to sell insurance / no matter what.\n',
#  'Most car rental companies are self-insured / and simply getting a free ride / from consumers.\n',
#  'A House commerce subcommittee / wants a national ban / on the sale of collision damage insurance.\n',
#  'The large car rental companies are for it.\n',
#  '/ Several smaller ones are not.\n',
#  'Neither was testimony from astronauts or even photographic evidence.\n',
#  'So NASA has commissioned a mini-book to show that, indeed, Americans did land on the Moon.\n',
#  'Most humans on Earth accept that U.S. astronauts first got to the moon aboard the Apollo 11 mission on July 20, 1969.\n',
#  "But those who don't believe have created a sort of cottage industry of doubt, and that is what NASA wants to combat.\n",
#  'The National Aeronautics and Space Administration has dealt with the controversy for decades, without much fanfare, but Roger Launius, NASA\'s former chief historian, said the questioning intensified in 2001 after the Fox television network aired "Conspiracy Theory:\n',
#  'Did We Land on the Moon?"\n',
#  'Those who doubt the Apollo moon landings maintained the United States lacked the technology to send humans to the Moon and was so desperate to appear to win the space race against the Soviet Union that it faked the moon mission on movie sets.\n',
#  'The doubters said the fake was done so poorly that there is ample evidence of fraud, including a picture of astronauts planting the American flag that allegedly shows the flag rippling in the wind.\n',
#  'The skeptics contended there can be no breeze on the moon, so the picture must have been faked.\n',
#  'But when the astronauts struggled to plant the U.S. flag in the lunar surface, they twisted it around a bit before it stuck, and that naturally created ripples in the flag.\n',
#  'But on the Moon, the rippling went unchecked, making it look as if it were being carried by the wind.\n',
#  "The site's creator, astronomer Phil Plait, was blunt in his condemnation of the doubters, whom he calls conspiracy theorists.\n",
#  '"The craziness involves people who think that the NASA Apollo Moon missions were faked," Plait said on the site.\n',
#  '"There are lots of rumors spreading around about this, and rest assured they are all completely false.\n',
#  'In 1994, / a Japanese business bought Locke Company, / saving it from a shutdown.\n',
#  "A joint venture with Japan's Nippon Steel in 1995 / helped Inland survive / and produce higher-quality steel.\n",
#  'From the IBM Building to Rockefeller Center, / foreign investors are snapping up American assets.\n',
#  'Even the Pillsbury doughboy may acquire a British accent, / the company having been sold to British interests.\n',
#  'It being fine, they went hiking.\n',
#  'Foreigners now control 10 percent of American manufacturing / and 20 percent of American banking.\n',
#  'But the growing international presence / in plants, real estate, stocks and bonds / and in American branches of foreign-owned banks / troubles many business and trade experts.\n',
#  'The issue of / whether foreign investment in the United States is harmful or helpful / is still unresolved.\n',
#  'However, / there is nothing new / about the selling of American assets.\n',
#  'There is something wrong with the machine.\n',
#  "We can't think of anything better.\n",
#  "It's been going on / since the Indians traded Manhattan to the Dutch / for knives, trinkets and a few pieces of cloth.\n",
# ...
#  'New industries have sprung up everywhere, some for domestic processing of agricultural commodities and some for import substitution.\n',
#  'As well several million people have migrated to urban areas in search of income and employment.\n',
#  'All of these changes have had a significant environmental impact particularly on the quality of water, and the loss of both flora and fauna in relatively untouched areas.\n',
#  'Bio-diversity has been reduced.\n',
#  'Atmospheric pollution by particles and chemicals, and problems in the disposal of solid wastes are further environmental consequences of growth.\n',
#  'Many changes are taking place / in "food styles" in the United States.\n',
#  'The United States is traditionally famous / for its very solid and unchanging diet / of meat and potatoes.\n',
#  'Now / we have many different alternatives to choose from :\n',
#  'Ethnic restaurants and supermarkets / are commonplace in the United States.\n',
#  'Because the United States is a country of immigrants, / there is an immense variety.\n',
#  'Health food gained popularity / when people began to think more seriously / about their physical well-being.\n',
#  '/ i.e., / there are no preservatives to help it last longer / or other chemicals to make it taste or look better.\n',
#  'Fast-food restaurants are now expanding rapidly / all over the country.\n',
#  '/ In the United States, / speed is a very important factor.\n',
#  "People usually have a short lunch break / or they just don't want to waste their time eating.\n",
#  "America's attitude toward food / is changing, too.\n",
#  '/ The traditional big breakfast and dinner at 6 :\n',
#  'Like so many people in other cultures, / many Americans are taking time / to relax and enjoy the finer tastes at dinner, / even if they still rush through lunch / at a hamburger stand.\n',
#  'The introduction of environmental rules is a painful process.\n',
#  'The evaluation of the environmental impact of large-scale projects necessarily uses environmental expertise intensively.\n',
#  'Price incentives have to be examined carefully to ensure that they do not lead to detrimental environmental practices.\n',
#  'Commercial waste, for example, has to be costed as a cost of production component.\n',
#  'Subsidized rates for water supply and energy lead to resource waste.\n',
#  'Indonesia is looking for new technologies and management systems for waste minimization, treatment and, where possible, recycling or reuse.\n',
#  'There is greater coordination between those who protect the environment and those who cause it problems.\n',
#  'Regulations for monitoring and enforcing of environmental policies are also being strengthened.\n',
#  'In successive five-year development plans, Indonesia has acknowledged the strains being placed on the environment by rapid economic growth.\n',
#  'The Basic Law on Conservation stresses community participation and provides the basis for environmental impact assessment.\n',
#  'In complete contrast, the tiny island republic of Singapore, which generates a large variety of toxic wastes from its heavy engineering and manufacturing industries, has tough environmental laws.\n',
#  "Singapore's 2.7 million people live in 626 square kilometers.\n",
#  'About 48% of the island is used for commercial, residential and industrial purposes.\n',
#  'Around 12% is used for agriculture, while the remaining 40% comprises forests, reserves and other non-built up areas.\n',
#  'Important sectors of the Singapore economy include manufacturing, trade, financial and business services, transport and communications.\n',
#  'Heavy engineering and manufacturing are mainly located in the Jurong Industrial Estate at the southwestern area of the island.\n',
#  'Clean industries such as light engineering and electronics are scattered in areas near population centers.\n',
#  'The Pollution Control Department of the Ministry of the Environment controls toxic wastes, and the control begins when a new factory is at the planning stage.\n',
#  'Singapore generates a variety of toxic wastes, such as waste oil, spent solvent, spent enchant and waste sludge.\n',
#  'Industries which do not have such facilities are required to engage approved waste disposal contractors to collect their wastes for recycling or treatment.\n',
#  'Recovery and reuse of wastes is encouraged as this reduces the amount disposal.\n',
#  'Wastes that cannot be recycled must be treated and rendered safe for disposal.\n',
#  'Singapore uses various methods and technologies for treatment and disposal of toxic wastes:\n',
#  '- Biological treatment for biodegradable liquid wastes\n',
#  '- Physical and chemical treatment\n',
#  '- Fixation or immobilization, which binds the toxic\n',
#  'Most liquid wastes are treated by in-house treatment plants.\n',
#  'Aqueous wastes, after treatment are normally discharged into the sewer for further treatment at sewage treatment works.\n',
#  'Elsewhere in the region, Hong Kong generates 390,000 tons of air pollution a day, which is roughly divided into sulphur dioxide, nitrogen dioxide and carbon monoxide, plus uncountable tons of suspended particulate.\n',
#  "The territory is also undergoing what is considered the world's largest construction boom.\n",
#  'Entire islands and mountains have disappeared to be used in land reclamation sites and for the new Chek Lap Kok airport.\n',
#  'In just one aspect of the construction, 70 million cubic meters of soft marine mud must be dredged from the seabed and replaced with 76 million cubic meters of sand excavated from other marine locations.\n',
#  "However, contractors must satisfy the strict requirements of Hong Kong's Environmental Protection Department.\n",
#  "The department has mandated 60 water monitoring stations covering Hong Kong's territorial waters and two boats to monitor dissolved oxygen, turbidity, suspended solids and temperature.\n",
#  'The dredgers working on the airport and related projects are also obliged to dispose of marine mud in designated sites.\n',
#  'They were fitted with satellite navigation positioning devices to make sure that they complied with this regulation.\n',
#  "In the Caucasus region of the Soviet Union, / nearly 50 out of every 100,000 people / live to celebrate their 100th birthday, / and many don't stop at 100!\n",
#  "/ But these Soviet old people aren't alone.\n",
#  'These peoples remain healthy in body and spirit / despite the passage of time.\n',
#  'What accounts for this ability / to survive to such old age, / and to survive so well?\n',
#  'First of all, / hard physical work is a way of life / for all of these long-lived peoples.\n',
#  'Another factor / that may contribute to the good health of these people / is their isolation.\n',
#  'They never eat more food / than their bodies need.\n',
#  'It is clear that / isolation from urban pressures and pollution, / clean mountain air, / daily hard work, / moderate diets, / good genes, / and a youthful approach to life / all contribute to the health and remarkable long life / of all these people.\n',
#  "- I've seen some weird stuff.\n",
#  '- Like little lights flopping around in the sky.\n',
#  "- They're working with unearthly technologies out\n",
#  '- The most important thing that... to remember when\n',
#  'Nevada Highway 375 shoots across the high desert landscape in what seems like an endless straight line.\n',
#  "It might as well be a road to the twilight zone because it takes us to a place that doesn't exist.\n",
#  'Somewhere beyond these mountains, two and a half hours outside of Las Vegas, there is a secret airbase where spy planes like the Stealth Fighter and the Blackbird first tested their wings.\n',
#  "You won't find the base on any map, but you will find it in these old satellite pictures we discovered, taken by both the Soviets and the U.S. government.\n",
#  'We see runways, buildings and what looks like large trenches.\n',
#  'What do people do there?\n',
#  'For some unofficial answers, we stopped at the nearest town we could find:\n',
#  "one dog, one flagpole and one bar called the Little A'le'Inn.\n",
#  "- There's things over there that... would boggle\n",
#  "- And I think there's a lot of aliens out there.\n",
#  "- You see a lot of different things that sometimes it's\n",
#  '- not wise to talk about.\n',
#  'People here tell us about seeing strange lights in the sky and about rumors of captured UFOs stored in secret hangars.\n',
#  'But just down the road, we hear a different story at the Area 51 Research Center.\n',
#  '- The alien stories that emerge around here, most of\n',
#  'Glen Campbell quit his job with a computer company to work full time uncovering the inner workings of Area 51.\n',
#  '- This is the best publicized secret base in the\n',
#  "- country, yet the government won't acknowledge\n",
#  '- How long have you been looking into this base?\n',
#  "- I've been here for two years.\n",
#  '- And what do you know about what happens in that\n',
#  "- I really don't know.\n",
#  'I know some of the routine procedures\n',
#  "But I don't know what's going on in\n",
#  "- there, and frankly a lot of the workers don't know\n",
#  "- what's going on in there.\n",
#  "It's a holdover of the Cold War.\n",
#  'the perfect place for a government to keep its secrets and, allegedly, the perfect place to commit a crime.\n',
#  'Base workers, risking imprisonment, came forward to tell us how government contractors allegedly used Area 51 as a secret dumping ground.\n',
#  'They describe how under armed guard classified materials were dumped into large open trenches and set on fire.\n',
#  'The workers tell us they developed health problems after breathing the smoke.\n',
#  'They say their complaints were ignored, and requests for protective clothing were denied.\n',
#  'Law professor Jonathan Turly represents Mrs.\n',
#  'Frost and base workers in a suit against the military.\n',
#  "- We're only asked one question to this government\n",
#  '- And what did they say to you?\n',
#  '- They said that "we don\'t understand the question"\n',
#  '- admit that it exists?\n',
#  '- Once you admit that the base is there, you become\n',
#  '- liable for any crimes that may have gone on there.\n',
#  'We followed Campbell and about 30 other amateur spies to a ridge on public land where part of Area 51 is actually exposed to public view.\n',
#  '- What do you think is hiding behind that ridge?\n',
#  'Just make yourself comfortable and enjoy the scenery.\n',
#  '- Here, honey, or over there?\n',
#  '- You can see some of them right now.\n',
#  '- Yeah, I can see them.\n',
#  'With a pair of binoculars, the nondescript buildings and hangars we found are surprisingly easy to see.\n',
#  '- The government gets to spy on us all the time,\n',
#  '- now we can spy back.\n',
#  "But, as it turned out, we weren't the only ones lurking in the desert that day.\n",
#  'Guards in white vehicles appeared in the distance, watching us as we watched the base.\n',
#  '"Disney thinks that they are so big we can\'t hurt them.\n',
#  'But when you get too big for your britches, you\'ve got problems coming."\n',
#  'Why target a company that can be nauseatingly wholesome?\n',
#  'Because Disney is producing entertainment that AFA believes morally suspect.\n',
#  'Worse, Disney has extended health benefits to the live-in partners of gay employees.\n',
#  'As Wildmon mobilizes his zealots, is Mickey quaking in his oversize shoes?\n',
#  'Says spokesman John Dreyer with a shrug:\n',
#  'Disney is not alone.\n',
#  'his outfit was boycotting the retailer because its Waldenbooks division, now spun off, was selling Playboy\n',
#  'than AFL-CIO members got their noses out of joint because Kmart buys ads in the Detroit News, where a nasty strike is in progress.\n',
#  'Want to attract boycotters?\n',
#  "McDonald's was for years dogged by environmentalists who spread a false but devilishly persistent rumor that Big Macs contained beef from cows raised on land cleared from Latin American rain forests.\n",
#  "Sighs McDonald's spokesman Chuck Ebeling:\n",
#  '"With 10,000 locations nationwide, we\'re a lightning rod for the issue."\n',
#  "The irony is that by the time a company gets big and visible enough to make irate consumers vote with their feet, it's too big for a boycott to affect it much.\n",
#  'In October, a coalition of dairy farmers, consumer groups, and environmentalists in Wisconsin announced a boycott of Monsanto, claiming that its genetically engineered products are unsafe.\n',
#  "Monsanto was unaware of the boycott until a reporter called the company's headquarters in St.\n",
#  "And what's the point in boycotting a product you never use anyway?\n",
#  'Christian fundamentalists in Kansas and elsewhere are swearing off Coors beer, a seemingly odd choice given the highly conservative bent of the Coors family.\n',
#  'But the brewer, like Disney, now buys health insurance for people whom boycott leader Fred Phelps Sr.\n',
#  "Odder still, Baptists don't seem to be the types who knock back a few cold ones after church.\n",
#  "Coors spokesman Joe Fuentes allows as how the AFL-CIO boycott of the late '80s, which included people like ironworkers and truck drivers, was a far greater blow.\n",
#  'In cyberspace, China seems an upside-down caricature of the real thing.\n',
#  "Dozens of Web sites offer critical views that are forbidden on Beijing's streets.\n",
#  'Pictures of the bloody Tiananmen crackdown are available.\n',
#  'So does Beijing fear the power of cyberspace?\n',
#  'Last month, Beijing signed a deal with a Dallas-based firm that will provide Internet access in all 30 province and regions of China.\n',
#  'Asia accounted for just a small fraction of the estimated 140 million users worldwide.\n',
#  'But usage in the region, which is expected to be the epicenter of global economic growth in the 21st century, has exploded.\n',
#  'In India and South Korea, which a few years ago opened up full service, the number of users has increased exponentially.\n',
#  'The number of Net "hosts"\n',
#  'The implications are enormous for Asian nations, where doctrines from Confucianism to communism militate against the free circulation of ideas.\n',
#  'That has fed a fear among governments that information would take on a more sinister, even subversive aspect.\n',
#  'Indeed, many look to Singapore, that unrepentant island of discipline, as a model.\n',
#  'Singapore authorities caused an uproar in 1994 by searching 80,000 files on a business network.\n',
#  'When they uncovered five pornographic images, they sent stern warnings to the offenders.\n',
#  "But the authorities have not been able to keep up with the Net's explosive growth.\n",
#  'The amount of data moving on the Net quadrupled, according to a National University of Singapore study.\n',
#  'Singapore\'s economic planners hope to turn the nation into a "wired island" in which every home and institution is connected to a central Internet gateway by the end of the year 2000.\n',
#  "That's a censor's nightmare.\n",
#  'Singapore plans to police only "public areas."\n',
#  'In Indonesia, the military has proposed "blacking out" objectionable information.\n',
#  'But for now it has focused on pumping out progovernment information.\n',
#  'In China, too, the government may simply drown out the cyberdissidents.\n',
#  'Beijing has widely advertised the new Net services even before issuing a planned set of "behavior regulations."\n',
#  'It is encouraging scholarly exchanges and new business opportunities.\n',
#  'Beijing has even launched its own official electronic magazine, The Chinese Scholar.\n',
#  "Some say it's overreacting.\n",
#  "China's fear of the Internet has been much exaggerated.\n",
#  "Many of these dissident groups have been online for a decade, and they haven't really subverted anything.\n",
#  'Environmental protection no longer means / an end to economic development;\n',
#  '/ both commerce and the planet can prosper.\n',
#  'Ten to twelve percent of the Amazon jungle / has been destroyed since 1976.\n',
#  '"A necessary evil," / say the cattle ranchers, gold miners and\xa0plantation owners.\n',
#  'If you want to make money, / you have to clear land.\n',
#  ...]

# %%
# 2. 중복 제거
data_pairs = list(set(zip(kor_sentences, eng_sentences)))

# %%
# 3. 전처리 함수 정의
def preprocess_kor(sentence):
    sentence = re.sub(r"[^가-힣\s]", "", sentence)
    return sentence.strip()

def preprocess_eng(sentence):
    sentence = re.sub(r"[^a-zA-Z\s]", "", sentence)
    sentence = '<start> ' + sentence.strip() + ' <end>'
    return sentence

# %%
kor_sentences = [preprocess_kor(sent) for sent, _ in data_pairs]
eng_sentences = [preprocess_eng(sent) for _, sent in data_pairs]

# %%
# 4. 토큰화
mecab = Mecab()
kor_sentences = [mecab.morphs(sent) for sent in kor_sentences]
eng_sentences = [sent.split() for sent in eng_sentences]

# %%
# 5. 데이터 필터링
kor_eng_pairs = [(kor, eng) for kor, eng in zip(kor_sentences, eng_sentences) if len(kor) <= 40 and len(eng) <= 40]

kor_corpus, eng_corpus = zip(*kor_eng_pairs)

# %%
# 6. 텐서 변환 및 토크나이저 생성
def tokenize(lang):
    tokenizer = Tokenizer(filters='')
    tokenizer.fit_on_texts(lang)
    tensor = tokenizer.texts_to_sequences(lang)
    tensor = pad_sequences(tensor, padding='post')
    return tensor, tokenizer

# %%
input_tensor, inp_tokenizer = tokenize(kor_corpus)
target_tensor, targ_tokenizer = tokenize(eng_corpus)

# %%
input_tensor
# Out:
# array([[ 1055,   541,  3762, ...,     0,     0,     0],
#        [   60,   721,  2449, ...,     0,     0,     0],
#        [12655,  3242,  2450, ...,     0,     0,     0],
#        ...,
#        [    2,     7,   324, ...,     0,     0,     0],
#        [   34,    81,     7, ...,     0,     0,     0],
#        [ 3693,  1460,    22, ...,     0,     0,     0]], dtype=int32)

# %%
target_tensor
# Out:
# array([[   2,   68, 6802, ...,    0,    0,    0],
#        [   2,    1,  585, ...,    0,    0,    0],
#        [   2,   39,   13, ...,    0,    0,    0],
#        ...,
#        [   2, 2948,   21, ...,    0,    0,    0],
#        [   2,   92,   19, ...,    0,    0,    0],
#        [   2, 2255,  715, ...,    0,    0,    0]], dtype=int32)

# %%
BUFFER_SIZE = len(input_tensor)
print(BUFFER_SIZE)
BATCH_SIZE = 64
steps_per_epoch = BUFFER_SIZE // BATCH_SIZE
print(steps_per_epoch)
# Out:
# 67350
# 1052

# %%
embedding_dim = 256
units = 1024
vocab_inp_size = len(inp_tokenizer.word_index) + 1
vocab_tar_size = len(targ_tokenizer.word_index) + 1

# %%
dataset = tf.data.Dataset.from_tensor_slices((input_tensor, target_tensor)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
dataset
# Out:
# <BatchDataset shapes: ((64, 40), (64, 40)), types: (tf.int32, tf.int32)>

# %%
# 7. 모델 설계
class Encoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
        super(Encoder, self).__init__()
        self.batch_sz = batch_sz
        self.enc_units = enc_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)  #입력, 출력 
        self.gru = tf.keras.layers.GRU(self.enc_units,  #은닉 상태의 차원 수 (enc_units)
                                       return_sequences=True, #출력 시퀀스의 각 타임스텝에서 출력 반환
                                       return_state=True,  #최종 은닉 상태 반환 
                                       recurrent_initializer='glorot_uniform')  #내부 가중치 초기화

    def call(self, x, hidden):
        x = self.embedding(x)
        output, state = self.gru(x, initial_state=hidden)
        return output, state

    def initialize_hidden_state(self):
        return tf.zeros((self.batch_sz, self.enc_units))

# %%
class BahdanauAttention(tf.keras.layers.Layer):
    def __init__(self, units):
        super(BahdanauAttention, self).__init__()
        self.W1 = tf.keras.layers.Dense(units)  #for query
        self.W2 = tf.keras.layers.Dense(units)  #for values
        self.V = tf.keras.layers.Dense(1)       

    def call(self, query, values):
        hidden_with_time_axis = tf.expand_dims(query, 1)  #(batch_size, 1, hidden_size) 시간 축 추가 
        score = self.V(tf.nn.tanh(
            self.W1(hidden_with_time_axis) + self.W2(values)))  #(batch_size, seq_len, hidden_size)는 values #(batch_size, seq_len, units)가 반환 
        attention_weights = tf.nn.softmax(score, axis=1)
        context_vector = attention_weights * values
        context_vector = tf.reduce_sum(context_vector, axis=1) #최종 context vector 생성 
        return context_vector, attention_weights

# %%
class Decoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
        super(Decoder, self).__init__()
        self.batch_sz = batch_sz
        self.dec_units = dec_units  #GRU 레이어의 은닉 상태 크기 
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(self.dec_units, 
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform')
        self.fc = tf.keras.layers.Dense(vocab_size)
        self.attention = BahdanauAttention(self.dec_units)

    def call(self, x, hidden, enc_output): 
        context_vector, attention_weights = self.attention(hidden, enc_output)
        x = self.embedding(x)
        x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)
        output, state = self.gru(x)
        output = tf.reshape(output, (-1, output.shape[2]))
        x = self.fc(output)
        return x, state, attention_weights

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

# %%
optimizer = tf.keras.optimizers.Adam()

loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

# %%
import os
def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)
    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask
    return tf.reduce_mean(loss_)

checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
    loss = 0
    with tf.GradientTape() as tape:
        enc_output, enc_hidden = encoder(inp, enc_hidden)
        dec_hidden = enc_hidden
        dec_input = tf.expand_dims([targ_tokenizer.word_index['<start>']] * BATCH_SIZE, 1)
        for t in range(1, targ.shape[1]):
            predictions, dec_hidden, _ = decoder(dec_input, dec_hidden, enc_output)
            loss += loss_function(targ[:, t], predictions)
            dec_input = tf.expand_dims(targ[:, t], 1)
    batch_loss = (loss / int(targ.shape[1]))
    variables = encoder.trainable_variables + decoder.trainable_variables
    gradients = tape.gradient(loss, variables)
    optimizer.apply_gradients(zip(gradients, variables))
    return batch_loss

# %%
EPOCHS = 3

for epoch in range(EPOCHS):
    enc_hidden = encoder.initialize_hidden_state()
    total_loss = 0
    for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
        batch_loss = train_step(inp, targ, enc_hidden)
        total_loss += batch_loss
    print(f'Epoch {epoch+1} Loss {total_loss/steps_per_epoch:.4f}')
# Out:
# Epoch 1 Loss 3.4834
# Epoch 2 Loss 3.0440
# Epoch 3 Loss 2.8250

# %%
회고

- 시간이 너무 오래 걸렸다. 아이펠 끝나고 좀 더 학습시키고 결과를 봐야할 거 같다. 
- 그리고 아직 seq 2 seq attention모델이 익숙하지가 않다. 그래서 코드를 긁어오긴 했지만 이해가 잘 안간다. ...
